# %%
import os

import pandas as pd
import numpy as np
import json

from flask import Flask
from flask import jsonify
from flask import request
from flask import make_response
from flask import url_for
from flask import render_template

from sqlalchemy.orm.exc import NoResultFound
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from sqlalchemy.ext.automap import automap_base
import pymysql

pymysql.install_as_MySQLdb()

# %%
engine = create_engine("mysql://root:ming1119@localhost:3306/cloudresources")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['cloud_resource_data']

# %%
# Save reference to the table
Cloudresources_data = Base.classes.cloud_resource_data

# Create session (link) from Python to the DB
session = Session(engine)

# %%
#query the table from mysql
cloud_results = session.query(Cloudresources_data.id, Cloudresources_data.cpu, Cloudresources_data.memory, 
                                Cloudresources_data.network,Cloudresources_data.disk, Cloudresources_data.average,
                                  Cloudresources_data.app_name,Cloudresources_data.server_id,Cloudresources_data.server_cost).\
    order_by(Cloudresources_data.id.asc()).all()

# %%
cloud_results
# Out:
# [(1,
#   Decimal('0.4100000000'),
#   Decimal('0.1000000000'),
#   Decimal('0.4900000000'),
#   Decimal('0.2000000000'),
#   Decimal('0.3000000000'),
#   'APIGateway',
#   1,
#   500),
#  (2,
#   Decimal('0.9100000000'),
#   Decimal('0.5200000000'),
#   Decimal('0.0900000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.4600000000'),
#   'APIGateway',
#   2,
#   500),
#  (3,
#   Decimal('0.7200000000'),
#   Decimal('0.8900000000'),
#   Decimal('0.4700000000'),
#   Decimal('0.4400000000'),
#   Decimal('0.6300000000'),
#   'APIGateway',
#   3,
#   500),
#  (4,
#   Decimal('0.8600000000'),
#   Decimal('0.7900000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.1400000000'),
#   Decimal('0.6600000000'),
#   'APIGateway',
#   4,
#   500),
#  (5,
#   Decimal('0.5900000000'),
#   Decimal('0.2100000000'),
#   Decimal('0.7900000000'),
#   Decimal('0.4900000000'),
#   Decimal('0.5200000000'),
#   'APIGateway',
#   5,
#   500),
#  (6,
#   Decimal('0.3000000000'),
#   Decimal('0.7400000000'),
#   Decimal('0.1700000000'),
#   Decimal('0.8400000000'),
#   Decimal('0.5100000000'),
#   'APIGateway',
#   6,
#   500),
#  (7,
#   Decimal('0.8200000000'),
#   Decimal('0.6600000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.8700000000'),
#   Decimal('0.6800000000'),
#   'APIGateway',
#   7,
#   500),
#  (8,
#   Decimal('0.6200000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.0600000000'),
#   Decimal('0.7500000000'),
#   Decimal('0.4400000000'),
#   'APIGateway',
#   8,
#   500),
#  (9,
#   Decimal('0.0700000000'),
#   Decimal('0.8400000000'),
#   Decimal('0.1500000000'),
#   Decimal('0.1100000000'),
#   Decimal('0.2900000000'),
#   'APIGateway',
#   9,
#   500),
#  (10,
#   Decimal('0.4700000000'),
#   Decimal('0.1200000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.8400000000'),
#   Decimal('0.5300000000'),
#   'APIGateway',
#   10,
#   500),
#  (11,
#   Decimal('0.2500000000'),
#   Decimal('0.2700000000'),
#   Decimal('0.0400000000'),
#   Decimal('0.5900000000'),
#   Decimal('0.2900000000'),
#   'APIGateway',
#   11,
#   500),
#  (12,
#   Decimal('0.1000000000'),
#   Decimal('0.6700000000'),
#   Decimal('0.4300000000'),
#   Decimal('0.6200000000'),
#   Decimal('0.4600000000'),
#   'APIGateway',
#   12,
#   500),
#  (13,
#   Decimal('0.1700000000'),
#   Decimal('0.0900000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.2500000000'),
#   'APIGateway',
#   13,
#   500),
#  (14,
#   Decimal('0.4300000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.9200000000'),
#   Decimal('0.6800000000'),
#   Decimal('0.7200000000'),
#   'APIGateway',
#   14,
#   500),
#  (15,
#   Decimal('0.9900000000'),
#   Decimal('0.5500000000'),
#   Decimal('0.3800000000'),
#   Decimal('0.6500000000'),
#   Decimal('0.6400000000'),
#   'APIGateway',
#   15,
#   500),
#  (16,
#   Decimal('0.6300000000'),
#   Decimal('0.7900000000'),
#   Decimal('0.2800000000'),
#   Decimal('0.3900000000'),
#   Decimal('0.5200000000'),
#   'APIGateway',
#   16,
#   500),
#  (17,
#   Decimal('0.7800000000'),
#   Decimal('0.9800000000'),
#   Decimal('0.2800000000'),
#   Decimal('0.2100000000'),
#   Decimal('0.5600000000'),
#   'APIGateway',
#   17,
#   500),
#  (18,
#   Decimal('0.8600000000'),
#   Decimal('0.1900000000'),
#   Decimal('0.9100000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.5800000000'),
#   'APIGateway',
#   18,
#   500),
#  (19,
#   Decimal('0.6100000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.3800000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.5800000000'),
#   'APIGateway',
#   19,
#   500),
#  (20,
#   Decimal('0.7200000000'),
#   Decimal('0.5500000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.8800000000'),
#   Decimal('0.6100000000'),
#   'APIGateway',
#   20,
#   500),
#  (21,
#   Decimal('0.6400000000'),
#   Decimal('0.0400000000'),
#   Decimal('0.4100000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.4400000000'),
#   'APIGateway',
#   21,
#   500),
#  (22,
#   Decimal('0.8500000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.3900000000'),
#   Decimal('0.7000000000'),
#   'APIGateway',
#   22,
#   500),
#  (23,
#   Decimal('0.5200000000'),
#   Decimal('0.0100000000'),
#   Decimal('0.5600000000'),
#   Decimal('0.3000000000'),
#   Decimal('0.3500000000'),
#   'APIGateway',
#   23,
#   500),
#  (24,
#   Decimal('0.6600000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.9200000000'),
#   Decimal('0.5700000000'),
#   'APIGateway',
#   24,
#   500),
#  (25,
#   Decimal('0.5700000000'),
#   Decimal('0.2700000000'),
#   Decimal('0.1700000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.4600000000'),
#   'APIGateway',
#   25,
#   500),
#  (26,
#   Decimal('0.4500000000'),
#   Decimal('0.2600000000'),
#   Decimal('0.8400000000'),
#   Decimal('0.9500000000'),
#   Decimal('0.6200000000'),
#   'APIGateway',
#   26,
#   500),
#  (27,
#   Decimal('0.9300000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.6400000000'),
#   'APIGateway',
#   27,
#   500),
#  (28,
#   Decimal('0.4200000000'),
#   Decimal('0.7100000000'),
#   Decimal('0.4600000000'),
#   Decimal('0.6600000000'),
#   Decimal('0.5600000000'),
#   'APIGateway',
#   28,
#   500),
#  (29,
#   Decimal('0.1100000000'),
#   Decimal('0.6000000000'),
#   Decimal('0.6600000000'),
#   Decimal('0.4100000000'),
#   Decimal('0.4400000000'),
#   'APIGateway',
#   29,
#   500),
#  (30,
#   Decimal('0.6200000000'),
#   Decimal('0.4200000000'),
#   Decimal('0.5700000000'),
#   Decimal('0.2500000000'),
#   Decimal('0.4700000000'),
#   'APIGateway',
#   30,
#   500),
#  (31,
#   Decimal('0.2600000000'),
#   Decimal('0.5100000000'),
#   Decimal('0.4200000000'),
#   Decimal('0.0600000000'),
#   Decimal('0.3100000000'),
#   'APIGateway',
#   31,
#   500),
#  (32,
#   Decimal('0.4300000000'),
#   Decimal('0.7500000000'),
#   Decimal('0.9900000000'),
#   Decimal('0.4800000000'),
#   Decimal('0.6600000000'),
#   'APIGateway',
#   32,
#   500),
#  (33,
#   Decimal('0.6400000000'),
#   Decimal('0.1600000000'),
#   Decimal('0.8900000000'),
#   Decimal('0.6100000000'),
#   Decimal('0.5700000000'),
#   'APIGateway',
#   33,
#   500),
#  (34,
#   Decimal('0.7300000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.2000000000'),
#   Decimal('0.1700000000'),
#   Decimal('0.3000000000'),
#   'APIGateway',
#   34,
#   500),
#  (35,
#   Decimal('0.1100000000'),
#   Decimal('0.5100000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.3200000000'),
#   'APIGateway',
#   35,
#   500),
#  (36,
#   Decimal('0.3100000000'),
#   Decimal('0.3500000000'),
#   Decimal('0.6400000000'),
#   Decimal('0.6000000000'),
#   Decimal('0.4800000000'),
#   'APIGateway',
#   36,
#   500),
#  (37,
#   Decimal('0.8600000000'),
#   Decimal('0.1300000000'),
#   Decimal('0.0100000000'),
#   Decimal('0.5300000000'),
#   Decimal('0.3800000000'),
#   'APIGateway',
#   37,
#   500),
#  (38,
#   Decimal('0.8500000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.3200000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.6200000000'),
#   'APIGateway',
#   38,
#   500),
#  (39,
#   Decimal('0.4100000000'),
#   Decimal('0.3300000000'),
#   Decimal('0.0200000000'),
#   Decimal('0.6400000000'),
#   Decimal('0.3500000000'),
#   'APIGateway',
#   39,
#   500),
#  (40,
#   Decimal('0.6300000000'),
#   Decimal('0.2100000000'),
#   Decimal('0.3300000000'),
#   Decimal('0.1900000000'),
#   Decimal('0.3400000000'),
#   'Encryption',
#   40,
#   500),
#  (41,
#   Decimal('0.0100000000'),
#   Decimal('0.0100000000'),
#   Decimal('0.6400000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.2400000000'),
#   'Encryption',
#   41,
#   500),
#  (42,
#   Decimal('0.8200000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.1400000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.4600000000'),
#   'Encryption',
#   42,
#   500),
#  (43,
#   Decimal('0.3700000000'),
#   Decimal('0.5500000000'),
#   Decimal('0.9800000000'),
#   Decimal('0.0400000000'),
#   Decimal('0.4800000000'),
#   'Encryption',
#   43,
#   500),
#  (44,
#   Decimal('0.7100000000'),
#   Decimal('0.5400000000'),
#   Decimal('0.6100000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.4800000000'),
#   'Encryption',
#   44,
#   500),
#  (45,
#   Decimal('0.3500000000'),
#   Decimal('0.4000000000'),
#   Decimal('0.9700000000'),
#   Decimal('0.8700000000'),
#   Decimal('0.6500000000'),
#   'Encryption',
#   45,
#   500),
#  (46,
#   Decimal('0.7000000000'),
#   Decimal('0.9700000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.5200000000'),
#   'Encryption',
#   46,
#   500),
#  (47,
#   Decimal('0.6200000000'),
#   Decimal('0.7200000000'),
#   Decimal('0.9500000000'),
#   Decimal('0.2700000000'),
#   Decimal('0.6400000000'),
#   'Encryption',
#   47,
#   500),
#  (48,
#   Decimal('0.8700000000'),
#   Decimal('0.5500000000'),
#   Decimal('0.8700000000'),
#   Decimal('0.8800000000'),
#   Decimal('0.7900000000'),
#   'Encryption',
#   48,
#   500),
#  (49,
#   Decimal('0.2100000000'),
#   Decimal('0.4500000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.2100000000'),
#   Decimal('0.2300000000'),
#   'Encryption',
#   49,
#   500),
#  (50,
#   Decimal('0.8700000000'),
#   Decimal('0.7800000000'),
#   Decimal('0.5600000000'),
#   Decimal('0.6000000000'),
#   Decimal('0.7000000000'),
#   'Encryption',
#   50,
#   500),
#  (51,
#   Decimal('0.7700000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.6100000000'),
#   Decimal('0.5200000000'),
#   'Encryption',
#   51,
#   500),
#  (52,
#   Decimal('0.1100000000'),
#   Decimal('0.4400000000'),
#   Decimal('0.2400000000'),
#   Decimal('0.9400000000'),
#   Decimal('0.4300000000'),
#   'Encryption',
#   52,
#   500),
#  (53,
#   Decimal('0.2200000000'),
#   Decimal('0.3200000000'),
#   Decimal('0.9200000000'),
#   Decimal('0.1300000000'),
#   Decimal('0.4000000000'),
#   'Encryption',
#   53,
#   500),
#  (54,
#   Decimal('0.0900000000'),
#   Decimal('0.1200000000'),
#   Decimal('0.1700000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.2400000000'),
#   'Encryption',
#   54,
#   500),
#  (55,
#   Decimal('0.8700000000'),
#   Decimal('0.5200000000'),
#   Decimal('0.4100000000'),
#   Decimal('0.4100000000'),
#   Decimal('0.5500000000'),
#   'Encryption',
#   55,
#   500),
#  (56,
#   Decimal('0.5500000000'),
#   Decimal('0.4800000000'),
#   Decimal('0.6300000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.6300000000'),
#   'Encryption',
#   56,
#   500),
#  (57,
#   Decimal('0.6200000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.7200000000'),
#   Decimal('0.7900000000'),
#   Decimal('0.7400000000'),
#   'Encryption',
#   57,
#   500),
#  (58,
#   Decimal('0.4800000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.5500000000'),
#   Decimal('0.0400000000'),
#   Decimal('0.3600000000'),
#   'Encryption',
#   58,
#   500),
#  (59,
#   Decimal('0.1400000000'),
#   Decimal('0.6200000000'),
#   Decimal('0.7300000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.5900000000'),
#   'Encryption',
#   59,
#   500),
#  (60,
#   Decimal('0.5000000000'),
#   Decimal('0.1600000000'),
#   Decimal('0.5000000000'),
#   Decimal('0.6600000000'),
#   Decimal('0.4600000000'),
#   'Encryption',
#   60,
#   500),
#  (61,
#   Decimal('0.9100000000'),
#   Decimal('0.6400000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.2800000000'),
#   Decimal('0.5500000000'),
#   'Encryption',
#   61,
#   500),
#  (62,
#   Decimal('0.1900000000'),
#   Decimal('0.1700000000'),
#   Decimal('0.8000000000'),
#   Decimal('0.7200000000'),
#   Decimal('0.4700000000'),
#   'Encryption',
#   62,
#   500),
#  (63,
#   Decimal('0.4700000000'),
#   Decimal('0.5200000000'),
#   Decimal('0.4300000000'),
#   Decimal('0.4900000000'),
#   Decimal('0.4800000000'),
#   'Encryption',
#   63,
#   500),
#  (64,
#   Decimal('0.1400000000'),
#   Decimal('0.3500000000'),
#   Decimal('0.9300000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.5000000000'),
#   'Encryption',
#   64,
#   500),
#  (65,
#   Decimal('0.1000000000'),
#   Decimal('0.4100000000'),
#   Decimal('0.8900000000'),
#   Decimal('0.5700000000'),
#   Decimal('0.4900000000'),
#   'Encryption',
#   65,
#   500),
#  (66,
#   Decimal('0.2800000000'),
#   Decimal('0.5200000000'),
#   Decimal('0.0800000000'),
#   Decimal('0.4200000000'),
#   Decimal('0.3200000000'),
#   'Encryption',
#   66,
#   500),
#  (67,
#   Decimal('0.9400000000'),
#   Decimal('1.0000000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.7300000000'),
#   'Encryption',
#   67,
#   500),
#  (68,
#   Decimal('0.9900000000'),
#   Decimal('0.7800000000'),
#   Decimal('0.6600000000'),
#   Decimal('0.7000000000'),
#   Decimal('0.7800000000'),
#   'Encryption',
#   68,
#   500),
#  (69,
#   Decimal('0.6200000000'),
#   Decimal('0.4100000000'),
#   Decimal('0.8900000000'),
#   Decimal('0.9500000000'),
#   Decimal('0.7200000000'),
#   'Encryption',
#   69,
#   500),
#  (70,
#   Decimal('0.9800000000'),
#   Decimal('0.1100000000'),
#   Decimal('0.2600000000'),
#   Decimal('0.2400000000'),
#   Decimal('0.4000000000'),
#   'Encryption',
#   70,
#   500),
#  (71,
#   Decimal('0.2200000000'),
#   Decimal('0.0100000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.7700000000'),
#   Decimal('0.2700000000'),
#   'Encryption',
#   71,
#   500),
#  (72,
#   Decimal('0.4300000000'),
#   Decimal('0.7500000000'),
#   Decimal('0.4500000000'),
#   Decimal('0.9700000000'),
#   Decimal('0.6500000000'),
#   'Encryption',
#   72,
#   500),
#  (73,
#   Decimal('0.6000000000'),
#   Decimal('0.8000000000'),
#   Decimal('0.3500000000'),
#   Decimal('0.3000000000'),
#   Decimal('0.5100000000'),
#   'Encryption',
#   73,
#   500),
#  (74,
#   Decimal('0.2400000000'),
#   Decimal('0.0800000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.0400000000'),
#   Decimal('0.1100000000'),
#   'Encryption',
#   74,
#   500),
#  (75,
#   Decimal('0.0400000000'),
#   Decimal('0.3000000000'),
#   Decimal('0.5200000000'),
#   Decimal('0.6000000000'),
#   Decimal('0.3600000000'),
#   'Encryption',
#   75,
#   500),
#  (76,
#   Decimal('0.2200000000'),
#   Decimal('0.1200000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.3200000000'),
#   Decimal('0.2400000000'),
#   'Encryption',
#   76,
#   500),
#  (77,
#   Decimal('0.2200000000'),
#   Decimal('0.6100000000'),
#   Decimal('0.3900000000'),
#   Decimal('0.1600000000'),
#   Decimal('0.3400000000'),
#   'Encryption',
#   77,
#   500),
#  (78,
#   Decimal('0.1600000000'),
#   Decimal('0.2600000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.6400000000'),
#   Decimal('0.2700000000'),
#   'Encryption',
#   78,
#   500),
#  (79,
#   Decimal('0.7700000000'),
#   Decimal('0.6600000000'),
#   Decimal('0.6800000000'),
#   Decimal('0.3900000000'),
#   Decimal('0.6300000000'),
#   'Encryption',
#   79,
#   500),
#  (80,
#   Decimal('0.7800000000'),
#   Decimal('0.1500000000'),
#   Decimal('0.1700000000'),
#   Decimal('0.2400000000'),
#   Decimal('0.3300000000'),
#   'Encryption',
#   80,
#   500),
#  (81,
#   Decimal('0.8900000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.6000000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.7000000000'),
#   'Encryption',
#   81,
#   500),
#  (82,
#   Decimal('0.3700000000'),
#   Decimal('0.6800000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.8900000000'),
#   Decimal('0.7300000000'),
#   'Encryption',
#   82,
#   500),
#  (83,
#   Decimal('0.3100000000'),
#   Decimal('0.2500000000'),
#   Decimal('0.2100000000'),
#   Decimal('0.2400000000'),
#   Decimal('0.2500000000'),
#   'Encryption',
#   83,
#   500),
#  (84,
#   Decimal('0.8000000000'),
#   Decimal('0.1900000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.2400000000'),
#   Decimal('0.4000000000'),
#   'Encryption',
#   84,
#   500),
#  (85,
#   Decimal('0.3400000000'),
#   Decimal('0.3500000000'),
#   Decimal('0.4200000000'),
#   Decimal('0.7900000000'),
#   Decimal('0.4700000000'),
#   'Encryption',
#   85,
#   500),
#  (86,
#   Decimal('0.3500000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.2800000000'),
#   Decimal('0.4100000000'),
#   Decimal('0.4800000000'),
#   'Encryption',
#   86,
#   500),
#  (87,
#   Decimal('0.0100000000'),
#   Decimal('0.0200000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.1000000000'),
#   Decimal('0.2700000000'),
#   'Encryption',
#   87,
#   500),
#  (88,
#   Decimal('0.0500000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.0600000000'),
#   Decimal('0.4700000000'),
#   Decimal('0.2200000000'),
#   'Encryption',
#   88,
#   500),
#  (89,
#   Decimal('0.3300000000'),
#   Decimal('0.5400000000'),
#   Decimal('0.9800000000'),
#   Decimal('0.5500000000'),
#   Decimal('0.6000000000'),
#   'Encryption',
#   89,
#   500),
#  (90,
#   Decimal('0.3200000000'),
#   Decimal('0.4600000000'),
#   Decimal('0.0400000000'),
#   Decimal('0.8800000000'),
#   Decimal('0.4200000000'),
#   'Encryption',
#   90,
#   500),
#  (91,
#   Decimal('0.2100000000'),
#   Decimal('0.1600000000'),
#   Decimal('0.7200000000'),
#   Decimal('0.5000000000'),
#   Decimal('0.4000000000'),
#   'Encryption',
#   91,
#   500),
#  (92,
#   Decimal('0.4100000000'),
#   Decimal('0.3900000000'),
#   Decimal('0.3000000000'),
#   Decimal('0.8200000000'),
#   Decimal('0.4800000000'),
#   'Encryption',
#   92,
#   500),
#  (93,
#   Decimal('0.1600000000'),
#   Decimal('0.0600000000'),
#   Decimal('0.1800000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.1900000000'),
#   'Encryption',
#   93,
#   500),
#  (94,
#   Decimal('0.4300000000'),
#   Decimal('0.8200000000'),
#   Decimal('0.7800000000'),
#   Decimal('0.7600000000'),
#   Decimal('0.7000000000'),
#   'Encryption',
#   94,
#   500),
#  (95,
#   Decimal('0.8600000000'),
#   Decimal('0.3500000000'),
#   Decimal('0.9200000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.5400000000'),
#   'Encryption',
#   95,
#   500),
#  (96,
#   Decimal('0.2100000000'),
#   Decimal('0.6600000000'),
#   Decimal('0.2300000000'),
#   Decimal('0.0100000000'),
#   Decimal('0.2800000000'),
#   'Encryption',
#   96,
#   500),
#  (97,
#   Decimal('0.4500000000'),
#   Decimal('0.9700000000'),
#   Decimal('0.3200000000'),
#   Decimal('0.7100000000'),
#   Decimal('0.6100000000'),
#   'Encryption',
#   97,
#   500),
#  (98,
#   Decimal('0.9300000000'),
#   Decimal('0.7200000000'),
#   Decimal('0.9900000000'),
#   Decimal('0E-10'),
#   Decimal('0.6600000000'),
#   'Encryption',
#   98,
#   500),
#  (99,
#   Decimal('0.6100000000'),
#   Decimal('0.8800000000'),
#   Decimal('0.7700000000'),
#   Decimal('0.8700000000'),
#   Decimal('0.7800000000'),
#   'Encryption',
#   99,
#   500),
#  (100,
#   Decimal('0.9400000000'),
#   Decimal('0.3000000000'),
#   Decimal('0.7200000000'),
#   Decimal('0.7100000000'),
#   Decimal('0.6700000000'),
#   'Encryption',
#   100,
#   500),
#  (101,
#   Decimal('0.3600000000'),
#   Decimal('0.4500000000'),
#   Decimal('0.5400000000'),
#   Decimal('0.4400000000'),
#   Decimal('0.4500000000'),
#   'Encryption',
#   101,
#   500),
#  (102,
#   Decimal('0.0300000000'),
#   Decimal('0.6700000000'),
#   Decimal('0.1500000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.2200000000'),
#   'Encryption',
#   102,
#   500),
#  (103,
#   Decimal('0.7600000000'),
#   Decimal('0.8000000000'),
#   Decimal('0.7500000000'),
#   Decimal('0.1400000000'),
#   Decimal('0.6100000000'),
#   'Encryption',
#   103,
#   500),
#  (104,
#   Decimal('0.5700000000'),
#   Decimal('0.0400000000'),
#   Decimal('0.7800000000'),
#   Decimal('0.3300000000'),
#   Decimal('0.4300000000'),
#   'Encryption',
#   104,
#   500),
#  (105,
#   Decimal('0.2600000000'),
#   Decimal('0.4000000000'),
#   Decimal('0.4500000000'),
#   Decimal('0.1700000000'),
#   Decimal('0.3200000000'),
#   'Encryption',
#   105,
#   500),
#  (106,
#   Decimal('0.1600000000'),
#   Decimal('0.4900000000'),
#   Decimal('0.9400000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.5700000000'),
#   'Encryption',
#   106,
#   500),
#  (107,
#   Decimal('0.7300000000'),
#   Decimal('0.7000000000'),
#   Decimal('0.1400000000'),
#   Decimal('0.1600000000'),
#   Decimal('0.4300000000'),
#   'Encryption',
#   107,
#   500),
#  (108,
#   Decimal('0.4400000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.1800000000'),
#   Decimal('0.8000000000'),
#   Decimal('0.4500000000'),
#   'Encryption',
#   108,
#   500),
#  (109,
#   Decimal('0.2400000000'),
#   Decimal('0.2800000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.7800000000'),
#   Decimal('0.4000000000'),
#   'Encryption',
#   109,
#   500),
#  (110,
#   Decimal('0.8800000000'),
#   Decimal('0.6400000000'),
#   Decimal('0.3000000000'),
#   Decimal('0.6500000000'),
#   Decimal('0.6200000000'),
#   'Encryption',
#   110,
#   500),
#  (111,
#   Decimal('0.7000000000'),
#   Decimal('0.1400000000'),
#   Decimal('0.5000000000'),
#   Decimal('0.8700000000'),
#   Decimal('0.5500000000'),
#   'Encryption',
#   111,
#   500),
#  (112,
#   Decimal('0.0200000000'),
#   Decimal('0.0400000000'),
#   Decimal('0.3800000000'),
#   Decimal('0.4700000000'),
#   Decimal('0.2300000000'),
#   'Encryption',
#   112,
#   500),
#  (113,
#   Decimal('0.7300000000'),
#   Decimal('0.0600000000'),
#   Decimal('0.1900000000'),
#   Decimal('0.1400000000'),
#   Decimal('0.2800000000'),
#   'Encryption',
#   113,
#   500),
#  (114,
#   Decimal('0.2100000000'),
#   Decimal('0.9200000000'),
#   Decimal('0.7400000000'),
#   Decimal('0.5400000000'),
#   Decimal('0.6000000000'),
#   'Encryption',
#   114,
#   500),
#  (115,
#   Decimal('0.5600000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.2400000000'),
#   Decimal('0.5600000000'),
#   Decimal('0.4300000000'),
#   'Encryption',
#   115,
#   500),
#  (116,
#   Decimal('0.6400000000'),
#   Decimal('0.0800000000'),
#   Decimal('0.4100000000'),
#   Decimal('0.2300000000'),
#   Decimal('0.3400000000'),
#   'Encryption',
#   116,
#   500),
#  (117,
#   Decimal('0.8100000000'),
#   Decimal('0.2700000000'),
#   Decimal('0.7800000000'),
#   Decimal('0.1600000000'),
#   Decimal('0.5000000000'),
#   'Encryption',
#   117,
#   500),
#  (118,
#   Decimal('0.9200000000'),
#   Decimal('0.9000000000'),
#   Decimal('0.3000000000'),
#   Decimal('0.1700000000'),
#   Decimal('0.5700000000'),
#   'Encryption',
#   118,
#   500),
#  (119,
#   Decimal('0.4900000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.9900000000'),
#   Decimal('0.5500000000'),
#   'Encryption',
#   119,
#   500),
#  (120,
#   Decimal('0.6700000000'),
#   Decimal('0.6800000000'),
#   Decimal('0.5000000000'),
#   Decimal('0.6800000000'),
#   Decimal('0.6300000000'),
#   'Encryption',
#   120,
#   500),
#  (121,
#   Decimal('0E-10'),
#   Decimal('0.3300000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.1100000000'),
#   Decimal('0.1300000000'),
#   'Encryption',
#   121,
#   500),
#  (122,
#   Decimal('0.1000000000'),
#   Decimal('0.7000000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.1600000000'),
#   Decimal('0.4500000000'),
#   'Encryption',
#   122,
#   500),
#  (123,
#   Decimal('0.9800000000'),
#   Decimal('0.3000000000'),
#   Decimal('0.1200000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.3600000000'),
#   'Encryption',
#   123,
#   500),
#  (124,
#   Decimal('0.5200000000'),
#   Decimal('0.9800000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.4300000000'),
#   Decimal('0.5600000000'),
#   'Encryption',
#   124,
#   500),
#  (125,
#   Decimal('0.3300000000'),
#   Decimal('0.4400000000'),
#   Decimal('0.5700000000'),
#   Decimal('0.4000000000'),
#   Decimal('0.4400000000'),
#   'Encryption',
#   125,
#   500),
#  (126,
#   Decimal('0.5600000000'),
#   Decimal('0.2300000000'),
#   Decimal('0.2200000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.3500000000'),
#   'Encryption',
#   126,
#   500),
#  (127,
#   Decimal('0.8000000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.1000000000'),
#   Decimal('0.0900000000'),
#   Decimal('0.4200000000'),
#   'Encryption',
#   127,
#   500),
#  (128,
#   Decimal('0.3400000000'),
#   Decimal('0.7800000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.7100000000'),
#   Decimal('0.6300000000'),
#   'Encryption',
#   128,
#   500),
#  (129,
#   Decimal('0.4900000000'),
#   Decimal('0.9200000000'),
#   Decimal('0.4400000000'),
#   Decimal('0.9700000000'),
#   Decimal('0.7100000000'),
#   'Encryption',
#   129,
#   500),
#  (130,
#   Decimal('0.8800000000'),
#   Decimal('0.0400000000'),
#   Decimal('0.6000000000'),
#   Decimal('0.4900000000'),
#   Decimal('0.5000000000'),
#   'Encryption',
#   130,
#   500),
#  (131,
#   Decimal('0.1600000000'),
#   Decimal('0.5100000000'),
#   Decimal('0.3300000000'),
#   Decimal('0.9300000000'),
#   Decimal('0.4800000000'),
#   'Encryption',
#   131,
#   500),
#  (132,
#   Decimal('0.1300000000'),
#   Decimal('0.2000000000'),
#   Decimal('0.6300000000'),
#   Decimal('0.4900000000'),
#   Decimal('0.3600000000'),
#   'Encryption',
#   132,
#   500),
#  (133,
#   Decimal('0.8300000000'),
#   Decimal('0.4900000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.1900000000'),
#   Decimal('0.5500000000'),
#   'Encryption',
#   133,
#   500),
#  (134,
#   Decimal('0.5700000000'),
#   Decimal('0.9100000000'),
#   Decimal('0.6500000000'),
#   Decimal('0.2200000000'),
#   Decimal('0.5900000000'),
#   'Encryption',
#   134,
#   500),
#  (135,
#   Decimal('0.7400000000'),
#   Decimal('0.4500000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.4800000000'),
#   'Encryption',
#   135,
#   500),
#  (136,
#   Decimal('0.7100000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.2800000000'),
#   Decimal('0.4200000000'),
#   'Encryption',
#   136,
#   500),
#  (137,
#   Decimal('0.1000000000'),
#   Decimal('0.7000000000'),
#   Decimal('0.7800000000'),
#   Decimal('0.4300000000'),
#   Decimal('0.5000000000'),
#   'Encryption',
#   137,
#   500),
#  (138,
#   Decimal('0.6300000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.1400000000'),
#   Decimal('0.1600000000'),
#   Decimal('0.3800000000'),
#   'Encryption',
#   138,
#   500),
#  (139,
#   Decimal('0.2100000000'),
#   Decimal('0.2500000000'),
#   Decimal('0.8000000000'),
#   Decimal('0.4300000000'),
#   Decimal('0.4200000000'),
#   'Encryption',
#   139,
#   500),
#  (140,
#   Decimal('0.3100000000'),
#   Decimal('0.7000000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.4200000000'),
#   'Encryption',
#   140,
#   500),
#  (141,
#   Decimal('0.4300000000'),
#   Decimal('0.2100000000'),
#   Decimal('0.7100000000'),
#   Decimal('0.8800000000'),
#   Decimal('0.5600000000'),
#   'Encryption',
#   141,
#   500),
#  (142,
#   Decimal('0.7500000000'),
#   Decimal('0.2500000000'),
#   Decimal('0.5400000000'),
#   Decimal('0.4400000000'),
#   Decimal('0.4900000000'),
#   'Encryption',
#   142,
#   500),
#  (143,
#   Decimal('0.9300000000'),
#   Decimal('0.7900000000'),
#   Decimal('0.2400000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.5800000000'),
#   'Encryption',
#   143,
#   500),
#  (144,
#   Decimal('0.5200000000'),
#   Decimal('0.8500000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.5700000000'),
#   Decimal('0.6900000000'),
#   'Encryption',
#   144,
#   500),
#  (145,
#   Decimal('0.9300000000'),
#   Decimal('0.5300000000'),
#   Decimal('0.1000000000'),
#   Decimal('0.9800000000'),
#   Decimal('0.6400000000'),
#   'Encryption',
#   145,
#   500),
#  (146,
#   Decimal('0.6600000000'),
#   Decimal('0.8100000000'),
#   Decimal('0.2700000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.5300000000'),
#   'Encryption',
#   146,
#   500),
#  (147,
#   Decimal('0.0900000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.8900000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.4300000000'),
#   'Encryption',
#   147,
#   500),
#  (148,
#   Decimal('0.6000000000'),
#   Decimal('0.6300000000'),
#   Decimal('0.1400000000'),
#   Decimal('0.2100000000'),
#   Decimal('0.4000000000'),
#   'Encryption',
#   148,
#   500),
#  (149,
#   Decimal('0.9300000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.0100000000'),
#   Decimal('0.7900000000'),
#   Decimal('0.5300000000'),
#   'Encryption',
#   149,
#   500),
#  (150,
#   Decimal('0.9600000000'),
#   Decimal('0.7800000000'),
#   Decimal('0.2200000000'),
#   Decimal('0.8800000000'),
#   Decimal('0.7100000000'),
#   'Encryption',
#   150,
#   500),
#  (151,
#   Decimal('0.6900000000'),
#   Decimal('0.8900000000'),
#   Decimal('0.3100000000'),
#   Decimal('1.0000000000'),
#   Decimal('0.7200000000'),
#   'Encryption',
#   151,
#   500),
#  (152,
#   Decimal('0.3100000000'),
#   Decimal('0.9300000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.5400000000'),
#   'Encryption',
#   152,
#   500),
#  (153,
#   Decimal('0.3500000000'),
#   Decimal('0.0800000000'),
#   Decimal('0.4800000000'),
#   Decimal('0.5500000000'),
#   Decimal('0.3600000000'),
#   'Encryption',
#   153,
#   500),
#  (154,
#   Decimal('0.1400000000'),
#   Decimal('0.4000000000'),
#   Decimal('0.5700000000'),
#   Decimal('0.2100000000'),
#   Decimal('0.3300000000'),
#   'Encryption',
#   154,
#   500),
#  (155,
#   Decimal('0.6600000000'),
#   Decimal('0.4800000000'),
#   Decimal('0.4100000000'),
#   Decimal('0.4000000000'),
#   Decimal('0.4900000000'),
#   'Encryption',
#   155,
#   500),
#  (156,
#   Decimal('0.2100000000'),
#   Decimal('0.2600000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.1100000000'),
#   Decimal('0.1500000000'),
#   'Encryption',
#   156,
#   500),
#  (157,
#   Decimal('0.9600000000'),
#   Decimal('0.0800000000'),
#   Decimal('0.0200000000'),
#   Decimal('0.5000000000'),
#   Decimal('0.3900000000'),
#   'Encryption',
#   157,
#   500),
#  (158,
#   Decimal('0.7700000000'),
#   Decimal('0.5400000000'),
#   Decimal('0.7700000000'),
#   Decimal('0.6000000000'),
#   Decimal('0.6700000000'),
#   'Encryption',
#   158,
#   500),
#  (159,
#   Decimal('0.6100000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.9400000000'),
#   Decimal('0.8500000000'),
#   Decimal('0.7500000000'),
#   'Encryption',
#   159,
#   500),
#  (160,
#   Decimal('0.3400000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.2200000000'),
#   Decimal('0.5100000000'),
#   Decimal('0.4100000000'),
#   'Encryption',
#   160,
#   500),
#  (161,
#   Decimal('0.5800000000'),
#   Decimal('0.8100000000'),
#   Decimal('0.9200000000'),
#   Decimal('0.4400000000'),
#   Decimal('0.6900000000'),
#   'Encryption',
#   161,
#   500),
#  (162,
#   Decimal('0.0800000000'),
#   Decimal('0.5400000000'),
#   Decimal('0.8200000000'),
#   Decimal('0.6300000000'),
#   Decimal('0.5200000000'),
#   'Encryption',
#   162,
#   500),
#  (163,
#   Decimal('0.8800000000'),
#   Decimal('0.0900000000'),
#   Decimal('0.7100000000'),
#   Decimal('0.5400000000'),
#   Decimal('0.5600000000'),
#   'Encryption',
#   163,
#   500),
#  (164,
#   Decimal('0.9100000000'),
#   Decimal('0.7600000000'),
#   Decimal('0.2000000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.5400000000'),
#   'Encryption',
#   164,
#   500),
#  (165,
#   Decimal('0.7600000000'),
#   Decimal('0.5400000000'),
#   Decimal('0.8000000000'),
#   Decimal('0.4600000000'),
#   Decimal('0.6400000000'),
#   'Encryption',
#   165,
#   500),
#  (166,
#   Decimal('0.1200000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.6700000000'),
#   Decimal('0.1600000000'),
#   Decimal('0.4400000000'),
#   'Encryption',
#   166,
#   500),
#  (167,
#   Decimal('0.9200000000'),
#   Decimal('0.7800000000'),
#   Decimal('0.7300000000'),
#   Decimal('0.4400000000'),
#   Decimal('0.7200000000'),
#   'Encryption',
#   167,
#   500),
#  (168,
#   Decimal('0.3000000000'),
#   Decimal('0.9700000000'),
#   Decimal('0.2400000000'),
#   Decimal('0.4700000000'),
#   Decimal('0.5000000000'),
#   'Encryption',
#   168,
#   500),
#  (169,
#   Decimal('0.2500000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.1300000000'),
#   Decimal('0.7000000000'),
#   Decimal('0.2800000000'),
#   'Encryption',
#   169,
#   500),
#  (170,
#   Decimal('0.3200000000'),
#   Decimal('0.1300000000'),
#   Decimal('0.2000000000'),
#   Decimal('0.1000000000'),
#   Decimal('0.1900000000'),
#   'Encryption',
#   170,
#   500),
#  (171,
#   Decimal('0.0100000000'),
#   Decimal('0.5100000000'),
#   Decimal('0.4200000000'),
#   Decimal('0.3800000000'),
#   Decimal('0.3300000000'),
#   'Encryption',
#   171,
#   500),
#  (172,
#   Decimal('0.9200000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.5100000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.5800000000'),
#   'Encryption',
#   172,
#   500),
#  (173,
#   Decimal('0.6400000000'),
#   Decimal('0.9200000000'),
#   Decimal('0.9100000000'),
#   Decimal('0.7400000000'),
#   Decimal('0.8000000000'),
#   'Encryption',
#   173,
#   500),
#  (174,
#   Decimal('0.1200000000'),
#   Decimal('0.8100000000'),
#   Decimal('0.5200000000'),
#   Decimal('0.3900000000'),
#   Decimal('0.4600000000'),
#   'ContentApp',
#   174,
#   500),
#  (175,
#   Decimal('0E-10'),
#   Decimal('0.8100000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.8400000000'),
#   Decimal('0.5000000000'),
#   'ContentApp',
#   175,
#   500),
#  (176,
#   Decimal('0.8400000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.8800000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.6200000000'),
#   'ContentApp',
#   176,
#   500),
#  (177,
#   Decimal('0.3500000000'),
#   Decimal('0.6100000000'),
#   Decimal('0.4300000000'),
#   Decimal('0.3000000000'),
#   Decimal('0.4200000000'),
#   'ContentApp',
#   177,
#   500),
#  (178,
#   Decimal('0.1600000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.7100000000'),
#   Decimal('0.5200000000'),
#   'ContentApp',
#   178,
#   500),
#  (179,
#   Decimal('0.3600000000'),
#   Decimal('0.9300000000'),
#   Decimal('0.4000000000'),
#   Decimal('0.8900000000'),
#   Decimal('0.6400000000'),
#   'ContentApp',
#   179,
#   500),
#  (180,
#   Decimal('0.2600000000'),
#   Decimal('0.5700000000'),
#   Decimal('0.1900000000'),
#   Decimal('0.9800000000'),
#   Decimal('0.5000000000'),
#   'ContentApp',
#   180,
#   500),
#  (181,
#   Decimal('0.1800000000'),
#   Decimal('0.9000000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.6200000000'),
#   Decimal('0.6600000000'),
#   'ContentApp',
#   181,
#   500),
#  (182,
#   Decimal('0.7100000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.0600000000'),
#   Decimal('0.9100000000'),
#   Decimal('0.6600000000'),
#   'ContentApp',
#   182,
#   500),
#  (183,
#   Decimal('0.6200000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.6400000000'),
#   'ContentApp',
#   183,
#   500),
#  (184,
#   Decimal('0.0100000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.8700000000'),
#   Decimal('0.4900000000'),
#   Decimal('0.5500000000'),
#   'ContentApp',
#   184,
#   500),
#  (185,
#   Decimal('0.2300000000'),
#   Decimal('0.2400000000'),
#   Decimal('0.7600000000'),
#   Decimal('0.2200000000'),
#   Decimal('0.3600000000'),
#   'ContentApp',
#   185,
#   500),
#  (186,
#   Decimal('0.2600000000'),
#   Decimal('0.8900000000'),
#   Decimal('0.6800000000'),
#   Decimal('0.0600000000'),
#   Decimal('0.4700000000'),
#   'ContentApp',
#   186,
#   500),
#  (187,
#   Decimal('0.6500000000'),
#   Decimal('0.6200000000'),
#   Decimal('0.8000000000'),
#   Decimal('0.9000000000'),
#   Decimal('0.7400000000'),
#   'ContentApp',
#   187,
#   500),
#  (188,
#   Decimal('0.7700000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.5900000000'),
#   'ContentApp',
#   188,
#   500),
#  (189,
#   Decimal('0.4200000000'),
#   Decimal('0.2300000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.6000000000'),
#   Decimal('0.4900000000'),
#   'ContentApp',
#   189,
#   500),
#  (190,
#   Decimal('0.6000000000'),
#   Decimal('0.2700000000'),
#   Decimal('0.1300000000'),
#   Decimal('0.8900000000'),
#   Decimal('0.4700000000'),
#   'ContentApp',
#   190,
#   500),
#  (191,
#   Decimal('0.0600000000'),
#   Decimal('0.1200000000'),
#   Decimal('0.4900000000'),
#   Decimal('0.2000000000'),
#   Decimal('0.2200000000'),
#   'ContentApp',
#   191,
#   500),
#  (192,
#   Decimal('0.5500000000'),
#   Decimal('0.1800000000'),
#   Decimal('0.5600000000'),
#   Decimal('0.9200000000'),
#   Decimal('0.5500000000'),
#   'ContentApp',
#   192,
#   500),
#  (193,
#   Decimal('0.2600000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.1100000000'),
#   Decimal('0.0400000000'),
#   Decimal('0.3200000000'),
#   'ContentApp',
#   193,
#   500),
#  (194,
#   Decimal('0.1300000000'),
#   Decimal('0.6100000000'),
#   Decimal('0.9800000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.4400000000'),
#   'ContentApp',
#   194,
#   500),
#  (195,
#   Decimal('0.1200000000'),
#   Decimal('0.2100000000'),
#   Decimal('0.4000000000'),
#   Decimal('0.1100000000'),
#   Decimal('0.2100000000'),
#   'ContentApp',
#   195,
#   500),
#  (196,
#   Decimal('0.1100000000'),
#   Decimal('0.9100000000'),
#   Decimal('0.0900000000'),
#   Decimal('0.7200000000'),
#   Decimal('0.4600000000'),
#   'ContentApp',
#   196,
#   500),
#  (197,
#   Decimal('0.0900000000'),
#   Decimal('0.9900000000'),
#   Decimal('0.6700000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.5300000000'),
#   'ContentApp',
#   197,
#   500),
#  (198,
#   Decimal('0.7500000000'),
#   Decimal('0.8800000000'),
#   Decimal('0.4500000000'),
#   Decimal('0.2600000000'),
#   Decimal('0.5800000000'),
#   'ContentApp',
#   198,
#   500),
#  (199,
#   Decimal('0.3800000000'),
#   Decimal('0.2500000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.1800000000'),
#   Decimal('0.2100000000'),
#   'ContentApp',
#   199,
#   500),
#  (200,
#   Decimal('0.5100000000'),
#   Decimal('0.4200000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.2700000000'),
#   Decimal('0.3900000000'),
#   'ContentApp',
#   200,
#   500),
#  (201,
#   Decimal('0.1800000000'),
#   Decimal('0.1600000000'),
#   Decimal('0.3500000000'),
#   Decimal('0.3800000000'),
#   Decimal('0.2700000000'),
#   'ContentApp',
#   201,
#   500),
#  (202,
#   Decimal('0.5300000000'),
#   Decimal('0.8000000000'),
#   Decimal('0.9900000000'),
#   Decimal('0.4700000000'),
#   Decimal('0.7000000000'),
#   'ContentApp',
#   202,
#   500),
#  (203,
#   Decimal('0.5600000000'),
#   Decimal('0.2800000000'),
#   Decimal('0.3000000000'),
#   Decimal('0.4500000000'),
#   Decimal('0.4000000000'),
#   'ContentApp',
#   203,
#   500),
#  (204,
#   Decimal('0.6700000000'),
#   Decimal('0.6500000000'),
#   Decimal('0.8500000000'),
#   Decimal('0.7300000000'),
#   Decimal('0.7300000000'),
#   'ContentApp',
#   204,
#   500),
#  (205,
#   Decimal('0.0800000000'),
#   Decimal('0.1500000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.2200000000'),
#   'ContentApp',
#   205,
#   500),
#  (206,
#   Decimal('0.3400000000'),
#   Decimal('0.5600000000'),
#   Decimal('0.2700000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.3800000000'),
#   'ContentApp',
#   206,
#   500),
#  (207,
#   Decimal('0.3900000000'),
#   Decimal('0.2200000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.4700000000'),
#   Decimal('0.2900000000'),
#   'ContentApp',
#   207,
#   500),
#  (208,
#   Decimal('0.3000000000'),
#   Decimal('0.3200000000'),
#   Decimal('0.4300000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.2700000000'),
#   'ContentApp',
#   208,
#   500),
#  (209,
#   Decimal('0.4600000000'),
#   Decimal('0.7900000000'),
#   Decimal('0.1800000000'),
#   Decimal('0.4900000000'),
#   Decimal('0.4800000000'),
#   'ContentApp',
#   209,
#   500),
#  (210,
#   Decimal('0.5700000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.0800000000'),
#   Decimal('0.7100000000'),
#   Decimal('0.5600000000'),
#   'ContentApp',
#   210,
#   500),
#  (211,
#   Decimal('0.9000000000'),
#   Decimal('0.5900000000'),
#   Decimal('0.6300000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.5500000000'),
#   'ContentApp',
#   211,
#   500),
#  (212,
#   Decimal('0.4200000000'),
#   Decimal('0.5300000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.4000000000'),
#   'ContentApp',
#   212,
#   500),
#  (213,
#   Decimal('0.0800000000'),
#   Decimal('0.1000000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.8500000000'),
#   Decimal('0.2700000000'),
#   'ContentApp',
#   213,
#   500),
#  (214,
#   Decimal('0.2400000000'),
#   Decimal('0.8200000000'),
#   Decimal('0.9900000000'),
#   Decimal('0.8100000000'),
#   Decimal('0.7100000000'),
#   'ContentApp',
#   214,
#   500),
#  (215,
#   Decimal('0.2000000000'),
#   Decimal('0.9200000000'),
#   Decimal('0.9500000000'),
#   Decimal('0.8200000000'),
#   Decimal('0.7200000000'),
#   'ContentApp',
#   215,
#   500),
#  (216,
#   Decimal('0.2500000000'),
#   Decimal('0.4200000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.7400000000'),
#   Decimal('0.5600000000'),
#   'ContentApp',
#   216,
#   500),
#  (217,
#   Decimal('0.0700000000'),
#   Decimal('0.2100000000'),
#   Decimal('0.8500000000'),
#   Decimal('0E-10'),
#   Decimal('0.2800000000'),
#   'ContentApp',
#   217,
#   500),
#  (218,
#   Decimal('0.0600000000'),
#   Decimal('0.9200000000'),
#   Decimal('0.3200000000'),
#   Decimal('0.5600000000'),
#   Decimal('0.4700000000'),
#   'ContentApp',
#   218,
#   500),
#  (219,
#   Decimal('0.4400000000'),
#   Decimal('0.0100000000'),
#   Decimal('0.0200000000'),
#   Decimal('0.5100000000'),
#   Decimal('0.2500000000'),
#   'ContentApp',
#   219,
#   500),
#  (220,
#   Decimal('0.1800000000'),
#   Decimal('0.2300000000'),
#   Decimal('0.1800000000'),
#   Decimal('0.1200000000'),
#   Decimal('0.1800000000'),
#   'ContentApp',
#   220,
#   500),
#  (221,
#   Decimal('0.3100000000'),
#   Decimal('0.3800000000'),
#   Decimal('0.4900000000'),
#   Decimal('0.7000000000'),
#   Decimal('0.4700000000'),
#   'ContentApp',
#   221,
#   500),
#  (222,
#   Decimal('0.7100000000'),
#   Decimal('0.5000000000'),
#   Decimal('0.4700000000'),
#   Decimal('0.2500000000'),
#   Decimal('0.4800000000'),
#   'ContentApp',
#   222,
#   500),
#  (223,
#   Decimal('0.3900000000'),
#   Decimal('0.1900000000'),
#   Decimal('0.9900000000'),
#   Decimal('0.3200000000'),
#   Decimal('0.4700000000'),
#   'ContentApp',
#   223,
#   500),
#  (224,
#   Decimal('0.8800000000'),
#   Decimal('0.3900000000'),
#   Decimal('0.5200000000'),
#   Decimal('0.6800000000'),
#   Decimal('0.6200000000'),
#   'ContentApp',
#   224,
#   500),
#  (225,
#   Decimal('0.2500000000'),
#   Decimal('0.3300000000'),
#   Decimal('0.8900000000'),
#   Decimal('0.8700000000'),
#   Decimal('0.5800000000'),
#   'ContentApp',
#   225,
#   500),
#  (226,
#   Decimal('0.4600000000'),
#   Decimal('0.2000000000'),
#   Decimal('0.8700000000'),
#   Decimal('0.2700000000'),
#   Decimal('0.4500000000'),
#   'ContentApp',
#   226,
#   500),
#  (227,
#   Decimal('0.3200000000'),
#   Decimal('0.3200000000'),
#   Decimal('0.3900000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.4300000000'),
#   'ContentApp',
#   227,
#   500),
#  (228,
#   Decimal('0.3500000000'),
#   Decimal('0.3800000000'),
#   Decimal('0.1400000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.3900000000'),
#   'ContentApp',
#   228,
#   500),
#  (229,
#   Decimal('0.4700000000'),
#   Decimal('0.3500000000'),
#   Decimal('0.4800000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.3400000000'),
#   'ContentApp',
#   229,
#   500),
#  (230,
#   Decimal('0.8700000000'),
#   Decimal('0.0200000000'),
#   Decimal('0.5900000000'),
#   Decimal('0.0900000000'),
#   Decimal('0.3900000000'),
#   'ContentApp',
#   230,
#   500),
#  (231,
#   Decimal('0.0800000000'),
#   Decimal('0.8100000000'),
#   Decimal('0.0100000000'),
#   Decimal('0.7400000000'),
#   Decimal('0.4100000000'),
#   'ContentApp',
#   231,
#   500),
#  (232,
#   Decimal('0.7900000000'),
#   Decimal('0.7900000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.4500000000'),
#   Decimal('0.7500000000'),
#   'ContentApp',
#   232,
#   500),
#  (233,
#   Decimal('0.5700000000'),
#   Decimal('0.8800000000'),
#   Decimal('0.8400000000'),
#   Decimal('0.2800000000'),
#   Decimal('0.6400000000'),
#   'ContentApp',
#   233,
#   500),
#  (234,
#   Decimal('0.6100000000'),
#   Decimal('0.4600000000'),
#   Decimal('0.3800000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.3700000000'),
#   'ContentApp',
#   234,
#   500),
#  (235,
#   Decimal('0.8400000000'),
#   Decimal('0.1400000000'),
#   Decimal('0.6100000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.4700000000'),
#   'ContentApp',
#   235,
#   500),
#  (236,
#   Decimal('0.1800000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.7400000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.3300000000'),
#   'ContentApp',
#   236,
#   500),
#  (237,
#   Decimal('0.4100000000'),
#   Decimal('0.7500000000'),
#   Decimal('0.9800000000'),
#   Decimal('0.8500000000'),
#   Decimal('0.7500000000'),
#   'ContentApp',
#   237,
#   500),
#  (238,
#   Decimal('0.8300000000'),
#   Decimal('0.6200000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.4700000000'),
#   Decimal('0.5500000000'),
#   'ContentApp',
#   238,
#   500),
#  (239,
#   Decimal('0.5100000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.0600000000'),
#   Decimal('0.2800000000'),
#   Decimal('0.3000000000'),
#   'ContentApp',
#   239,
#   500),
#  (240,
#   Decimal('0.0900000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.5400000000'),
#   Decimal('0.4100000000'),
#   'ContentApp',
#   240,
#   500),
#  (241,
#   Decimal('0.5200000000'),
#   Decimal('0.2200000000'),
#   Decimal('0.4000000000'),
#   Decimal('0.6600000000'),
#   Decimal('0.4500000000'),
#   'ContentApp',
#   241,
#   500),
#  (242,
#   Decimal('0.8400000000'),
#   Decimal('0.6100000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.5700000000'),
#   Decimal('0.5800000000'),
#   'ContentApp',
#   242,
#   500),
#  (243,
#   Decimal('0.1800000000'),
#   Decimal('0.0600000000'),
#   Decimal('0.4800000000'),
#   Decimal('0.8200000000'),
#   Decimal('0.3900000000'),
#   'ContentApp',
#   243,
#   500),
#  (244,
#   Decimal('0.8200000000'),
#   Decimal('0.6600000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.6000000000'),
#   'ContentApp',
#   244,
#   500),
#  (245,
#   Decimal('0.0200000000'),
#   Decimal('0.5900000000'),
#   Decimal('0.7200000000'),
#   Decimal('0.2300000000'),
#   Decimal('0.3900000000'),
#   'ContentApp',
#   245,
#   500),
#  (246,
#   Decimal('0.2800000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.8400000000'),
#   Decimal('0.5400000000'),
#   Decimal('0.4900000000'),
#   'ContentApp',
#   246,
#   500),
#  (247,
#   Decimal('0.1500000000'),
#   Decimal('0.8700000000'),
#   Decimal('0.3800000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.4300000000'),
#   'ContentApp',
#   247,
#   500),
#  (248,
#   Decimal('0.9800000000'),
#   Decimal('0.6800000000'),
#   Decimal('0.4500000000'),
#   Decimal('0.9900000000'),
#   Decimal('0.7700000000'),
#   'ContentApp',
#   248,
#   500),
#  (249,
#   Decimal('0.6900000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.8000000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.5400000000'),
#   'ContentApp',
#   249,
#   500),
#  (250,
#   Decimal('0.2100000000'),
#   Decimal('0.6000000000'),
#   Decimal('0.7800000000'),
#   Decimal('0.3500000000'),
#   Decimal('0.4800000000'),
#   'ContentApp',
#   250,
#   500),
#  (251,
#   Decimal('0.4300000000'),
#   Decimal('0.7100000000'),
#   Decimal('0.7300000000'),
#   Decimal('0.6500000000'),
#   Decimal('0.6300000000'),
#   'ContentApp',
#   251,
#   500),
#  (252,
#   Decimal('0.2800000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.2300000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.5400000000'),
#   'ContentApp',
#   252,
#   500),
#  (253,
#   Decimal('0.8200000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.1200000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.4700000000'),
#   'ContentApp',
#   253,
#   500),
#  (254,
#   Decimal('0.1000000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.5300000000'),
#   Decimal('0.4100000000'),
#   Decimal('0.3400000000'),
#   'ContentApp',
#   254,
#   500),
#  (255,
#   Decimal('0.8100000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.4300000000'),
#   Decimal('0.5400000000'),
#   'ContentApp',
#   255,
#   500),
#  (256,
#   Decimal('0.4700000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.7600000000'),
#   Decimal('0.0800000000'),
#   Decimal('0.4200000000'),
#   'ContentApp',
#   256,
#   500),
#  (257,
#   Decimal('0.9000000000'),
#   Decimal('0.5000000000'),
#   Decimal('0E-10'),
#   Decimal('0.1500000000'),
#   Decimal('0.3900000000'),
#   'ContentApp',
#   257,
#   500),
#  (258,
#   Decimal('0.1700000000'),
#   Decimal('0.0800000000'),
#   Decimal('0.4000000000'),
#   Decimal('0.1000000000'),
#   Decimal('0.1900000000'),
#   'ContentApp',
#   258,
#   500),
#  (259,
#   Decimal('0.6500000000'),
#   Decimal('0.4000000000'),
#   Decimal('0.2500000000'),
#   Decimal('0.4800000000'),
#   Decimal('0.4400000000'),
#   'ContentApp',
#   259,
#   500),
#  (260,
#   Decimal('0.4600000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.5700000000'),
#   Decimal('0.5500000000'),
#   Decimal('0.6000000000'),
#   'ContentApp',
#   260,
#   500),
#  (261,
#   Decimal('0.2500000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.3900000000'),
#   Decimal('0.4100000000'),
#   Decimal('0.3500000000'),
#   'ContentApp',
#   261,
#   500),
#  (262,
#   Decimal('0.8200000000'),
#   Decimal('0.7000000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.6000000000'),
#   Decimal('0.6100000000'),
#   'ContentApp',
#   262,
#   500),
#  (263,
#   Decimal('0.6300000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.4400000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.4200000000'),
#   'ContentApp',
#   263,
#   500),
#  (264,
#   Decimal('0E-10'),
#   Decimal('0.8200000000'),
#   Decimal('0.8200000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.6300000000'),
#   'ContentApp',
#   264,
#   500),
#  (265,
#   Decimal('0.7100000000'),
#   Decimal('0.6300000000'),
#   Decimal('0.5400000000'),
#   Decimal('0.8800000000'),
#   Decimal('0.6900000000'),
#   'ContentApp',
#   265,
#   500),
#  (266,
#   Decimal('0.5900000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.4000000000'),
#   Decimal('0.3600000000'),
#   'ContentApp',
#   266,
#   500),
#  (267,
#   Decimal('0.1200000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.6300000000'),
#   Decimal('0.3000000000'),
#   'ContentApp',
#   267,
#   500),
#  (268,
#   Decimal('0.5200000000'),
#   Decimal('0.3200000000'),
#   Decimal('0.6400000000'),
#   Decimal('0.3200000000'),
#   Decimal('0.4500000000'),
#   'ContentApp',
#   268,
#   500),
#  (269,
#   Decimal('0.4400000000'),
#   Decimal('0.6300000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.8000000000'),
#   Decimal('0.4800000000'),
#   'ContentApp',
#   269,
#   500),
#  (270,
#   Decimal('0.3400000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.4300000000'),
#   Decimal('0.6500000000'),
#   Decimal('0.3600000000'),
#   'ContentApp',
#   270,
#   500),
#  (271,
#   Decimal('0.2900000000'),
#   Decimal('0.5300000000'),
#   Decimal('0.9000000000'),
#   Decimal('0.3000000000'),
#   Decimal('0.5000000000'),
#   'ContentApp',
#   271,
#   500),
#  (272,
#   Decimal('0.1600000000'),
#   Decimal('0.3900000000'),
#   Decimal('0.6600000000'),
#   Decimal('0.3500000000'),
#   Decimal('0.3900000000'),
#   'ContentApp',
#   272,
#   500),
#  (273,
#   Decimal('0.0500000000'),
#   Decimal('0.1800000000'),
#   Decimal('0.3200000000'),
#   Decimal('0.3900000000'),
#   Decimal('0.2400000000'),
#   'ContentApp',
#   273,
#   500),
#  (274,
#   Decimal('0.5600000000'),
#   Decimal('0.0800000000'),
#   Decimal('0.3300000000'),
#   Decimal('0.1300000000'),
#   Decimal('0.2700000000'),
#   'ContentApp',
#   274,
#   500),
#  (275,
#   Decimal('0.1700000000'),
#   Decimal('0.1700000000'),
#   Decimal('0.0900000000'),
#   Decimal('0.0900000000'),
#   Decimal('0.1300000000'),
#   'ContentApp',
#   275,
#   500),
#  (276,
#   Decimal('0.8400000000'),
#   Decimal('0.3900000000'),
#   Decimal('0.5600000000'),
#   Decimal('0.1100000000'),
#   Decimal('0.4700000000'),
#   'ContentApp',
#   276,
#   500),
#  (277,
#   Decimal('0.1700000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.1400000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.2400000000'),
#   'ContentApp',
#   277,
#   500),
#  (278,
#   Decimal('0.9600000000'),
#   Decimal('0.0600000000'),
#   Decimal('0.5200000000'),
#   Decimal('0.4700000000'),
#   Decimal('0.5000000000'),
#   'ContentApp',
#   278,
#   500),
#  (279,
#   Decimal('0.3700000000'),
#   Decimal('0.1600000000'),
#   Decimal('0.7800000000'),
#   Decimal('0.5500000000'),
#   Decimal('0.4600000000'),
#   'ContentApp',
# ...
#   Decimal('0.6900000000'),
#   Decimal('0.3500000000'),
#   Decimal('0.7100000000'),
#   'couchbase',
#   907,
#   500),
#  (908,
#   Decimal('0.9900000000'),
#   Decimal('0.9800000000'),
#   Decimal('0.5900000000'),
#   Decimal('0.7100000000'),
#   Decimal('0.8100000000'),
#   'couchbase',
#   908,
#   500),
#  (909,
#   Decimal('0.1500000000'),
#   Decimal('0.6700000000'),
#   Decimal('0.8100000000'),
#   Decimal('0.6800000000'),
#   Decimal('0.5800000000'),
#   'couchbase',
#   909,
#   500),
#  (910,
#   Decimal('0.7800000000'),
#   Decimal('0.7000000000'),
#   Decimal('0.2600000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.4400000000'),
#   'couchbase',
#   910,
#   500),
#  (911,
#   Decimal('0.3500000000'),
#   Decimal('0.9700000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.5500000000'),
#   Decimal('0.4800000000'),
#   'couchbase',
#   911,
#   500),
#  (912,
#   Decimal('0E-10'),
#   Decimal('0.7100000000'),
#   Decimal('0.2600000000'),
#   Decimal('0.5100000000'),
#   Decimal('0.3700000000'),
#   'couchbase',
#   912,
#   500),
#  (913,
#   Decimal('0.2700000000'),
#   Decimal('0.7600000000'),
#   Decimal('0.9100000000'),
#   Decimal('0.9700000000'),
#   Decimal('0.7300000000'),
#   'couchbase',
#   913,
#   500),
#  (914,
#   Decimal('0.5200000000'),
#   Decimal('0.3000000000'),
#   Decimal('0.8800000000'),
#   Decimal('0.7000000000'),
#   Decimal('0.6000000000'),
#   'couchbase',
#   914,
#   500),
#  (915,
#   Decimal('0.5200000000'),
#   Decimal('0.7400000000'),
#   Decimal('0.4700000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.4400000000'),
#   'couchbase',
#   915,
#   500),
#  (916,
#   Decimal('0.7000000000'),
#   Decimal('0.6100000000'),
#   Decimal('0.7500000000'),
#   Decimal('0.6600000000'),
#   Decimal('0.6800000000'),
#   'couchbase',
#   916,
#   500),
#  (917,
#   Decimal('0.8300000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.4400000000'),
#   Decimal('0.4200000000'),
#   'couchbase',
#   917,
#   500),
#  (918,
#   Decimal('0.1100000000'),
#   Decimal('0.2700000000'),
#   Decimal('0.6600000000'),
#   Decimal('0.2000000000'),
#   Decimal('0.3100000000'),
#   'couchbase',
#   918,
#   500),
#  (919,
#   Decimal('0.1000000000'),
#   Decimal('0.6200000000'),
#   Decimal('0.2200000000'),
#   Decimal('0.7300000000'),
#   Decimal('0.4200000000'),
#   'couchbase',
#   919,
#   500),
#  (920,
#   Decimal('0.6400000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.4200000000'),
#   'couchbase',
#   920,
#   500),
#  (921,
#   Decimal('0.3100000000'),
#   Decimal('0.7700000000'),
#   Decimal('0.2500000000'),
#   Decimal('0.7000000000'),
#   Decimal('0.5100000000'),
#   'couchbase',
#   921,
#   500),
#  (922,
#   Decimal('0.5000000000'),
#   Decimal('0.1900000000'),
#   Decimal('0.1700000000'),
#   Decimal('0.9700000000'),
#   Decimal('0.4600000000'),
#   'couchbase',
#   922,
#   500),
#  (923,
#   Decimal('0.3000000000'),
#   Decimal('0.4300000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.4600000000'),
#   Decimal('0.5100000000'),
#   'couchbase',
#   923,
#   500),
#  (924,
#   Decimal('0.7000000000'),
#   Decimal('0.2400000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.4000000000'),
#   'couchbase',
#   924,
#   500),
#  (925,
#   Decimal('0.7000000000'),
#   Decimal('0.5400000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.4100000000'),
#   'couchbase',
#   925,
#   500),
#  (926,
#   Decimal('0.2900000000'),
#   Decimal('0.1000000000'),
#   Decimal('0.7500000000'),
#   Decimal('0.1300000000'),
#   Decimal('0.3200000000'),
#   'couchbase',
#   926,
#   500),
#  (927,
#   Decimal('0.5000000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.7500000000'),
#   Decimal('0.5400000000'),
#   'couchbase',
#   927,
#   500),
#  (928,
#   Decimal('0.8000000000'),
#   Decimal('0.5700000000'),
#   Decimal('0.8000000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.5500000000'),
#   'couchbase',
#   928,
#   500),
#  (929,
#   Decimal('0.0200000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.4400000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.3500000000'),
#   'couchbase',
#   929,
#   500),
#  (930,
#   Decimal('0.4700000000'),
#   Decimal('0.6000000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.1000000000'),
#   Decimal('0.5300000000'),
#   'couchbase',
#   930,
#   500),
#  (931,
#   Decimal('0.4500000000'),
#   Decimal('0.4000000000'),
#   Decimal('0.0200000000'),
#   Decimal('0.7200000000'),
#   Decimal('0.4000000000'),
#   'couchbase',
#   931,
#   500),
#  (932,
#   Decimal('0.2600000000'),
#   Decimal('0.5700000000'),
#   Decimal('0.9100000000'),
#   Decimal('0.7200000000'),
#   Decimal('0.6200000000'),
#   'couchbase',
#   932,
#   500),
#  (933,
#   Decimal('0.2500000000'),
#   Decimal('0.1600000000'),
#   Decimal('0.7100000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.4900000000'),
#   'couchbase',
#   933,
#   500),
#  (934,
#   Decimal('0.8900000000'),
#   Decimal('0.5600000000'),
#   Decimal('0.0900000000'),
#   Decimal('0.5100000000'),
#   Decimal('0.5100000000'),
#   'couchbase',
#   934,
#   500),
#  (935,
#   Decimal('0.0500000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.1000000000'),
#   Decimal('0.7900000000'),
#   Decimal('0.4500000000'),
#   'couchbase',
#   935,
#   500),
#  (936,
#   Decimal('0.5000000000'),
#   Decimal('0.2300000000'),
#   Decimal('0.3500000000'),
#   Decimal('0.8100000000'),
#   Decimal('0.4700000000'),
#   'couchbase',
#   936,
#   500),
#  (937,
#   Decimal('0.4100000000'),
#   Decimal('0.1900000000'),
#   Decimal('0.4200000000'),
#   Decimal('0.9100000000'),
#   Decimal('0.4800000000'),
#   'couchbase',
#   937,
#   500),
#  (938,
#   Decimal('0.6900000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.6100000000'),
#   Decimal('0.2800000000'),
#   Decimal('0.5400000000'),
#   'couchbase',
#   938,
#   500),
#  (939,
#   Decimal('0.2800000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.7000000000'),
#   Decimal('0.4900000000'),
#   'couchbase',
#   939,
#   500),
#  (940,
#   Decimal('0.2900000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.3000000000'),
#   Decimal('0.2300000000'),
#   Decimal('0.4100000000'),
#   'couchbase',
#   940,
#   500),
#  (941,
#   Decimal('0.0900000000'),
#   Decimal('0.5300000000'),
#   Decimal('0.3500000000'),
#   Decimal('0.9000000000'),
#   Decimal('0.4700000000'),
#   'couchbase',
#   941,
#   500),
#  (942,
#   Decimal('0.5300000000'),
#   Decimal('0.4700000000'),
#   Decimal('0.8000000000'),
#   Decimal('0.4800000000'),
#   Decimal('0.5700000000'),
#   'couchbase',
#   942,
#   500),
#  (943,
#   Decimal('0.9800000000'),
#   Decimal('0.7700000000'),
#   Decimal('0.3300000000'),
#   Decimal('0.5000000000'),
#   Decimal('0.6400000000'),
#   'couchbase',
#   943,
#   500),
#  (944,
#   Decimal('0.3000000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.1400000000'),
#   Decimal('0.5500000000'),
#   Decimal('0.4600000000'),
#   'couchbase',
#   944,
#   500),
#  (945,
#   Decimal('0.5400000000'),
#   Decimal('0.3200000000'),
#   Decimal('0.7900000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.5000000000'),
#   'couchbase',
#   945,
#   500),
#  (946,
#   Decimal('0.7700000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.3900000000'),
#   Decimal('0.8500000000'),
#   Decimal('0.7200000000'),
#   'couchbase',
#   946,
#   500),
#  (947,
#   Decimal('0.7800000000'),
#   Decimal('0.1100000000'),
#   Decimal('0.4600000000'),
#   Decimal('0.7000000000'),
#   Decimal('0.5200000000'),
#   'couchbase',
#   947,
#   500),
#  (948,
#   Decimal('0.5400000000'),
#   Decimal('0.9300000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.8400000000'),
#   Decimal('0.6500000000'),
#   'couchbase',
#   948,
#   500),
#  (949,
#   Decimal('0.6000000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.3100000000'),
#   Decimal('0.6100000000'),
#   'couchbase',
#   949,
#   500),
#  (950,
#   Decimal('0.4800000000'),
#   Decimal('0.4300000000'),
#   Decimal('0.1000000000'),
#   Decimal('0.0800000000'),
#   Decimal('0.2700000000'),
#   'couchbase',
#   950,
#   500),
#  (951,
#   Decimal('0.6100000000'),
#   Decimal('0.0200000000'),
#   Decimal('0.3800000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.3300000000'),
#   'MongoDB',
#   951,
#   500),
#  (952,
#   Decimal('0.1900000000'),
#   Decimal('0.6100000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.2900000000'),
#   'MongoDB',
#   952,
#   500),
#  (953,
#   Decimal('0.9500000000'),
#   Decimal('0.1600000000'),
#   Decimal('0.0900000000'),
#   Decimal('0.9300000000'),
#   Decimal('0.5300000000'),
#   'MongoDB',
#   953,
#   500),
#  (954,
#   Decimal('0.8800000000'),
#   Decimal('0.0400000000'),
#   Decimal('0.5600000000'),
#   Decimal('0.8400000000'),
#   Decimal('0.5800000000'),
#   'MongoDB',
#   954,
#   500),
#  (955,
#   Decimal('0.5000000000'),
#   Decimal('0.8100000000'),
#   Decimal('0.1300000000'),
#   Decimal('0.2700000000'),
#   Decimal('0.4300000000'),
#   'MongoDB',
#   955,
#   500),
#  (956,
#   Decimal('0.8300000000'),
#   Decimal('0.6700000000'),
#   Decimal('0.2400000000'),
#   Decimal('0.9300000000'),
#   Decimal('0.6700000000'),
#   'MongoDB',
#   956,
#   500),
#  (957,
#   Decimal('0.6300000000'),
#   Decimal('0.1200000000'),
#   Decimal('0.0100000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.4300000000'),
#   'MongoDB',
#   957,
#   500),
#  (958,
#   Decimal('0.0500000000'),
#   Decimal('0.8700000000'),
#   Decimal('0.3800000000'),
#   Decimal('0.1500000000'),
#   Decimal('0.3600000000'),
#   'MongoDB',
#   958,
#   500),
#  (959,
#   Decimal('0.4800000000'),
#   Decimal('0.3300000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.2300000000'),
#   Decimal('0.2700000000'),
#   'MongoDB',
#   959,
#   500),
#  (960,
#   Decimal('0.3100000000'),
#   Decimal('0.4700000000'),
#   Decimal('0.8900000000'),
#   Decimal('1.0000000000'),
#   Decimal('0.6700000000'),
#   'MongoDB',
#   960,
#   500),
#  (961,
#   Decimal('0.2500000000'),
#   Decimal('0.8900000000'),
#   Decimal('0.1300000000'),
#   Decimal('0.9900000000'),
#   Decimal('0.5600000000'),
#   'MongoDB',
#   961,
#   500),
#  (962,
#   Decimal('0.6400000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.3200000000'),
#   Decimal('0.7900000000'),
#   Decimal('0.6400000000'),
#   'MongoDB',
#   962,
#   500),
#  (963,
#   Decimal('0.6600000000'),
#   Decimal('0.4300000000'),
#   Decimal('0.8600000000'),
#   Decimal('0.2300000000'),
#   Decimal('0.5500000000'),
#   'MongoDB',
#   963,
#   500),
#  (964,
#   Decimal('0.5500000000'),
#   Decimal('0.5000000000'),
#   Decimal('0.5700000000'),
#   Decimal('0.1800000000'),
#   Decimal('0.4500000000'),
#   'MongoDB',
#   964,
#   500),
#  (965,
#   Decimal('0.8600000000'),
#   Decimal('0.7800000000'),
#   Decimal('0.8000000000'),
#   Decimal('0.1500000000'),
#   Decimal('0.6400000000'),
#   'MongoDB',
#   965,
#   500),
#  (966,
#   Decimal('0.5300000000'),
#   Decimal('0.2700000000'),
#   Decimal('0.4500000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.4000000000'),
#   'MongoDB',
#   966,
#   500),
#  (967,
#   Decimal('0.1700000000'),
#   Decimal('0.8700000000'),
#   Decimal('0.8700000000'),
#   Decimal('0.3900000000'),
#   Decimal('0.5800000000'),
#   'MongoDB',
#   967,
#   500),
#  (968,
#   Decimal('0.6100000000'),
#   Decimal('0.7100000000'),
#   Decimal('0.3300000000'),
#   Decimal('0.1400000000'),
#   Decimal('0.4500000000'),
#   'MongoDB',
#   968,
#   500),
#  (969,
#   Decimal('0.2100000000'),
#   Decimal('0.9500000000'),
#   Decimal('0.9000000000'),
#   Decimal('0.7100000000'),
#   Decimal('0.7000000000'),
#   'MongoDB',
#   969,
#   500),
#  (970,
#   Decimal('0.5300000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.2500000000'),
#   Decimal('0.5300000000'),
#   Decimal('0.4200000000'),
#   'MongoDB',
#   970,
#   500),
#  (971,
#   Decimal('0.6400000000'),
#   Decimal('0.1900000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.1700000000'),
#   Decimal('0.2600000000'),
#   'MongoDB',
#   971,
#   500),
#  (972,
#   Decimal('0.0700000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.8300000000'),
#   Decimal('0.7800000000'),
#   Decimal('0.4900000000'),
#   'MongoDB',
#   972,
#   500),
#  (973,
#   Decimal('0.3100000000'),
#   Decimal('0.2000000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.2800000000'),
#   Decimal('0.2200000000'),
#   'MongoDB',
#   973,
#   500),
#  (974,
#   Decimal('0.6800000000'),
#   Decimal('0.9000000000'),
#   Decimal('0.1800000000'),
#   Decimal('0.6600000000'),
#   Decimal('0.6000000000'),
#   'MongoDB',
#   974,
#   500),
#  (975,
#   Decimal('0E-10'),
#   Decimal('0.2900000000'),
#   Decimal('0.6200000000'),
#   Decimal('0.0100000000'),
#   Decimal('0.2300000000'),
#   'MongoDB',
#   975,
#   500),
#  (976,
#   Decimal('0.7700000000'),
#   Decimal('0.3700000000'),
#   Decimal('0.3400000000'),
#   Decimal('0.5800000000'),
#   Decimal('0.5100000000'),
#   'MongoDB',
#   976,
#   500),
#  (977,
#   Decimal('0.2800000000'),
#   Decimal('0.8400000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.1500000000'),
#   Decimal('0.4900000000'),
#   'MongoDB',
#   977,
#   500),
#  (978,
#   Decimal('0.4000000000'),
#   Decimal('0.7900000000'),
#   Decimal('0.0100000000'),
#   Decimal('0.7200000000'),
#   Decimal('0.4800000000'),
#   'MongoDB',
#   978,
#   500),
#  (979,
#   Decimal('0.8300000000'),
#   Decimal('0.1400000000'),
#   Decimal('0.5600000000'),
#   Decimal('0.3000000000'),
#   Decimal('0.4600000000'),
#   'MongoDB',
#   979,
#   500),
#  (980,
#   Decimal('0.6700000000'),
#   Decimal('0.2500000000'),
#   Decimal('0.4600000000'),
#   Decimal('0.2000000000'),
#   Decimal('0.3900000000'),
#   'MongoDB',
#   980,
#   500),
#  (981,
#   Decimal('0.9300000000'),
#   Decimal('0.1700000000'),
#   Decimal('0.5700000000'),
#   Decimal('0.4600000000'),
#   Decimal('0.5300000000'),
#   'MongoDB',
#   981,
#   500),
#  (982,
#   Decimal('0.2800000000'),
#   Decimal('0.8900000000'),
#   Decimal('0.5000000000'),
#   Decimal('0.7400000000'),
#   Decimal('0.6000000000'),
#   'MongoDB',
#   982,
#   500),
#  (983,
#   Decimal('0.2400000000'),
#   Decimal('0.3600000000'),
#   Decimal('0.2000000000'),
#   Decimal('0.9000000000'),
#   Decimal('0.4200000000'),
#   'MongoDB',
#   983,
#   500),
#  (984,
#   Decimal('0.7300000000'),
#   Decimal('0.4600000000'),
#   Decimal('0.6000000000'),
#   Decimal('0.4700000000'),
#   Decimal('0.5600000000'),
#   'MongoDB',
#   984,
#   500),
#  (985,
#   Decimal('0.6300000000'),
#   Decimal('0.4400000000'),
#   Decimal('0.6300000000'),
#   Decimal('0.0600000000'),
#   Decimal('0.4400000000'),
#   'MongoDB',
#   985,
#   500),
#  (986,
#   Decimal('0.3300000000'),
#   Decimal('0.0700000000'),
#   Decimal('0.7900000000'),
#   Decimal('0.2500000000'),
#   Decimal('0.3600000000'),
#   'MongoDB',
#   986,
#   500),
#  (987,
#   Decimal('0.3000000000'),
#   Decimal('0.1900000000'),
#   Decimal('0.5000000000'),
#   Decimal('0.1000000000'),
#   Decimal('0.2700000000'),
#   'MongoDB',
#   987,
#   500),
#  (988,
#   Decimal('0.2300000000'),
#   Decimal('0.5100000000'),
#   Decimal('0.1800000000'),
#   Decimal('0.7300000000'),
#   Decimal('0.4100000000'),
#   'MongoDB',
#   988,
#   500),
#  (989,
#   Decimal('0.1300000000'),
#   Decimal('0.2600000000'),
#   Decimal('0.3200000000'),
#   Decimal('0.7600000000'),
#   Decimal('0.3700000000'),
#   'MongoDB',
#   989,
#   500),
#  (990,
#   Decimal('0.6300000000'),
#   Decimal('0E-10'),
#   Decimal('0.0100000000'),
#   Decimal('0.1300000000'),
#   Decimal('0.1900000000'),
#   'MongoDB',
#   990,
#   500),
#  (991,
#   Decimal('0.3000000000'),
#   Decimal('0.6300000000'),
#   Decimal('0.5200000000'),
#   Decimal('0.0400000000'),
#   Decimal('0.3700000000'),
#   'MongoDB',
#   991,
#   500),
#  (992,
#   Decimal('0.4000000000'),
#   Decimal('0.4900000000'),
#   Decimal('0.8500000000'),
#   Decimal('0.6400000000'),
#   Decimal('0.6000000000'),
#   'MongoDB',
#   992,
#   500),
#  (993,
#   Decimal('0.7400000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.5600000000'),
#   Decimal('0.6400000000'),
#   Decimal('0.4900000000'),
#   'MongoDB',
#   993,
#   500),
#  (994,
#   Decimal('0.4400000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.4400000000'),
#   Decimal('0.1100000000'),
#   Decimal('0.2600000000'),
#   'MongoDB',
#   994,
#   500),
#  (995,
#   Decimal('0.1000000000'),
#   Decimal('0.0800000000'),
#   Decimal('0.1600000000'),
#   Decimal('0.3800000000'),
#   Decimal('0.1800000000'),
#   'MongoDB',
#   995,
#   500),
#  (996,
#   Decimal('0.9400000000'),
#   Decimal('0.9600000000'),
#   Decimal('0.1200000000'),
#   Decimal('0.0200000000'),
#   Decimal('0.5100000000'),
#   'MongoDB',
#   996,
#   500),
#  (997,
#   Decimal('0.4500000000'),
#   Decimal('0.9400000000'),
#   Decimal('0.7500000000'),
#   Decimal('0.0500000000'),
#   Decimal('0.5400000000'),
#   'MongoDB',
#   997,
#   500),
#  (998,
#   Decimal('0.4800000000'),
#   Decimal('0.6900000000'),
#   Decimal('0.0300000000'),
#   Decimal('0.7700000000'),
#   Decimal('0.4900000000'),
#   'MongoDB',
#   998,
#   500),
#  (999,
#   Decimal('0.9900000000'),
#   Decimal('0.2400000000'),
#   Decimal('0.2900000000'),
#   Decimal('0.4500000000'),
#   Decimal('0.4900000000'),
#   'MongoDB',
#   999,
#   500),
#  (1000,
#   Decimal('0.9100000000'),
#   Decimal('0.6600000000'),
#   Decimal('0.6400000000'),
#   Decimal('0.5300000000'),
#   Decimal('0.6800000000'),
#   'MongoDB',
#   1000,
#   500),
#  ...]

# %%
cloud_results2 = session.query(Cloudresources_data).all()

# %%
cloud_results2
# Out:
# [<sqlalchemy.ext.automap.cloud_resource_data at 0x22af93885c0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93886a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388710>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93887f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388860>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93888d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93889b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388a20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388b00>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388ba8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388c50>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388cf8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388da0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388e48>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388ef0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9388f98>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1080>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1128>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b11d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1278>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1320>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b13c8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1470>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1518>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b15c0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1668>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1710>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b17b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1860>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1908>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b19b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1a58>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1b00>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1ba8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1c50>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1cc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1d68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1e10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1eb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93b1f60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc0f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc2e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc4e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc6d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc8d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bc978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bca20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bcac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bcb70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bcc18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bccc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bcd68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bce10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bceb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93bcf60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c80f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c82e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c84e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c86d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c88d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8a20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8ac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8b70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8c18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8cc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8d68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8e10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8eb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93c8f60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d50f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d52e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d54e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d56d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d58d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5a20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5ac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5b70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5c18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5cc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5d68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5e10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5eb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93d5f60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e00f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e02e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e04e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e06d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e08d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0a20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0ac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0b70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0c18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0cc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0d68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0e10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0eb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93e0f60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed0f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed2e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed4e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed6d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed8d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ed978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93eda20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93edac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93edb70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93edc18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93edcc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93edd68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93ede10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93edeb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93edf60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f80f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f82e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f84e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f86d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f88d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8a20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8ac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8b70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8c18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8cc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8d68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8e10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8eb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af93f8f60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94050f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94052e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94054e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94056d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94058d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405a20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405ac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405b70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405c18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405cc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405d68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405e10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405eb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9405f60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f0f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f2e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f4e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f6d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f8d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940f978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940fa20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940fac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940fb70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940fc18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940fcc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940fd68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940fe10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940feb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af940ff60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c0f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c2e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c4e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c6d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c8d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941c978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941ca20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941cac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941cb70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941cc18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941ccc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941cd68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941ce10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941ceb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af941cf60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94280f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94282e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94284e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94286d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94288d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428a20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428ac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428b70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428c18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428cc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428d68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428e10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428eb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9428f60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94340f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94342e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94344e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94346d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94348d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434a20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434ac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434b70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434c18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434cc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434d68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434e10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434eb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9434f60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f0f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f2e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f4e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f6d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f8d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943f978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943fa20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943fac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943fb70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943fc18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943fcc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943fd68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943fe10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943feb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af943ff60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b0f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b2e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b4e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b6d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b8d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944b978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944ba20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944bac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944bb70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944bc18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944bcc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944bd68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944be10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944beb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af944bf60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94580f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94582e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94584e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94586d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94588d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458a20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458ac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458b70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458c18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458cc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458d68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458e10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458eb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9458f60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94630f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94632e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94634e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94636d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94638d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463a20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463ac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463b70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463c18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463cc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463d68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463e10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463eb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9463f60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f0f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f2e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f4e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f6d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f8d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946f978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946fa20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946fac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946fb70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946fc18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946fcc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946fd68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946fe10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946feb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af946ff60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b0f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b2e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b4e0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b588>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b630>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b6d8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b780>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b828>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b8d0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947b978>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947ba20>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947bac8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947bb70>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947bc18>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947bcc0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947bd68>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947be10>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947beb8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af947bf60>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488048>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94880f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488198>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488240>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94882e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488390>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9319e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488438>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94884a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94885f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94886a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94887f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94889e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488b38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488be0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488c88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488d30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488dd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488f28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9488fd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94920b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94922b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94924a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94925f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94926a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94927f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94929e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492b38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492be0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492c88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492d30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492dd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492f28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9492fd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a00b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a02b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a04a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a05f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a06a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a07f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a09e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0b38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0be0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0c88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0d30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0dd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0f28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94a0fd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac0b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac2b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac4a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac5f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac6a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac7f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ac9e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94aca90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94acb38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94acbe0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94acc88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94acd30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94acdd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ace80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94acf28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94acfd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b60b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b62b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b64a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b65f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b66a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b67f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b69e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6b38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6be0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6c88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6d30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6dd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6f28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94b6fd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c30b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c32b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c34a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c35f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c36a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c37f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c39e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3b38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3be0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3c88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3d30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3dd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3f28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94c3fd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf0b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf2b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf4a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf5f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf6a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf7f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cf9e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cfa90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cfb38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cfbe0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cfc88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cfd30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cfdd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cfe80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cff28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94cffd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da0b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da2b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da4a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da5f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da6a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da7f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94da9e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94daa90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94dab38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94dabe0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94dac88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94dad30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94dadd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94dae80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94daf28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94dafd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e70b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e72b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e74a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e75f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e76a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e77f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e79e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7b38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7be0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7c88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7d30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7dd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7f28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94e7fd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f30b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f32b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f34a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f35f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f36a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f37f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f39e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3b38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3be0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3c88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3d30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3dd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3f28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94f3fd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff0b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff2b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff4a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff5f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff6a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff7f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ff9e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ffa90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ffb38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ffbe0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ffc88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ffd30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ffdd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94ffe80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94fff28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af94fffd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a0b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a2b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a4a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a5f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a6a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a7f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950a9e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950aa90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950ab38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950abe0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950ac88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950ad30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950add8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950ae80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950af28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af950afd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95160b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95162b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95164a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516550>,
# ...
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95166a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95167f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95169e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516b38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516be0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516c88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516d30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516dd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516f28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9516fd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95220b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95222b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95224a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95225f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95226a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95227f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95229e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522b38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522be0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522c88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522d30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522dd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522f28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9522fd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f0b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f2b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f4a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f5f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f6a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f7f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952f9e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952fa90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952fb38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952fbe0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952fc88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952fd30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952fdd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952fe80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952ff28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af952ffd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a0b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a2b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a4a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a5f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a6a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a7f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953a9e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953aa90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953ab38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953abe0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953ac88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953ad30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953add8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953ae80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953af28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af953afd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95470b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95472b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95474a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95475f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95476a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95477f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95479e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547b38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547be0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547c88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547d30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547dd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547f28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9547fd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95520b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95522b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95524a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95525f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95526a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95527f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95529e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552b38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552be0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552c88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552d30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552dd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552f28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9552fd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d0b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d2b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d4a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d5f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d6a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d7f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955d9e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955da90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955db38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955dbe0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955dc88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955dd30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955ddd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955de80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955df28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af955dfd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95690b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95692b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95694a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95695f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95696a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95697f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95699e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569b38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569be0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569c88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569d30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569dd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569f28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9569fd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95750b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95752b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95754a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95755f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95756a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95757f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95759e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575b38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575be0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575c88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575d30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575dd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575f28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9575fd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95820b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95822b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95824a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95825f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95826a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95827f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af95829e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582a90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582b38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582be0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582c88>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582d30>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582dd8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582e80>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582f28>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af9582fd0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d0b8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d160>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d208>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d2b0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d358>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d400>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d4a8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d550>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d5f8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d6a0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d748>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d7f0>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d898>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d940>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958d9e8>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958da90>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958db38>,
#  <sqlalchemy.ext.automap.cloud_resource_data at 0x22af958dbe0>,
#  ...]

# %%
#raw data from cloud_results query, this is the raw data
cloud_df = pd.DataFrame(cloud_results, columns=['id', 'cpu', 'memory','network','disk','average','app_name','server_id','server_cost'])

cloud_df['cpu'] = pd.to_numeric(cloud_df['cpu'])
cloud_df['memory'] = pd.to_numeric(cloud_df['memory'])
cloud_df['network'] = pd.to_numeric(cloud_df['network'])
cloud_df['disk'] = pd.to_numeric(cloud_df['disk'])
cloud_df['average'] = pd.to_numeric(cloud_df['average'])
cloud_df['server_cost'] = pd.to_numeric(cloud_df['server_cost'])

cloud_df.head()
# Out:
#    id   cpu  memory  network  disk  average    app_name  server_id  \
# 0   1  0.41    0.10     0.49  0.20     0.30  APIGateway          1
# 1   2  0.91    0.52     0.09  0.31     0.46  APIGateway          2
# 2   3  0.72    0.89     0.47  0.44     0.63  APIGateway          3
# 3   4  0.86    0.79     0.83  0.14     0.66  APIGateway          4
# 4   5  0.59    0.21     0.79  0.49     0.52  APIGateway          5
#
#    server_cost
# 0          500
# 1          500
# 2          500
# 3          500
# 4          500

# %%
json_data = json.loads(cloud_df.to_json(orient='records'))

json_data
# Out:
# [{'app_name': 'APIGateway',
#   'average': 0.3,
#   'cpu': 0.41,
#   'disk': 0.2,
#   'id': 1,
#   'memory': 0.1,
#   'network': 0.49,
#   'server_cost': 500,
#   'server_id': 1},
#  {'app_name': 'APIGateway',
#   'average': 0.46,
#   'cpu': 0.91,
#   'disk': 0.31,
#   'id': 2,
#   'memory': 0.52,
#   'network': 0.09,
#   'server_cost': 500,
#   'server_id': 2},
#  {'app_name': 'APIGateway',
#   'average': 0.63,
#   'cpu': 0.72,
#   'disk': 0.44,
#   'id': 3,
#   'memory': 0.89,
#   'network': 0.47,
#   'server_cost': 500,
#   'server_id': 3},
#  {'app_name': 'APIGateway',
#   'average': 0.66,
#   'cpu': 0.86,
#   'disk': 0.14,
#   'id': 4,
#   'memory': 0.79,
#   'network': 0.83,
#   'server_cost': 500,
#   'server_id': 4},
#  {'app_name': 'APIGateway',
#   'average': 0.52,
#   'cpu': 0.59,
#   'disk': 0.49,
#   'id': 5,
#   'memory': 0.21,
#   'network': 0.79,
#   'server_cost': 500,
#   'server_id': 5},
#  {'app_name': 'APIGateway',
#   'average': 0.51,
#   'cpu': 0.3,
#   'disk': 0.84,
#   'id': 6,
#   'memory': 0.74,
#   'network': 0.17,
#   'server_cost': 500,
#   'server_id': 6},
#  {'app_name': 'APIGateway',
#   'average': 0.68,
#   'cpu': 0.82,
#   'disk': 0.87,
#   'id': 7,
#   'memory': 0.66,
#   'network': 0.37,
#   'server_cost': 500,
#   'server_id': 7},
#  {'app_name': 'APIGateway',
#   'average': 0.44,
#   'cpu': 0.62,
#   'disk': 0.75,
#   'id': 8,
#   'memory': 0.34,
#   'network': 0.06,
#   'server_cost': 500,
#   'server_id': 8},
#  {'app_name': 'APIGateway',
#   'average': 0.29,
#   'cpu': 0.07,
#   'disk': 0.11,
#   'id': 9,
#   'memory': 0.84,
#   'network': 0.15,
#   'server_cost': 500,
#   'server_id': 9},
#  {'app_name': 'APIGateway',
#   'average': 0.53,
#   'cpu': 0.47,
#   'disk': 0.84,
#   'id': 10,
#   'memory': 0.12,
#   'network': 0.69,
#   'server_cost': 500,
#   'server_id': 10},
#  {'app_name': 'APIGateway',
#   'average': 0.29,
#   'cpu': 0.25,
#   'disk': 0.59,
#   'id': 11,
#   'memory': 0.27,
#   'network': 0.04,
#   'server_cost': 500,
#   'server_id': 11},
#  {'app_name': 'APIGateway',
#   'average': 0.46,
#   'cpu': 0.1,
#   'disk': 0.62,
#   'id': 12,
#   'memory': 0.67,
#   'network': 0.43,
#   'server_cost': 500,
#   'server_id': 12},
#  {'app_name': 'APIGateway',
#   'average': 0.25,
#   'cpu': 0.17,
#   'disk': 0.05,
#   'id': 13,
#   'memory': 0.09,
#   'network': 0.69,
#   'server_cost': 500,
#   'server_id': 13},
#  {'app_name': 'APIGateway',
#   'average': 0.72,
#   'cpu': 0.43,
#   'disk': 0.68,
#   'id': 14,
#   'memory': 0.86,
#   'network': 0.92,
#   'server_cost': 500,
#   'server_id': 14},
#  {'app_name': 'APIGateway',
#   'average': 0.64,
#   'cpu': 0.99,
#   'disk': 0.65,
#   'id': 15,
#   'memory': 0.55,
#   'network': 0.38,
#   'server_cost': 500,
#   'server_id': 15},
#  {'app_name': 'APIGateway',
#   'average': 0.52,
#   'cpu': 0.63,
#   'disk': 0.39,
#   'id': 16,
#   'memory': 0.79,
#   'network': 0.28,
#   'server_cost': 500,
#   'server_id': 16},
#  {'app_name': 'APIGateway',
#   'average': 0.56,
#   'cpu': 0.78,
#   'disk': 0.21,
#   'id': 17,
#   'memory': 0.98,
#   'network': 0.28,
#   'server_cost': 500,
#   'server_id': 17},
#  {'app_name': 'APIGateway',
#   'average': 0.58,
#   'cpu': 0.86,
#   'disk': 0.37,
#   'id': 18,
#   'memory': 0.19,
#   'network': 0.91,
#   'server_cost': 500,
#   'server_id': 18},
#  {'app_name': 'APIGateway',
#   'average': 0.58,
#   'cpu': 0.61,
#   'disk': 0.96,
#   'id': 19,
#   'memory': 0.37,
#   'network': 0.38,
#   'server_cost': 500,
#   'server_id': 19},
#  {'app_name': 'APIGateway',
#   'average': 0.61,
#   'cpu': 0.72,
#   'disk': 0.88,
#   'id': 20,
#   'memory': 0.55,
#   'network': 0.31,
#   'server_cost': 500,
#   'server_id': 20},
#  {'app_name': 'APIGateway',
#   'average': 0.44,
#   'cpu': 0.64,
#   'disk': 0.69,
#   'id': 21,
#   'memory': 0.04,
#   'network': 0.41,
#   'server_cost': 500,
#   'server_id': 21},
#  {'app_name': 'APIGateway',
#   'average': 0.7,
#   'cpu': 0.85,
#   'disk': 0.39,
#   'id': 22,
#   'memory': 0.69,
#   'network': 0.86,
#   'server_cost': 500,
#   'server_id': 22},
#  {'app_name': 'APIGateway',
#   'average': 0.35,
#   'cpu': 0.52,
#   'disk': 0.3,
#   'id': 23,
#   'memory': 0.01,
#   'network': 0.56,
#   'server_cost': 500,
#   'server_id': 23},
#  {'app_name': 'APIGateway',
#   'average': 0.57,
#   'cpu': 0.66,
#   'disk': 0.92,
#   'id': 24,
#   'memory': 0.36,
#   'network': 0.34,
#   'server_cost': 500,
#   'server_id': 24},
#  {'app_name': 'APIGateway',
#   'average': 0.46,
#   'cpu': 0.57,
#   'disk': 0.83,
#   'id': 25,
#   'memory': 0.27,
#   'network': 0.17,
#   'server_cost': 500,
#   'server_id': 25},
#  {'app_name': 'APIGateway',
#   'average': 0.62,
#   'cpu': 0.45,
#   'disk': 0.95,
#   'id': 26,
#   'memory': 0.26,
#   'network': 0.84,
#   'server_cost': 500,
#   'server_id': 26},
#  {'app_name': 'APIGateway',
#   'average': 0.64,
#   'cpu': 0.93,
#   'disk': 0.96,
#   'id': 27,
#   'memory': 0.31,
#   'network': 0.37,
#   'server_cost': 500,
#   'server_id': 27},
#  {'app_name': 'APIGateway',
#   'average': 0.56,
#   'cpu': 0.42,
#   'disk': 0.66,
#   'id': 28,
#   'memory': 0.71,
#   'network': 0.46,
#   'server_cost': 500,
#   'server_id': 28},
#  {'app_name': 'APIGateway',
#   'average': 0.44,
#   'cpu': 0.11,
#   'disk': 0.41,
#   'id': 29,
#   'memory': 0.6,
#   'network': 0.66,
#   'server_cost': 500,
#   'server_id': 29},
#  {'app_name': 'APIGateway',
#   'average': 0.47,
#   'cpu': 0.62,
#   'disk': 0.25,
#   'id': 30,
#   'memory': 0.42,
#   'network': 0.57,
#   'server_cost': 500,
#   'server_id': 30},
#  {'app_name': 'APIGateway',
#   'average': 0.31,
#   'cpu': 0.26,
#   'disk': 0.06,
#   'id': 31,
#   'memory': 0.51,
#   'network': 0.42,
#   'server_cost': 500,
#   'server_id': 31},
#  {'app_name': 'APIGateway',
#   'average': 0.66,
#   'cpu': 0.43,
#   'disk': 0.48,
#   'id': 32,
#   'memory': 0.75,
#   'network': 0.99,
#   'server_cost': 500,
#   'server_id': 32},
#  {'app_name': 'APIGateway',
#   'average': 0.57,
#   'cpu': 0.64,
#   'disk': 0.61,
#   'id': 33,
#   'memory': 0.16,
#   'network': 0.89,
#   'server_cost': 500,
#   'server_id': 33},
#  {'app_name': 'APIGateway',
#   'average': 0.3,
#   'cpu': 0.73,
#   'disk': 0.17,
#   'id': 34,
#   'memory': 0.07,
#   'network': 0.2,
#   'server_cost': 500,
#   'server_id': 34},
#  {'app_name': 'APIGateway',
#   'average': 0.32,
#   'cpu': 0.11,
#   'disk': 0.29,
#   'id': 35,
#   'memory': 0.51,
#   'network': 0.37,
#   'server_cost': 500,
#   'server_id': 35},
#  {'app_name': 'APIGateway',
#   'average': 0.48,
#   'cpu': 0.31,
#   'disk': 0.6,
#   'id': 36,
#   'memory': 0.35,
#   'network': 0.64,
#   'server_cost': 500,
#   'server_id': 36},
#  {'app_name': 'APIGateway',
#   'average': 0.38,
#   'cpu': 0.86,
#   'disk': 0.53,
#   'id': 37,
#   'memory': 0.13,
#   'network': 0.01,
#   'server_cost': 500,
#   'server_id': 37},
#  {'app_name': 'APIGateway',
#   'average': 0.62,
#   'cpu': 0.85,
#   'disk': 0.96,
#   'id': 38,
#   'memory': 0.34,
#   'network': 0.32,
#   'server_cost': 500,
#   'server_id': 38},
#  {'app_name': 'APIGateway',
#   'average': 0.35,
#   'cpu': 0.41,
#   'disk': 0.64,
#   'id': 39,
#   'memory': 0.33,
#   'network': 0.02,
#   'server_cost': 500,
#   'server_id': 39},
#  {'app_name': 'Encryption',
#   'average': 0.34,
#   'cpu': 0.63,
#   'disk': 0.19,
#   'id': 40,
#   'memory': 0.21,
#   'network': 0.33,
#   'server_cost': 500,
#   'server_id': 40},
#  {'app_name': 'Encryption',
#   'average': 0.24,
#   'cpu': 0.01,
#   'disk': 0.29,
#   'id': 41,
#   'memory': 0.01,
#   'network': 0.64,
#   'server_cost': 500,
#   'server_id': 41},
#  {'app_name': 'Encryption',
#   'average': 0.46,
#   'cpu': 0.82,
#   'disk': 0.29,
#   'id': 42,
#   'memory': 0.58,
#   'network': 0.14,
#   'server_cost': 500,
#   'server_id': 42},
#  {'app_name': 'Encryption',
#   'average': 0.48,
#   'cpu': 0.37,
#   'disk': 0.04,
#   'id': 43,
#   'memory': 0.55,
#   'network': 0.98,
#   'server_cost': 500,
#   'server_id': 43},
#  {'app_name': 'Encryption',
#   'average': 0.48,
#   'cpu': 0.71,
#   'disk': 0.07,
#   'id': 44,
#   'memory': 0.54,
#   'network': 0.61,
#   'server_cost': 500,
#   'server_id': 44},
#  {'app_name': 'Encryption',
#   'average': 0.65,
#   'cpu': 0.35,
#   'disk': 0.87,
#   'id': 45,
#   'memory': 0.4,
#   'network': 0.97,
#   'server_cost': 500,
#   'server_id': 45},
#  {'app_name': 'Encryption',
#   'average': 0.52,
#   'cpu': 0.7,
#   'disk': 0.05,
#   'id': 46,
#   'memory': 0.97,
#   'network': 0.37,
#   'server_cost': 500,
#   'server_id': 46},
#  {'app_name': 'Encryption',
#   'average': 0.64,
#   'cpu': 0.62,
#   'disk': 0.27,
#   'id': 47,
#   'memory': 0.72,
#   'network': 0.95,
#   'server_cost': 500,
#   'server_id': 47},
#  {'app_name': 'Encryption',
#   'average': 0.79,
#   'cpu': 0.87,
#   'disk': 0.88,
#   'id': 48,
#   'memory': 0.55,
#   'network': 0.87,
#   'server_cost': 500,
#   'server_id': 48},
#  {'app_name': 'Encryption',
#   'average': 0.23,
#   'cpu': 0.21,
#   'disk': 0.21,
#   'id': 49,
#   'memory': 0.45,
#   'network': 0.05,
#   'server_cost': 500,
#   'server_id': 49},
#  {'app_name': 'Encryption',
#   'average': 0.7,
#   'cpu': 0.87,
#   'disk': 0.6,
#   'id': 50,
#   'memory': 0.78,
#   'network': 0.56,
#   'server_cost': 500,
#   'server_id': 50},
#  {'app_name': 'Encryption',
#   'average': 0.52,
#   'cpu': 0.77,
#   'disk': 0.61,
#   'id': 51,
#   'memory': 0.37,
#   'network': 0.31,
#   'server_cost': 500,
#   'server_id': 51},
#  {'app_name': 'Encryption',
#   'average': 0.43,
#   'cpu': 0.11,
#   'disk': 0.94,
#   'id': 52,
#   'memory': 0.44,
#   'network': 0.24,
#   'server_cost': 500,
#   'server_id': 52},
#  {'app_name': 'Encryption',
#   'average': 0.4,
#   'cpu': 0.22,
#   'disk': 0.13,
#   'id': 53,
#   'memory': 0.32,
#   'network': 0.92,
#   'server_cost': 500,
#   'server_id': 53},
#  {'app_name': 'Encryption',
#   'average': 0.24,
#   'cpu': 0.09,
#   'disk': 0.58,
#   'id': 54,
#   'memory': 0.12,
#   'network': 0.17,
#   'server_cost': 500,
#   'server_id': 54},
#  {'app_name': 'Encryption',
#   'average': 0.55,
#   'cpu': 0.87,
#   'disk': 0.41,
#   'id': 55,
#   'memory': 0.52,
#   'network': 0.41,
#   'server_cost': 500,
#   'server_id': 55},
#  {'app_name': 'Encryption',
#   'average': 0.63,
#   'cpu': 0.55,
#   'disk': 0.86,
#   'id': 56,
#   'memory': 0.48,
#   'network': 0.63,
#   'server_cost': 500,
#   'server_id': 56},
#  {'app_name': 'Encryption',
#   'average': 0.74,
#   'cpu': 0.62,
#   'disk': 0.79,
#   'id': 57,
#   'memory': 0.83,
#   'network': 0.72,
#   'server_cost': 500,
#   'server_id': 57},
#  {'app_name': 'Encryption',
#   'average': 0.36,
#   'cpu': 0.48,
#   'disk': 0.04,
#   'id': 58,
#   'memory': 0.36,
#   'network': 0.55,
#   'server_cost': 500,
#   'server_id': 58},
#  {'app_name': 'Encryption',
#   'average': 0.59,
#   'cpu': 0.14,
#   'disk': 0.86,
#   'id': 59,
#   'memory': 0.62,
#   'network': 0.73,
#   'server_cost': 500,
#   'server_id': 59},
#  {'app_name': 'Encryption',
#   'average': 0.46,
#   'cpu': 0.5,
#   'disk': 0.66,
#   'id': 60,
#   'memory': 0.16,
#   'network': 0.5,
#   'server_cost': 500,
#   'server_id': 60},
#  {'app_name': 'Encryption',
#   'average': 0.55,
#   'cpu': 0.91,
#   'disk': 0.28,
#   'id': 61,
#   'memory': 0.64,
#   'network': 0.37,
#   'server_cost': 500,
#   'server_id': 61},
#  {'app_name': 'Encryption',
#   'average': 0.47,
#   'cpu': 0.19,
#   'disk': 0.72,
#   'id': 62,
#   'memory': 0.17,
#   'network': 0.8,
#   'server_cost': 500,
#   'server_id': 62},
#  {'app_name': 'Encryption',
#   'average': 0.48,
#   'cpu': 0.47,
#   'disk': 0.49,
#   'id': 63,
#   'memory': 0.52,
#   'network': 0.43,
#   'server_cost': 500,
#   'server_id': 63},
#  {'app_name': 'Encryption',
#   'average': 0.5,
#   'cpu': 0.14,
#   'disk': 0.58,
#   'id': 64,
#   'memory': 0.35,
#   'network': 0.93,
#   'server_cost': 500,
#   'server_id': 64},
#  {'app_name': 'Encryption',
#   'average': 0.49,
#   'cpu': 0.1,
#   'disk': 0.57,
#   'id': 65,
#   'memory': 0.41,
#   'network': 0.89,
#   'server_cost': 500,
#   'server_id': 65},
#  {'app_name': 'Encryption',
#   'average': 0.32,
#   'cpu': 0.28,
#   'disk': 0.42,
#   'id': 66,
#   'memory': 0.52,
#   'network': 0.08,
#   'server_cost': 500,
#   'server_id': 66},
#  {'app_name': 'Encryption',
#   'average': 0.73,
#   'cpu': 0.94,
#   'disk': 0.31,
#   'id': 67,
#   'memory': 1.0,
#   'network': 0.69,
#   'server_cost': 500,
#   'server_id': 67},
#  {'app_name': 'Encryption',
#   'average': 0.78,
#   'cpu': 0.99,
#   'disk': 0.7,
#   'id': 68,
#   'memory': 0.78,
#   'network': 0.66,
#   'server_cost': 500,
#   'server_id': 68},
#  {'app_name': 'Encryption',
#   'average': 0.72,
#   'cpu': 0.62,
#   'disk': 0.95,
#   'id': 69,
#   'memory': 0.41,
#   'network': 0.89,
#   'server_cost': 500,
#   'server_id': 69},
#  {'app_name': 'Encryption',
#   'average': 0.4,
#   'cpu': 0.98,
#   'disk': 0.24,
#   'id': 70,
#   'memory': 0.11,
#   'network': 0.26,
#   'server_cost': 500,
#   'server_id': 70},
#  {'app_name': 'Encryption',
#   'average': 0.27,
#   'cpu': 0.22,
#   'disk': 0.77,
#   'id': 71,
#   'memory': 0.01,
#   'network': 0.07,
#   'server_cost': 500,
#   'server_id': 71},
#  {'app_name': 'Encryption',
#   'average': 0.65,
#   'cpu': 0.43,
#   'disk': 0.97,
#   'id': 72,
#   'memory': 0.75,
#   'network': 0.45,
#   'server_cost': 500,
#   'server_id': 72},
#  {'app_name': 'Encryption',
#   'average': 0.51,
#   'cpu': 0.6,
#   'disk': 0.3,
#   'id': 73,
#   'memory': 0.8,
#   'network': 0.35,
#   'server_cost': 500,
#   'server_id': 73},
#  {'app_name': 'Encryption',
#   'average': 0.11,
#   'cpu': 0.24,
#   'disk': 0.04,
#   'id': 74,
#   'memory': 0.08,
#   'network': 0.07,
#   'server_cost': 500,
#   'server_id': 74},
#  {'app_name': 'Encryption',
#   'average': 0.36,
#   'cpu': 0.04,
#   'disk': 0.6,
#   'id': 75,
#   'memory': 0.3,
#   'network': 0.52,
#   'server_cost': 500,
#   'server_id': 75},
#  {'app_name': 'Encryption',
#   'average': 0.24,
#   'cpu': 0.22,
#   'disk': 0.32,
#   'id': 76,
#   'memory': 0.12,
#   'network': 0.29,
#   'server_cost': 500,
#   'server_id': 76},
#  {'app_name': 'Encryption',
#   'average': 0.34,
#   'cpu': 0.22,
#   'disk': 0.16,
#   'id': 77,
#   'memory': 0.61,
#   'network': 0.39,
#   'server_cost': 500,
#   'server_id': 77},
#  {'app_name': 'Encryption',
#   'average': 0.27,
#   'cpu': 0.16,
#   'disk': 0.64,
#   'id': 78,
#   'memory': 0.26,
#   'network': 0.03,
#   'server_cost': 500,
#   'server_id': 78},
#  {'app_name': 'Encryption',
#   'average': 0.63,
#   'cpu': 0.77,
#   'disk': 0.39,
#   'id': 79,
#   'memory': 0.66,
#   'network': 0.68,
#   'server_cost': 500,
#   'server_id': 79},
#  {'app_name': 'Encryption',
#   'average': 0.33,
#   'cpu': 0.78,
#   'disk': 0.24,
#   'id': 80,
#   'memory': 0.15,
#   'network': 0.17,
#   'server_cost': 500,
#   'server_id': 80},
#  {'app_name': 'Encryption',
#   'average': 0.7,
#   'cpu': 0.89,
#   'disk': 0.96,
#   'id': 81,
#   'memory': 0.34,
#   'network': 0.6,
#   'server_cost': 500,
#   'server_id': 81},
#  {'app_name': 'Encryption',
#   'average': 0.73,
#   'cpu': 0.37,
#   'disk': 0.89,
#   'id': 82,
#   'memory': 0.68,
#   'network': 0.96,
#   'server_cost': 500,
#   'server_id': 82},
#  {'app_name': 'Encryption',
#   'average': 0.25,
#   'cpu': 0.31,
#   'disk': 0.24,
#   'id': 83,
#   'memory': 0.25,
#   'network': 0.21,
#   'server_cost': 500,
#   'server_id': 83},
#  {'app_name': 'Encryption',
#   'average': 0.4,
#   'cpu': 0.8,
#   'disk': 0.24,
#   'id': 84,
#   'memory': 0.19,
#   'network': 0.37,
#   'server_cost': 500,
#   'server_id': 84},
#  {'app_name': 'Encryption',
#   'average': 0.47,
#   'cpu': 0.34,
#   'disk': 0.79,
#   'id': 85,
#   'memory': 0.35,
#   'network': 0.42,
#   'server_cost': 500,
#   'server_id': 85},
#  {'app_name': 'Encryption',
#   'average': 0.48,
#   'cpu': 0.35,
#   'disk': 0.41,
#   'id': 86,
#   'memory': 0.86,
#   'network': 0.28,
#   'server_cost': 500,
#   'server_id': 86},
#  {'app_name': 'Encryption',
#   'average': 0.27,
#   'cpu': 0.01,
#   'disk': 0.1,
#   'id': 87,
#   'memory': 0.02,
#   'network': 0.96,
#   'server_cost': 500,
#   'server_id': 87},
#  {'app_name': 'Encryption',
#   'average': 0.22,
#   'cpu': 0.05,
#   'disk': 0.47,
#   'id': 88,
#   'memory': 0.31,
#   'network': 0.06,
#   'server_cost': 500,
#   'server_id': 88},
#  {'app_name': 'Encryption',
#   'average': 0.6,
#   'cpu': 0.33,
#   'disk': 0.55,
#   'id': 89,
#   'memory': 0.54,
#   'network': 0.98,
#   'server_cost': 500,
#   'server_id': 89},
#  {'app_name': 'Encryption',
#   'average': 0.42,
#   'cpu': 0.32,
#   'disk': 0.88,
#   'id': 90,
#   'memory': 0.46,
#   'network': 0.04,
#   'server_cost': 500,
#   'server_id': 90},
#  {'app_name': 'Encryption',
#   'average': 0.4,
#   'cpu': 0.21,
#   'disk': 0.5,
#   'id': 91,
#   'memory': 0.16,
#   'network': 0.72,
#   'server_cost': 500,
#   'server_id': 91},
#  {'app_name': 'Encryption',
#   'average': 0.48,
#   'cpu': 0.41,
#   'disk': 0.82,
#   'id': 92,
#   'memory': 0.39,
#   'network': 0.3,
#   'server_cost': 500,
#   'server_id': 92},
#  {'app_name': 'Encryption',
#   'average': 0.19,
#   'cpu': 0.16,
#   'disk': 0.37,
#   'id': 93,
#   'memory': 0.06,
#   'network': 0.18,
#   'server_cost': 500,
#   'server_id': 93},
#  {'app_name': 'Encryption',
#   'average': 0.7,
#   'cpu': 0.43,
#   'disk': 0.76,
#   'id': 94,
#   'memory': 0.82,
#   'network': 0.78,
#   'server_cost': 500,
#   'server_id': 94},
#  {'app_name': 'Encryption',
#   'average': 0.54,
#   'cpu': 0.86,
#   'disk': 0.03,
#   'id': 95,
#   'memory': 0.35,
#   'network': 0.92,
#   'server_cost': 500,
#   'server_id': 95},
#  {'app_name': 'Encryption',
#   'average': 0.28,
#   'cpu': 0.21,
#   'disk': 0.01,
#   'id': 96,
#   'memory': 0.66,
#   'network': 0.23,
#   'server_cost': 500,
#   'server_id': 96},
#  {'app_name': 'Encryption',
#   'average': 0.61,
#   'cpu': 0.45,
#   'disk': 0.71,
#   'id': 97,
#   'memory': 0.97,
#   'network': 0.32,
#   'server_cost': 500,
#   'server_id': 97},
#  {'app_name': 'Encryption',
#   'average': 0.66,
#   'cpu': 0.93,
#   'disk': 0.0,
#   'id': 98,
#   'memory': 0.72,
#   'network': 0.99,
#   'server_cost': 500,
#   'server_id': 98},
#  {'app_name': 'Encryption',
#   'average': 0.78,
#   'cpu': 0.61,
#   'disk': 0.87,
#   'id': 99,
#   'memory': 0.88,
#   'network': 0.77,
#   'server_cost': 500,
#   'server_id': 99},
#  {'app_name': 'Encryption',
#   'average': 0.67,
#   'cpu': 0.94,
#   'disk': 0.71,
#   'id': 100,
#   'memory': 0.3,
#   'network': 0.72,
#   'server_cost': 500,
#   'server_id': 100},
#  {'app_name': 'Encryption',
#   'average': 0.45,
#   'cpu': 0.36,
#   'disk': 0.44,
#   'id': 101,
#   'memory': 0.45,
#   'network': 0.54,
#   'server_cost': 500,
#   'server_id': 101},
#  {'app_name': 'Encryption',
#   'average': 0.22,
#   'cpu': 0.03,
#   'disk': 0.03,
#   'id': 102,
#   'memory': 0.67,
#   'network': 0.15,
#   'server_cost': 500,
#   'server_id': 102},
#  {'app_name': 'Encryption',
#   'average': 0.61,
#   'cpu': 0.76,
#   'disk': 0.14,
#   'id': 103,
#   'memory': 0.8,
#   'network': 0.75,
#   'server_cost': 500,
#   'server_id': 103},
#  {'app_name': 'Encryption',
#   'average': 0.43,
#   'cpu': 0.57,
#   'disk': 0.33,
#   'id': 104,
#   'memory': 0.04,
#   'network': 0.78,
#   'server_cost': 500,
#   'server_id': 104},
#  {'app_name': 'Encryption',
#   'average': 0.32,
#   'cpu': 0.26,
#   'disk': 0.17,
#   'id': 105,
#   'memory': 0.4,
#   'network': 0.45,
#   'server_cost': 500,
#   'server_id': 105},
#  {'app_name': 'Encryption',
#   'average': 0.57,
#   'cpu': 0.16,
#   'disk': 0.69,
#   'id': 106,
#   'memory': 0.49,
#   'network': 0.94,
#   'server_cost': 500,
#   'server_id': 106},
#  {'app_name': 'Encryption',
#   'average': 0.43,
#   'cpu': 0.73,
#   'disk': 0.16,
#   'id': 107,
#   'memory': 0.7,
#   'network': 0.14,
#   'server_cost': 500,
#   'server_id': 107},
#  {'app_name': 'Encryption',
#   'average': 0.45,
#   'cpu': 0.44,
#   'disk': 0.8,
#   'id': 108,
#   'memory': 0.37,
#   'network': 0.18,
#   'server_cost': 500,
#   'server_id': 108},
#  {'app_name': 'Encryption',
#   'average': 0.4,
#   'cpu': 0.24,
#   'disk': 0.78,
#   'id': 109,
#   'memory': 0.28,
#   'network': 0.31,
#   'server_cost': 500,
#   'server_id': 109},
#  {'app_name': 'Encryption',
#   'average': 0.62,
#   'cpu': 0.88,
#   'disk': 0.65,
#   'id': 110,
#   'memory': 0.64,
#   'network': 0.3,
#   'server_cost': 500,
#   'server_id': 110},
#  {'app_name': 'Encryption',
#   'average': 0.55,
#   'cpu': 0.7,
#   'disk': 0.87,
#   'id': 111,
#   'memory': 0.14,
#   'network': 0.5,
#   'server_cost': 500,
#   'server_id': 111},
#  {'app_name': 'Encryption',
#   'average': 0.23,
#   'cpu': 0.02,
#   'disk': 0.47,
#   'id': 112,
#   'memory': 0.04,
#   'network': 0.38,
#   'server_cost': 500,
#   'server_id': 112},
#  {'app_name': 'Encryption',
#   'average': 0.28,
#   'cpu': 0.73,
#   'disk': 0.14,
#   'id': 113,
#   'memory': 0.06,
#   'network': 0.19,
#   'server_cost': 500,
#   'server_id': 113},
#  {'app_name': 'Encryption',
#   'average': 0.6,
#   'cpu': 0.21,
#   'disk': 0.54,
#   'id': 114,
#   'memory': 0.92,
#   'network': 0.74,
#   'server_cost': 500,
#   'server_id': 114},
#  {'app_name': 'Encryption',
#   'average': 0.43,
#   'cpu': 0.56,
#   'disk': 0.56,
#   'id': 115,
#   'memory': 0.36,
#   'network': 0.24,
#   'server_cost': 500,
#   'server_id': 115},
#  {'app_name': 'Encryption',
#   'average': 0.34,
#   'cpu': 0.64,
#   'disk': 0.23,
#   'id': 116,
#   'memory': 0.08,
#   'network': 0.41,
#   'server_cost': 500,
#   'server_id': 116},
#  {'app_name': 'Encryption',
#   'average': 0.5,
#   'cpu': 0.81,
#   'disk': 0.16,
#   'id': 117,
#   'memory': 0.27,
#   'network': 0.78,
#   'server_cost': 500,
#   'server_id': 117},
#  {'app_name': 'Encryption',
#   'average': 0.57,
#   'cpu': 0.92,
#   'disk': 0.17,
#   'id': 118,
#   'memory': 0.9,
#   'network': 0.3,
#   'server_cost': 500,
#   'server_id': 118},
#  {'app_name': 'Encryption',
#   'average': 0.55,
#   'cpu': 0.49,
#   'disk': 0.99,
#   'id': 119,
#   'memory': 0.37,
#   'network': 0.34,
#   'server_cost': 500,
#   'server_id': 119},
#  {'app_name': 'Encryption',
#   'average': 0.63,
#   'cpu': 0.67,
#   'disk': 0.68,
#   'id': 120,
#   'memory': 0.68,
#   'network': 0.5,
#   'server_cost': 500,
#   'server_id': 120},
#  {'app_name': 'Encryption',
#   'average': 0.13,
#   'cpu': 0.0,
#   'disk': 0.11,
#   'id': 121,
#   'memory': 0.33,
#   'network': 0.07,
#   'server_cost': 500,
#   'server_id': 121},
#  {'app_name': 'Encryption',
#   'average': 0.45,
#   'cpu': 0.1,
#   'disk': 0.16,
#   'id': 122,
#   'memory': 0.7,
#   'network': 0.83,
#   'server_cost': 500,
#   'server_id': 122},
#  {'app_name': 'Encryption',
#   'average': 0.36,
#   'cpu': 0.98,
#   'disk': 0.05,
#   'id': 123,
#   'memory': 0.3,
#   'network': 0.12,
#   'server_cost': 500,
#   'server_id': 123},
#  {'app_name': 'Encryption',
#   'average': 0.56,
#   'cpu': 0.52,
#   'disk': 0.43,
#   'id': 124,
#   'memory': 0.98,
#   'network': 0.29,
#   'server_cost': 500,
#   'server_id': 124},
#  {'app_name': 'Encryption',
#   'average': 0.44,
#   'cpu': 0.33,
#   'disk': 0.4,
#   'id': 125,
#   'memory': 0.44,
#   'network': 0.57,
#   'server_cost': 500,
#   'server_id': 125},
#  {'app_name': 'Encryption',
#   'average': 0.35,
#   'cpu': 0.56,
#   'disk': 0.37,
#   'id': 126,
#   'memory': 0.23,
#   'network': 0.22,
#   'server_cost': 500,
#   'server_id': 126},
#  {'app_name': 'Encryption',
#   'average': 0.42,
#   'cpu': 0.8,
#   'disk': 0.09,
#   'id': 127,
#   'memory': 0.69,
#   'network': 0.1,
#   'server_cost': 500,
#   'server_id': 127},
#  {'app_name': 'Encryption',
#   'average': 0.63,
#   'cpu': 0.34,
#   'disk': 0.71,
#   'id': 128,
#   'memory': 0.78,
#   'network': 0.69,
#   'server_cost': 500,
#   'server_id': 128},
#  {'app_name': 'Encryption',
#   'average': 0.71,
#   'cpu': 0.49,
#   'disk': 0.97,
#   'id': 129,
#   'memory': 0.92,
#   'network': 0.44,
#   'server_cost': 500,
#   'server_id': 129},
#  {'app_name': 'Encryption',
#   'average': 0.5,
#   'cpu': 0.88,
#   'disk': 0.49,
#   'id': 130,
#   'memory': 0.04,
#   'network': 0.6,
#   'server_cost': 500,
#   'server_id': 130},
#  {'app_name': 'Encryption',
#   'average': 0.48,
#   'cpu': 0.16,
#   'disk': 0.93,
#   'id': 131,
#   'memory': 0.51,
#   'network': 0.33,
#   'server_cost': 500,
#   'server_id': 131},
#  {'app_name': 'Encryption',
#   'average': 0.36,
#   'cpu': 0.13,
#   'disk': 0.49,
#   'id': 132,
#   'memory': 0.2,
#   'network': 0.63,
#   'server_cost': 500,
#   'server_id': 132},
#  {'app_name': 'Encryption',
#   'average': 0.55,
#   'cpu': 0.83,
#   'disk': 0.19,
#   'id': 133,
#   'memory': 0.49,
#   'network': 0.69,
#   'server_cost': 500,
#   'server_id': 133},
#  {'app_name': 'Encryption',
#   'average': 0.59,
#   'cpu': 0.57,
#   'disk': 0.22,
#   'id': 134,
#   'memory': 0.91,
#   'network': 0.65,
#   'server_cost': 500,
#   'server_id': 134},
#  {'app_name': 'Encryption',
#   'average': 0.48,
#   'cpu': 0.74,
#   'disk': 0.05,
#   'id': 135,
#   'memory': 0.45,
#   'network': 0.69,
#   'server_cost': 500,
#   'server_id': 135},
#  {'app_name': 'Encryption',
#   'average': 0.42,
#   'cpu': 0.71,
#   'disk': 0.28,
#   'id': 136,
#   'memory': 0.37,
#   'network': 0.31,
#   'server_cost': 500,
#   'server_id': 136},
#  {'app_name': 'Encryption',
#   'average': 0.5,
#   'cpu': 0.1,
#   'disk': 0.43,
#   'id': 137,
#   'memory': 0.7,
#   'network': 0.78,
#   'server_cost': 500,
#   'server_id': 137},
#  {'app_name': 'Encryption',
#   'average': 0.38,
#   'cpu': 0.63,
#   'disk': 0.16,
#   'id': 138,
#   'memory': 0.58,
#   'network': 0.14,
#   'server_cost': 500,
#   'server_id': 138},
#  {'app_name': 'Encryption',
#   'average': 0.42,
#   'cpu': 0.21,
#   'disk': 0.43,
#   'id': 139,
#   'memory': 0.25,
#   'network': 0.8,
#   'server_cost': 500,
#   'server_id': 139},
#  {'app_name': 'Encryption',
#   'average': 0.42,
#   'cpu': 0.31,
#   'disk': 0.07,
#   'id': 140,
#   'memory': 0.7,
#   'network': 0.58,
#   'server_cost': 500,
#   'server_id': 140},
#  {'app_name': 'Encryption',
#   'average': 0.56,
#   'cpu': 0.43,
#   'disk': 0.88,
#   'id': 141,
#   'memory': 0.21,
#   'network': 0.71,
#   'server_cost': 500,
#   'server_id': 141},
#  {'app_name': 'Encryption',
#   'average': 0.49,
#   'cpu': 0.75,
#   'disk': 0.44,
#   'id': 142,
#   'memory': 0.25,
#   'network': 0.54,
#   'server_cost': 500,
#   'server_id': 142},
#  {'app_name': 'Encryption',
#   'average': 0.58,
#   'cpu': 0.93,
#   'disk': 0.36,
#   'id': 143,
#   'memory': 0.79,
#   'network': 0.24,
#   'server_cost': 500,
#   'server_id': 143},
#  {'app_name': 'Encryption',
#   'average': 0.69,
#   'cpu': 0.52,
#   'disk': 0.57,
#   'id': 144,
#   'memory': 0.85,
#   'network': 0.83,
#   'server_cost': 500,
#   'server_id': 144},
#  {'app_name': 'Encryption',
#   'average': 0.64,
#   'cpu': 0.93,
#   'disk': 0.98,
#   'id': 145,
#   'memory': 0.53,
#   'network': 0.1,
#   'server_cost': 500,
#   'server_id': 145},
#  {'app_name': 'Encryption',
#   'average': 0.53,
#   'cpu': 0.66,
#   'disk': 0.36,
#   'id': 146,
#   'memory': 0.81,
#   'network': 0.27,
#   'server_cost': 500,
#   'server_id': 146},
#  {'app_name': 'Encryption',
#   'average': 0.43,
#   'cpu': 0.09,
#   'disk': 0.69,
#   'id': 147,
#   'memory': 0.03,
#   'network': 0.89,
#   'server_cost': 500,
#   'server_id': 147},
#  {'app_name': 'Encryption',
#   'average': 0.4,
#   'cpu': 0.6,
#   'disk': 0.21,
#   'id': 148,
#   'memory': 0.63,
#   'network': 0.14,
#   'server_cost': 500,
#   'server_id': 148},
#  {'app_name': 'Encryption',
#   'average': 0.53,
#   'cpu': 0.93,
#   'disk': 0.79,
#   'id': 149,
#   'memory': 0.37,
#   'network': 0.01,
#   'server_cost': 500,
#   'server_id': 149},
#  {'app_name': 'Encryption',
#   'average': 0.71,
#   'cpu': 0.96,
#   'disk': 0.88,
#   'id': 150,
#   'memory': 0.78,
#   'network': 0.22,
#   'server_cost': 500,
#   'server_id': 150},
#  {'app_name': 'Encryption',
#   'average': 0.72,
#   'cpu': 0.69,
#   'disk': 1.0,
#   'id': 151,
#   'memory': 0.89,
#   'network': 0.31,
#   'server_cost': 500,
#   'server_id': 151},
#  {'app_name': 'Encryption',
#   'average': 0.54,
#   'cpu': 0.31,
#   'disk': 0.86,
#   'id': 152,
#   'memory': 0.93,
#   'network': 0.05,
#   'server_cost': 500,
#   'server_id': 152},
#  {'app_name': 'Encryption',
#   'average': 0.36,
#   'cpu': 0.35,
#   'disk': 0.55,
#   'id': 153,
#   'memory': 0.08,
#   'network': 0.48,
#   'server_cost': 500,
#   'server_id': 153},
#  {'app_name': 'Encryption',
#   'average': 0.33,
#   'cpu': 0.14,
#   'disk': 0.21,
#   'id': 154,
#   'memory': 0.4,
#   'network': 0.57,
#   'server_cost': 500,
#   'server_id': 154},
#  {'app_name': 'Encryption',
#   'average': 0.49,
#   'cpu': 0.66,
#   'disk': 0.4,
#   'id': 155,
#   'memory': 0.48,
#   'network': 0.41,
#   'server_cost': 500,
#   'server_id': 155},
#  {'app_name': 'Encryption',
#   'average': 0.15,
#   'cpu': 0.21,
#   'disk': 0.11,
#   'id': 156,
#   'memory': 0.26,
#   'network': 0.03,
#   'server_cost': 500,
#   'server_id': 156},
#  {'app_name': 'Encryption',
#   'average': 0.39,
#   'cpu': 0.96,
#   'disk': 0.5,
#   'id': 157,
#   'memory': 0.08,
#   'network': 0.02,
#   'server_cost': 500,
#   'server_id': 157},
#  {'app_name': 'Encryption',
#   'average': 0.67,
#   'cpu': 0.77,
#   'disk': 0.6,
#   'id': 158,
#   'memory': 0.54,
#   'network': 0.77,
#   'server_cost': 500,
#   'server_id': 158},
#  {'app_name': 'Encryption',
#   'average': 0.75,
#   'cpu': 0.61,
#   'disk': 0.85,
#   'id': 159,
#   'memory': 0.58,
#   'network': 0.94,
#   'server_cost': 500,
#   'server_id': 159},
#  {'app_name': 'Encryption',
#   'average': 0.41,
#   'cpu': 0.34,
#   'disk': 0.51,
#   'id': 160,
#   'memory': 0.58,
#   'network': 0.22,
#   'server_cost': 500,
#   'server_id': 160},
#  {'app_name': 'Encryption',
#   'average': 0.69,
#   'cpu': 0.58,
#   'disk': 0.44,
#   'id': 161,
#   'memory': 0.81,
#   'network': 0.92,
#   'server_cost': 500,
#   'server_id': 161},
#  {'app_name': 'Encryption',
#   'average': 0.52,
#   'cpu': 0.08,
#   'disk': 0.63,
#   'id': 162,
#   'memory': 0.54,
#   'network': 0.82,
#   'server_cost': 500,
#   'server_id': 162},
#  {'app_name': 'Encryption',
#   'average': 0.56,
#   'cpu': 0.88,
#   'disk': 0.54,
#   'id': 163,
#   'memory': 0.09,
#   'network': 0.71,
#   'server_cost': 500,
#   'server_id': 163},
#  {'app_name': 'Encryption',
#   'average': 0.54,
#   'cpu': 0.91,
#   'disk': 0.29,
#   'id': 164,
#   'memory': 0.76,
#   'network': 0.2,
#   'server_cost': 500,
#   'server_id': 164},
#  {'app_name': 'Encryption',
#   'average': 0.64,
#   'cpu': 0.76,
#   'disk': 0.46,
#   'id': 165,
#   'memory': 0.54,
#   'network': 0.8,
#   'server_cost': 500,
#   'server_id': 165},
#  {'app_name': 'Encryption',
#   'average': 0.44,
#   'cpu': 0.12,
#   'disk': 0.16,
#   'id': 166,
#   'memory': 0.83,
#   'network': 0.67,
#   'server_cost': 500,
#   'server_id': 166},
#  {'app_name': 'Encryption',
#   'average': 0.72,
#   'cpu': 0.92,
#   'disk': 0.44,
#   'id': 167,
#   'memory': 0.78,
#   'network': 0.73,
#   'server_cost': 500,
#   'server_id': 167},
#  {'app_name': 'Encryption',
#   'average': 0.5,
#   'cpu': 0.3,
#   'disk': 0.47,
#   'id': 168,
#   'memory': 0.97,
#   'network': 0.24,
#   'server_cost': 500,
#   'server_id': 168},
#  {'app_name': 'Encryption',
#   'average': 0.28,
#   'cpu': 0.25,
#   'disk': 0.7,
#   'id': 169,
#   'memory': 0.05,
#   'network': 0.13,
#   'server_cost': 500,
#   'server_id': 169},
#  {'app_name': 'Encryption',
#   'average': 0.19,
#   'cpu': 0.32,
#   'disk': 0.1,
#   'id': 170,
#   'memory': 0.13,
#   'network': 0.2,
#   'server_cost': 500,
#   'server_id': 170},
#  {'app_name': 'Encryption',
#   'average': 0.33,
#   'cpu': 0.01,
#   'disk': 0.38,
#   'id': 171,
#   'memory': 0.51,
#   'network': 0.42,
#   'server_cost': 500,
#   'server_id': 171},
#  {'app_name': 'Encryption',
#   'average': 0.58,
#   'cpu': 0.92,
#   'disk': 0.58,
#   'id': 172,
#   'memory': 0.29,
#   'network': 0.51,
#   'server_cost': 500,
#   'server_id': 172},
#  {'app_name': 'Encryption',
#   'average': 0.8,
#   'cpu': 0.64,
#   'disk': 0.74,
#   'id': 173,
#   'memory': 0.92,
#   'network': 0.91,
#   'server_cost': 500,
#   'server_id': 173},
#  {'app_name': 'ContentApp',
#   'average': 0.46,
#   'cpu': 0.12,
#   'disk': 0.39,
#   'id': 174,
#   'memory': 0.81,
#   'network': 0.52,
#   'server_cost': 500,
#   'server_id': 174},
#  {'app_name': 'ContentApp',
#   'average': 0.5,
#   'cpu': 0.0,
#   'disk': 0.84,
#   'id': 175,
#   'memory': 0.81,
#   'network': 0.36,
#   'server_cost': 500,
#   'server_id': 175},
#  {'app_name': 'ContentApp',
#   'average': 0.62,
#   'cpu': 0.84,
#   'disk': 0.37,
#   'id': 176,
#   'memory': 0.37,
#   'network': 0.88,
#   'server_cost': 500,
#   'server_id': 176},
#  {'app_name': 'ContentApp',
#   'average': 0.42,
#   'cpu': 0.35,
#   'disk': 0.3,
#   'id': 177,
#   'memory': 0.61,
#   'network': 0.43,
#   'server_cost': 500,
#   'server_id': 177},
#  {'app_name': 'ContentApp',
#   'average': 0.52,
#   'cpu': 0.16,
#   'disk': 0.71,
#   'id': 178,
#   'memory': 0.83,
#   'network': 0.37,
#   'server_cost': 500,
#   'server_id': 178},
#  {'app_name': 'ContentApp',
#   'average': 0.64,
#   'cpu': 0.36,
#   'disk': 0.89,
#   'id': 179,
#   'memory': 0.93,
#   'network': 0.4,
#   'server_cost': 500,
#   'server_id': 179},
#  {'app_name': 'ContentApp',
#   'average': 0.5,
#   'cpu': 0.26,
#   'disk': 0.98,
#   'id': 180,
#   'memory': 0.57,
#   'network': 0.19,
#   'server_cost': 500,
#   'server_id': 180},
#  {'app_name': 'ContentApp',
#   'average': 0.66,
#   'cpu': 0.18,
#   'disk': 0.62,
#   'id': 181,
#   'memory': 0.9,
#   'network': 0.96,
#   'server_cost': 500,
#   'server_id': 181},
#  {'app_name': 'ContentApp',
#   'average': 0.66,
#   'cpu': 0.71,
#   'disk': 0.91,
#   'id': 182,
#   'memory': 0.96,
#   'network': 0.06,
#   'server_cost': 500,
#   'server_id': 182},
#  {'app_name': 'ContentApp',
#   'average': 0.64,
#   'cpu': 0.62,
#   'disk': 0.03,
#   'id': 183,
#   'memory': 0.96,
#   'network': 0.96,
#   'server_cost': 500,
#   'server_id': 183},
#  {'app_name': 'ContentApp',
#   'average': 0.55,
#   'cpu': 0.01,
#   'disk': 0.49,
#   'id': 184,
#   'memory': 0.83,
#   'network': 0.87,
#   'server_cost': 500,
#   'server_id': 184},
#  {'app_name': 'ContentApp',
#   'average': 0.36,
#   'cpu': 0.23,
#   'disk': 0.22,
#   'id': 185,
#   'memory': 0.24,
#   'network': 0.76,
#   'server_cost': 500,
#   'server_id': 185},
#  {'app_name': 'ContentApp',
#   'average': 0.47,
#   'cpu': 0.26,
#   'disk': 0.06,
#   'id': 186,
#   'memory': 0.89,
#   'network': 0.68,
#   'server_cost': 500,
#   'server_id': 186},
#  {'app_name': 'ContentApp',
#   'average': 0.74,
#   'cpu': 0.65,
#   'disk': 0.9,
#   'id': 187,
#   'memory': 0.62,
#   'network': 0.8,
#   'server_cost': 500,
#   'server_id': 187},
#  {'app_name': 'ContentApp',
#   'average': 0.59,
#   'cpu': 0.77,
#   'disk': 0.69,
#   'id': 188,
#   'memory': 0.86,
#   'network': 0.03,
#   'server_cost': 500,
#   'server_id': 188},
#  {'app_name': 'ContentApp',
#   'average': 0.49,
#   'cpu': 0.42,
#   'disk': 0.6,
#   'id': 189,
#   'memory': 0.23,
#   'network': 0.69,
#   'server_cost': 500,
#   'server_id': 189},
#  {'app_name': 'ContentApp',
#   'average': 0.47,
#   'cpu': 0.6,
#   'disk': 0.89,
#   'id': 190,
#   'memory': 0.27,
#   'network': 0.13,
#   'server_cost': 500,
#   'server_id': 190},
#  {'app_name': 'ContentApp',
#   'average': 0.22,
#   'cpu': 0.06,
#   'disk': 0.2,
#   'id': 191,
#   'memory': 0.12,
#   'network': 0.49,
#   'server_cost': 500,
#   'server_id': 191},
#  {'app_name': 'ContentApp',
#   'average': 0.55,
#   'cpu': 0.55,
#   'disk': 0.92,
#   'id': 192,
#   'memory': 0.18,
#   'network': 0.56,
#   'server_cost': 500,
#   'server_id': 192},
#  {'app_name': 'ContentApp',
#   'average': 0.32,
#   'cpu': 0.26,
#   'disk': 0.04,
#   'id': 193,
#   'memory': 0.86,
#   'network': 0.11,
#   'server_cost': 500,
#   'server_id': 193},
#  {'app_name': 'ContentApp',
#   'average': 0.44,
#   'cpu': 0.13,
#   'disk': 0.05,
#   'id': 194,
#   'memory': 0.61,
#   'network': 0.98,
#   'server_cost': 500,
#   'server_id': 194},
#  {'app_name': 'ContentApp',
#   'average': 0.21,
#   'cpu': 0.12,
#   'disk': 0.11,
#   'id': 195,
#   'memory': 0.21,
#   'network': 0.4,
#   'server_cost': 500,
#   'server_id': 195},
#  {'app_name': 'ContentApp',
#   'average': 0.46,
#   'cpu': 0.11,
#   'disk': 0.72,
#   'id': 196,
#   'memory': 0.91,
#   'network': 0.09,
#   'server_cost': 500,
#   'server_id': 196},
#  {'app_name': 'ContentApp',
#   'average': 0.53,
#   'cpu': 0.09,
#   'disk': 0.36,
#   'id': 197,
#   'memory': 0.99,
#   'network': 0.67,
#   'server_cost': 500,
#   'server_id': 197},
#  {'app_name': 'ContentApp',
#   'average': 0.58,
#   'cpu': 0.75,
#   'disk': 0.26,
#   'id': 198,
#   'memory': 0.88,
#   'network': 0.45,
#   'server_cost': 500,
#   'server_id': 198},
#  {'app_name': 'ContentApp',
#   'average': 0.21,
#   'cpu': 0.38,
#   'disk': 0.18,
#   'id': 199,
#   'memory': 0.25,
#   'network': 0.03,
#   'server_cost': 500,
#   'server_id': 199},
#  {'app_name': 'ContentApp',
#   'average': 0.39,
#   'cpu': 0.51,
#   'disk': 0.27,
#   'id': 200,
#   'memory': 0.42,
#   'network': 0.36,
#   'server_cost': 500,
#   'server_id': 200},
#  {'app_name': 'ContentApp',
#   'average': 0.27,
#   'cpu': 0.18,
#   'disk': 0.38,
#   'id': 201,
#   'memory': 0.16,
#   'network': 0.35,
#   'server_cost': 500,
#   'server_id': 201},
#  {'app_name': 'ContentApp',
#   'average': 0.7,
#   'cpu': 0.53,
#   'disk': 0.47,
#   'id': 202,
#   'memory': 0.8,
#   'network': 0.99,
#   'server_cost': 500,
#   'server_id': 202},
#  {'app_name': 'ContentApp',
#   'average': 0.4,
#   'cpu': 0.56,
#   'disk': 0.45,
#   'id': 203,
#   'memory': 0.28,
#   'network': 0.3,
#   'server_cost': 500,
#   'server_id': 203},
#  {'app_name': 'ContentApp',
#   'average': 0.73,
#   'cpu': 0.67,
#   'disk': 0.73,
#   'id': 204,
#   'memory': 0.65,
#   'network': 0.85,
#   'server_cost': 500,
#   'server_id': 204},
#  {'app_name': 'ContentApp',
#   'average': 0.22,
#   'cpu': 0.08,
#   'disk': 0.07,
#   'id': 205,
#   'memory': 0.15,
#   'network': 0.58,
#   'server_cost': 500,
#   'server_id': 205},
#  {'app_name': 'ContentApp',
#   'average': 0.38,
#   'cpu': 0.34,
#   'disk': 0.34,
#   'id': 206,
#   'memory': 0.56,
#   'network': 0.27,
#   'server_cost': 500,
#   'server_id': 206},
#  {'app_name': 'ContentApp',
#   'average': 0.29,
#   'cpu': 0.39,
#   'disk': 0.47,
#   'id': 207,
#   'memory': 0.22,
#   'network': 0.07,
#   'server_cost': 500,
#   'server_id': 207},
#  {'app_name': 'ContentApp',
#   'average': 0.27,
#   'cpu': 0.3,
#   'disk': 0.05,
#   'id': 208,
#   'memory': 0.32,
#   'network': 0.43,
#   'server_cost': 500,
#   'server_id': 208},
#  {'app_name': 'ContentApp',
#   'average': 0.48,
#   'cpu': 0.46,
#   'disk': 0.49,
#   'id': 209,
#   'memory': 0.79,
#   'network': 0.18,
#   'server_cost': 500,
#   'server_id': 209},
#  {'app_name': 'ContentApp',
#   'average': 0.56,
#   'cpu': 0.57,
#   'disk': 0.71,
#   'id': 210,
#   'memory': 0.86,
#   'network': 0.08,
#   'server_cost': 500,
#   'server_id': 210},
#  {'app_name': 'ContentApp',
#   'average': 0.55,
#   'cpu': 0.9,
#   'disk': 0.07,
#   'id': 211,
#   'memory': 0.59,
#   'network': 0.63,
#   'server_cost': 500,
#   'server_id': 211},
#  {'app_name': 'ContentApp',
#   'average': 0.4,
#   'cpu': 0.42,
#   'disk': 0.34,
#   'id': 212,
#   'memory': 0.53,
#   'network': 0.31,
#   'server_cost': 500,
#   'server_id': 212},
#  {'app_name': 'ContentApp',
#   'average': 0.27,
#   'cpu': 0.08,
#   'disk': 0.85,
#   'id': 213,
#   'memory': 0.1,
#   'network': 0.07,
#   'server_cost': 500,
#   'server_id': 213},
#  {'app_name': 'ContentApp',
#   'average': 0.71,
#   'cpu': 0.24,
#   'disk': 0.81,
#   'id': 214,
#   'memory': 0.82,
#   'network': 0.99,
#   'server_cost': 500,
#   'server_id': 214},
#  {'app_name': 'ContentApp',
#   'average': 0.72,
#   'cpu': 0.2,
#   'disk': 0.82,
#   'id': 215,
#   'memory': 0.92,
#   'network': 0.95,
#   'server_cost': 500,
#   'server_id': 215},
#  {'app_name': 'ContentApp',
#   'average': 0.56,
#   'cpu': 0.25,
#   'disk': 0.74,
#   'id': 216,
#   'memory': 0.42,
#   'network': 0.83,
#   'server_cost': 500,
#   'server_id': 216},
#  {'app_name': 'ContentApp',
#   'average': 0.28,
#   'cpu': 0.07,
#   'disk': 0.0,
#   'id': 217,
#   'memory': 0.21,
#   'network': 0.85,
#   'server_cost': 500,
#   'server_id': 217},
#  {'app_name': 'ContentApp',
#   'average': 0.47,
#   'cpu': 0.06,
#   'disk': 0.56,
#   'id': 218,
#   'memory': 0.92,
#   'network': 0.32,
#   'server_cost': 500,
#   'server_id': 218},
#  {'app_name': 'ContentApp',
#   'average': 0.25,
#   'cpu': 0.44,
#   'disk': 0.51,
#   'id': 219,
#   'memory': 0.01,
#   'network': 0.02,
#   'server_cost': 500,
#   'server_id': 219},
#  {'app_name': 'ContentApp',
#   'average': 0.18,
#   'cpu': 0.18,
#   'disk': 0.12,
#   'id': 220,
#   'memory': 0.23,
#   'network': 0.18,
#   'server_cost': 500,
#   'server_id': 220},
#  {'app_name': 'ContentApp',
#   'average': 0.47,
#   'cpu': 0.31,
#   'disk': 0.7,
#   'id': 221,
#   'memory': 0.38,
#   'network': 0.49,
#   'server_cost': 500,
#   'server_id': 221},
#  {'app_name': 'ContentApp',
#   'average': 0.48,
#   'cpu': 0.71,
#   'disk': 0.25,
#   'id': 222,
#   'memory': 0.5,
#   'network': 0.47,
#   'server_cost': 500,
#   'server_id': 222},
#  {'app_name': 'ContentApp',
#   'average': 0.47,
#   'cpu': 0.39,
#   'disk': 0.32,
#   'id': 223,
#   'memory': 0.19,
#   'network': 0.99,
#   'server_cost': 500,
#   'server_id': 223},
#  {'app_name': 'ContentApp',
#   'average': 0.62,
#   'cpu': 0.88,
#   'disk': 0.68,
#   'id': 224,
#   'memory': 0.39,
#   'network': 0.52,
#   'server_cost': 500,
#   'server_id': 224},
#  {'app_name': 'ContentApp',
#   'average': 0.58,
#   'cpu': 0.25,
#   'disk': 0.87,
#   'id': 225,
#   'memory': 0.33,
#   'network': 0.89,
#   'server_cost': 500,
#   'server_id': 225},
#  {'app_name': 'ContentApp',
#   'average': 0.45,
#   'cpu': 0.46,
#   'disk': 0.27,
#   'id': 226,
#   'memory': 0.2,
#   'network': 0.87,
#   'server_cost': 500,
#   'server_id': 226},
#  {'app_name': 'ContentApp',
#   'average': 0.43,
#   'cpu': 0.32,
#   'disk': 0.69,
#   'id': 227,
#   'memory': 0.32,
#   'network': 0.39,
#   'server_cost': 500,
#   'server_id': 227},
#  {'app_name': 'ContentApp',
#   'average': 0.39,
#   'cpu': 0.35,
#   'disk': 0.69,
#   'id': 228,
#   'memory': 0.38,
#   'network': 0.14,
#   'server_cost': 500,
#   'server_id': 228},
#  {'app_name': 'ContentApp',
#   'average': 0.34,
#   'cpu': 0.47,
#   'disk': 0.05,
#   'id': 229,
#   'memory': 0.35,
#   'network': 0.48,
#   'server_cost': 500,
#   'server_id': 229},
#  {'app_name': 'ContentApp',
#   'average': 0.39,
#   'cpu': 0.87,
#   'disk': 0.09,
#   'id': 230,
#   'memory': 0.02,
#   'network': 0.59,
#   'server_cost': 500,
#   'server_id': 230},
#  {'app_name': 'ContentApp',
#   'average': 0.41,
#   'cpu': 0.08,
#   'disk': 0.74,
#   'id': 231,
#   'memory': 0.81,
#   'network': 0.01,
#   'server_cost': 500,
#   'server_id': 231},
#  {'app_name': 'ContentApp',
#   'average': 0.75,
#   'cpu': 0.79,
#   'disk': 0.45,
#   'id': 232,
#   'memory': 0.79,
#   'network': 0.96,
#   'server_cost': 500,
#   'server_id': 232},
#  {'app_name': 'ContentApp',
#   'average': 0.64,
#   'cpu': 0.57,
#   'disk': 0.28,
#   'id': 233,
#   'memory': 0.88,
#   'network': 0.84,
#   'server_cost': 500,
#   'server_id': 233},
#  {'app_name': 'ContentApp',
#   'average': 0.37,
#   'cpu': 0.61,
#   'disk': 0.03,
#   'id': 234,
#   'memory': 0.46,
#   'network': 0.38,
#   'server_cost': 500,
#   'server_id': 234},
#  {'app_name': 'ContentApp',
#   'average': 0.47,
#   'cpu': 0.84,
#   'disk': 0.29,
#   'id': 235,
#   'memory': 0.14,
#   'network': 0.61,
#   'server_cost': 500,
#   'server_id': 235},
#  {'app_name': 'ContentApp',
#   'average': 0.33,
#   'cpu': 0.18,
#   'disk': 0.37,
#   'id': 236,
#   'memory': 0.03,
#   'network': 0.74,
#   'server_cost': 500,
#   'server_id': 236},
#  {'app_name': 'ContentApp',
#   'average': 0.75,
#   'cpu': 0.41,
#   'disk': 0.85,
#   'id': 237,
#   'memory': 0.75,
#   'network': 0.98,
#   'server_cost': 500,
#   'server_id': 237},
#  {'app_name': 'ContentApp',
#   'average': 0.55,
#   'cpu': 0.83,
#   'disk': 0.47,
#   'id': 238,
#   'memory': 0.62,
#   'network': 0.29,
#   'server_cost': 500,
#   'server_id': 238},
#  {'app_name': 'ContentApp',
#   'average': 0.3,
#   'cpu': 0.51,
#   'disk': 0.28,
#   'id': 239,
#   'memory': 0.34,
#   'network': 0.06,
#   'server_cost': 500,
#   'server_id': 239},
#  {'app_name': 'ContentApp',
#   'average': 0.41,
#   'cpu': 0.09,
#   'disk': 0.54,
#   'id': 240,
#   'memory': 0.96,
#   'network': 0.05,
#   'server_cost': 500,
#   'server_id': 240},
#  {'app_name': 'ContentApp',
#   'average': 0.45,
#   'cpu': 0.52,
#   'disk': 0.66,
#   'id': 241,
#   'memory': 0.22,
#   'network': 0.4,
#   'server_cost': 500,
#   'server_id': 241},
#  {'app_name': 'ContentApp',
#   'average': 0.58,
#   'cpu': 0.84,
#   'disk': 0.57,
#   'id': 242,
#   'memory': 0.61,
#   'network': 0.29,
#   'server_cost': 500,
#   'server_id': 242},
#  {'app_name': 'ContentApp',
#   'average': 0.39,
#   'cpu': 0.18,
#   'disk': 0.82,
#   'id': 243,
#   'memory': 0.06,
#   'network': 0.48,
#   'server_cost': 500,
#   'server_id': 243},
#  {'app_name': 'ContentApp',
#   'average': 0.6,
#   'cpu': 0.82,
#   'disk': 0.36,
#   'id': 244,
#   'memory': 0.66,
#   'network': 0.58,
#   'server_cost': 500,
#   'server_id': 244},
#  {'app_name': 'ContentApp',
#   'average': 0.39,
#   'cpu': 0.02,
#   'disk': 0.23,
#   'id': 245,
#   'memory': 0.59,
#   'network': 0.72,
#   'server_cost': 500,
#   'server_id': 245},
#  {'app_name': 'ContentApp',
#   'average': 0.49,
#   'cpu': 0.28,
#   'disk': 0.54,
#   'id': 246,
#   'memory': 0.29,
#   'network': 0.84,
#   'server_cost': 500,
#   'server_id': 246},
#  {'app_name': 'ContentApp',
#   'average': 0.43,
#   'cpu': 0.15,
#   'disk': 0.34,
#   'id': 247,
#   'memory': 0.87,
#   'network': 0.38,
#   'server_cost': 500,
#   'server_id': 247},
#  {'app_name': 'ContentApp',
#   'average': 0.77,
#   'cpu': 0.98,
#   'disk': 0.99,
#   'id': 248,
#   'memory': 0.68,
#   'network': 0.45,
#   'server_cost': 500,
#   'server_id': 248},
#  {'app_name': 'ContentApp',
#   'average': 0.54,
#   'cpu': 0.69,
#   'disk': 0.31,
#   'id': 249,
#   'memory': 0.37,
#   'network': 0.8,
#   'server_cost': 500,
#   'server_id': 249},
#  {'app_name': 'ContentApp',
#   'average': 0.48,
#   'cpu': 0.21,
#   'disk': 0.35,
#   'id': 250,
#   'memory': 0.6,
#   'network': 0.78,
#   'server_cost': 500,
#   'server_id': 250},
#  {'app_name': 'ContentApp',
#   'average': 0.63,
#   'cpu': 0.43,
#   'disk': 0.65,
#   'id': 251,
#   'memory': 0.71,
#   'network': 0.73,
#   'server_cost': 500,
#   'server_id': 251},
#  {'app_name': 'ContentApp',
#   'average': 0.54,
#   'cpu': 0.28,
#   'disk': 0.96,
#   'id': 252,
#   'memory': 0.69,
#   'network': 0.23,
#   'server_cost': 500,
#   'server_id': 252},
#  {'app_name': 'ContentApp',
#   'average': 0.47,
#   'cpu': 0.82,
#   'disk': 0.37,
#   'id': 253,
#   'memory': 0.58,
#   'network': 0.12,
#   'server_cost': 500,
#   'server_id': 253},
#  {'app_name': 'ContentApp',
#   'average': 0.34,
#   'cpu': 0.1,
#   'disk': 0.41,
#   'id': 254,
#   'memory': 0.31,
#   'network': 0.53,
#   'server_cost': 500,
#   'server_id': 254},
#  {'app_name': 'ContentApp',
#   'average': 0.54,
#   'cpu': 0.81,
#   'disk': 0.43,
#   'id': 255,
#   'memory': 0.07,
#   'network': 0.86,
#   'server_cost': 500,
#   'server_id': 255},
#  {'app_name': 'ContentApp',
#   'average': 0.42,
#   'cpu': 0.47,
#   'disk': 0.08,
#   'id': 256,
#   'memory': 0.36,
#   'network': 0.76,
#   'server_cost': 500,
#   'server_id': 256},
#  {'app_name': 'ContentApp',
#   'average': 0.39,
#   'cpu': 0.9,
#   'disk': 0.15,
#   'id': 257,
#   'memory': 0.5,
#   'network': 0.0,
#   'server_cost': 500,
#   'server_id': 257},
#  {'app_name': 'ContentApp',
#   'average': 0.19,
#   'cpu': 0.17,
#   'disk': 0.1,
#   'id': 258,
#   'memory': 0.08,
#   'network': 0.4,
#   'server_cost': 500,
#   'server_id': 258},
#  {'app_name': 'ContentApp',
#   'average': 0.44,
#   'cpu': 0.65,
#   'disk': 0.48,
#   'id': 259,
#   'memory': 0.4,
#   'network': 0.25,
#   'server_cost': 500,
#   'server_id': 259},
#  {'app_name': 'ContentApp',
#   'average': 0.6,
#   'cpu': 0.46,
#   'disk': 0.55,
#   'id': 260,
#   'memory': 0.83,
#   'network': 0.57,
#   'server_cost': 500,
#   'server_id': 260},
#  {'app_name': 'ContentApp',
#   'average': 0.35,
#   'cpu': 0.25,
#   'disk': 0.41,
#   'id': 261,
#   'memory': 0.36,
#   'network': 0.39,
#   'server_cost': 500,
#   'server_id': 261},
#  {'app_name': 'ContentApp',
#   'average': 0.61,
#   'cpu': 0.82,
#   'disk': 0.6,
#   'id': 262,
#   'memory': 0.7,
#   'network': 0.31,
#   'server_cost': 500,
#   'server_id': 262},
#  {'app_name': 'ContentApp',
#   'average': 0.42,
#   'cpu': 0.63,
#   'disk': 0.31,
#   'id': 263,
#   'memory': 0.31,
#   'network': 0.44,
#   'server_cost': 500,
#   'server_id': 263},
#  {'app_name': 'ContentApp',
#   'average': 0.63,
#   'cpu': 0.0,
#   'disk': 0.86,
#   'id': 264,
#   'memory': 0.82,
#   'network': 0.82,
#   'server_cost': 500,
#   'server_id': 264},
#  {'app_name': 'ContentApp',
#   'average': 0.69,
#   'cpu': 0.71,
#   'disk': 0.88,
#   'id': 265,
#   'memory': 0.63,
#   'network': 0.54,
#   'server_cost': 500,
#   'server_id': 265},
#  {'app_name': 'ContentApp',
#   'average': 0.36,
#   'cpu': 0.59,
#   'disk': 0.4,
#   'id': 266,
#   'memory': 0.36,
#   'network': 0.07,
#   'server_cost': 500,
#   'server_id': 266},
#  {'app_name': 'ContentApp',
#   'average': 0.3,
#   'cpu': 0.12,
#   'disk': 0.63,
#   'id': 267,
#   'memory': 0.07,
#   'network': 0.37,
#   'server_cost': 500,
#   'server_id': 267},
#  {'app_name': 'ContentApp',
#   'average': 0.45,
#   'cpu': 0.52,
#   'disk': 0.32,
#   'id': 268,
#   'memory': 0.32,
#   'network': 0.64,
#   'server_cost': 500,
#   'server_id': 268},
#  {'app_name': 'ContentApp',
#   'average': 0.48,
#   'cpu': 0.44,
#   'disk': 0.8,
#   'id': 269,
#   'memory': 0.63,
#   'network': 0.05,
#   'server_cost': 500,
#   'server_id': 269},
#  {'app_name': 'ContentApp',
#   'average': 0.36,
#   'cpu': 0.34,
#   'disk': 0.65,
#   'id': 270,
#   'memory': 0.03,
#   'network': 0.43,
#   'server_cost': 500,
#   'server_id': 270},
#  {'app_name': 'ContentApp',
#   'average': 0.5,
#   'cpu': 0.29,
#   'disk': 0.3,
#   'id': 271,
#   'memory': 0.53,
#   'network': 0.9,
#   'server_cost': 500,
#   'server_id': 271},
#  {'app_name': 'ContentApp',
#   'average': 0.39,
#   'cpu': 0.16,
#   'disk': 0.35,
#   'id': 272,
#   'memory': 0.39,
#   'network': 0.66,
#   'server_cost': 500,
#   'server_id': 272},
#  {'app_name': 'ContentApp',
#   'average': 0.24,
#   'cpu': 0.05,
#   'disk': 0.39,
#   'id': 273,
#   'memory': 0.18,
#   'network': 0.32,
#   'server_cost': 500,
#   'server_id': 273},
#  {'app_name': 'ContentApp',
#   'average': 0.27,
#   'cpu': 0.56,
#   'disk': 0.13,
#   'id': 274,
#   'memory': 0.08,
#   'network': 0.33,
#   'server_cost': 500,
#   'server_id': 274},
#  {'app_name': 'ContentApp',
#   'average': 0.13,
#   'cpu': 0.17,
#   'disk': 0.09,
#   'id': 275,
#   'memory': 0.17,
#   'network': 0.09,
#   'server_cost': 500,
#   'server_id': 275},
#  {'app_name': 'ContentApp',
#   'average': 0.47,
#   'cpu': 0.84,
#   'disk': 0.11,
#   'id': 276,
#   'memory': 0.39,
#   'network': 0.56,
#   'server_cost': 500,
#   'server_id': 276},
#  {'app_name': 'ContentApp',
#   'average': 0.24,
#   'cpu': 0.17,
#   'disk': 0.29,
#   'id': 277,
#   'memory': 0.36,
#   'network': 0.14,
#   'server_cost': 500,
#   'server_id': 277},
#  {'app_name': 'ContentApp',
#   'average': 0.5,
#   'cpu': 0.96,
#   'disk': 0.47,
#   'id': 278,
#   'memory': 0.06,
#   'network': 0.52,
#   'server_cost': 500,
#   'server_id': 278},
#  {'app_name': 'ContentApp',
#   'average': 0.46,
#   'cpu': 0.37,
#   'disk': 0.55,
#   'id': 279,
#   'memory': 0.16,
#   'network': 0.78,
#   'server_cost': 500,
#   'server_id': 279},
#  {'app_name': 'ContentApp',
#   'average': 0.5,
#   'cpu': 0.13,
#   'disk': 0.29,
#   'id': 280,
#   'memory': 0.83,
#   'network': 0.76,
#   'server_cost': 500,
#   'server_id': 280},
#  {'app_name': 'ContentApp',
#   'average': 0.32,
#   'cpu': 0.49,
#   'disk': 0.03,
#   'id': 281,
#   'memory': 0.69,
#   'network': 0.07,
#   'server_cost': 500,
#   'server_id': 281},
#  {'app_name': 'ContentApp',
#   'average': 0.41,
#   'cpu': 0.33,
#   'disk': 0.24,
#   'id': 282,
#   'memory': 0.6,
#   'network': 0.49,
#   'server_cost': 500,
#   'server_id': 282},
#  {'app_name': 'ContentApp',
#   'average': 0.76,
#   'cpu': 0.99,
#   'disk': 0.54,
#   'id': 283,
#   'memory': 0.66,
#   'network': 0.84,
# ...
#  {'app_name': 'couchbase',
#   'average': 0.51,
#   'cpu': 0.84,
#   'disk': 0.44,
#   'id': 906,
#   'memory': 0.06,
#   'network': 0.71,
#   'server_cost': 500,
#   'server_id': 906},
#  {'app_name': 'couchbase',
#   'average': 0.71,
#   'cpu': 0.92,
#   'disk': 0.35,
#   'id': 907,
#   'memory': 0.89,
#   'network': 0.69,
#   'server_cost': 500,
#   'server_id': 907},
#  {'app_name': 'couchbase',
#   'average': 0.81,
#   'cpu': 0.99,
#   'disk': 0.71,
#   'id': 908,
#   'memory': 0.98,
#   'network': 0.59,
#   'server_cost': 500,
#   'server_id': 908},
#  {'app_name': 'couchbase',
#   'average': 0.58,
#   'cpu': 0.15,
#   'disk': 0.68,
#   'id': 909,
#   'memory': 0.67,
#   'network': 0.81,
#   'server_cost': 500,
#   'server_id': 909},
#  {'app_name': 'couchbase',
#   'average': 0.44,
#   'cpu': 0.78,
#   'disk': 0.03,
#   'id': 910,
#   'memory': 0.7,
#   'network': 0.26,
#   'server_cost': 500,
#   'server_id': 910},
#  {'app_name': 'couchbase',
#   'average': 0.48,
#   'cpu': 0.35,
#   'disk': 0.55,
#   'id': 911,
#   'memory': 0.97,
#   'network': 0.05,
#   'server_cost': 500,
#   'server_id': 911},
#  {'app_name': 'couchbase',
#   'average': 0.37,
#   'cpu': 0.0,
#   'disk': 0.51,
#   'id': 912,
#   'memory': 0.71,
#   'network': 0.26,
#   'server_cost': 500,
#   'server_id': 912},
#  {'app_name': 'couchbase',
#   'average': 0.73,
#   'cpu': 0.27,
#   'disk': 0.97,
#   'id': 913,
#   'memory': 0.76,
#   'network': 0.91,
#   'server_cost': 500,
#   'server_id': 913},
#  {'app_name': 'couchbase',
#   'average': 0.6,
#   'cpu': 0.52,
#   'disk': 0.7,
#   'id': 914,
#   'memory': 0.3,
#   'network': 0.88,
#   'server_cost': 500,
#   'server_id': 914},
#  {'app_name': 'couchbase',
#   'average': 0.44,
#   'cpu': 0.52,
#   'disk': 0.03,
#   'id': 915,
#   'memory': 0.74,
#   'network': 0.47,
#   'server_cost': 500,
#   'server_id': 915},
#  {'app_name': 'couchbase',
#   'average': 0.68,
#   'cpu': 0.7,
#   'disk': 0.66,
#   'id': 916,
#   'memory': 0.61,
#   'network': 0.75,
#   'server_cost': 500,
#   'server_id': 916},
#  {'app_name': 'couchbase',
#   'average': 0.42,
#   'cpu': 0.83,
#   'disk': 0.44,
#   'id': 917,
#   'memory': 0.05,
#   'network': 0.36,
#   'server_cost': 500,
#   'server_id': 917},
#  {'app_name': 'couchbase',
#   'average': 0.31,
#   'cpu': 0.11,
#   'disk': 0.2,
#   'id': 918,
#   'memory': 0.27,
#   'network': 0.66,
#   'server_cost': 500,
#   'server_id': 918},
#  {'app_name': 'couchbase',
#   'average': 0.42,
#   'cpu': 0.1,
#   'disk': 0.73,
#   'id': 919,
#   'memory': 0.62,
#   'network': 0.22,
#   'server_cost': 500,
#   'server_id': 919},
#  {'app_name': 'couchbase',
#   'average': 0.42,
#   'cpu': 0.64,
#   'disk': 0.03,
#   'id': 920,
#   'memory': 0.03,
#   'network': 0.96,
#   'server_cost': 500,
#   'server_id': 920},
#  {'app_name': 'couchbase',
#   'average': 0.51,
#   'cpu': 0.31,
#   'disk': 0.7,
#   'id': 921,
#   'memory': 0.77,
#   'network': 0.25,
#   'server_cost': 500,
#   'server_id': 921},
#  {'app_name': 'couchbase',
#   'average': 0.46,
#   'cpu': 0.5,
#   'disk': 0.97,
#   'id': 922,
#   'memory': 0.19,
#   'network': 0.17,
#   'server_cost': 500,
#   'server_id': 922},
#  {'app_name': 'couchbase',
#   'average': 0.51,
#   'cpu': 0.3,
#   'disk': 0.46,
#   'id': 923,
#   'memory': 0.43,
#   'network': 0.83,
#   'server_cost': 500,
#   'server_id': 923},
#  {'app_name': 'couchbase',
#   'average': 0.4,
#   'cpu': 0.7,
#   'disk': 0.36,
#   'id': 924,
#   'memory': 0.24,
#   'network': 0.31,
#   'server_cost': 500,
#   'server_id': 924},
#  {'app_name': 'couchbase',
#   'average': 0.41,
#   'cpu': 0.7,
#   'disk': 0.34,
#   'id': 925,
#   'memory': 0.54,
#   'network': 0.07,
#   'server_cost': 500,
#   'server_id': 925},
#  {'app_name': 'couchbase',
#   'average': 0.32,
#   'cpu': 0.29,
#   'disk': 0.13,
#   'id': 926,
#   'memory': 0.1,
#   'network': 0.75,
#   'server_cost': 500,
#   'server_id': 926},
#  {'app_name': 'couchbase',
#   'average': 0.54,
#   'cpu': 0.5,
#   'disk': 0.75,
#   'id': 927,
#   'memory': 0.58,
#   'network': 0.34,
#   'server_cost': 500,
#   'server_id': 927},
#  {'app_name': 'couchbase',
#   'average': 0.55,
#   'cpu': 0.8,
#   'disk': 0.03,
#   'id': 928,
#   'memory': 0.57,
#   'network': 0.8,
#   'server_cost': 500,
#   'server_id': 928},
#  {'app_name': 'couchbase',
#   'average': 0.35,
#   'cpu': 0.02,
#   'disk': 0.36,
#   'id': 929,
#   'memory': 0.58,
#   'network': 0.44,
#   'server_cost': 500,
#   'server_id': 929},
#  {'app_name': 'couchbase',
#   'average': 0.53,
#   'cpu': 0.47,
#   'disk': 0.1,
#   'id': 930,
#   'memory': 0.6,
#   'network': 0.96,
#   'server_cost': 500,
#   'server_id': 930},
#  {'app_name': 'couchbase',
#   'average': 0.4,
#   'cpu': 0.45,
#   'disk': 0.72,
#   'id': 931,
#   'memory': 0.4,
#   'network': 0.02,
#   'server_cost': 500,
#   'server_id': 931},
#  {'app_name': 'couchbase',
#   'average': 0.62,
#   'cpu': 0.26,
#   'disk': 0.72,
#   'id': 932,
#   'memory': 0.57,
#   'network': 0.91,
#   'server_cost': 500,
#   'server_id': 932},
#  {'app_name': 'couchbase',
#   'average': 0.49,
#   'cpu': 0.25,
#   'disk': 0.83,
#   'id': 933,
#   'memory': 0.16,
#   'network': 0.71,
#   'server_cost': 500,
#   'server_id': 933},
#  {'app_name': 'couchbase',
#   'average': 0.51,
#   'cpu': 0.89,
#   'disk': 0.51,
#   'id': 934,
#   'memory': 0.56,
#   'network': 0.09,
#   'server_cost': 500,
#   'server_id': 934},
#  {'app_name': 'couchbase',
#   'average': 0.45,
#   'cpu': 0.05,
#   'disk': 0.79,
#   'id': 935,
#   'memory': 0.86,
#   'network': 0.1,
#   'server_cost': 500,
#   'server_id': 935},
#  {'app_name': 'couchbase',
#   'average': 0.47,
#   'cpu': 0.5,
#   'disk': 0.81,
#   'id': 936,
#   'memory': 0.23,
#   'network': 0.35,
#   'server_cost': 500,
#   'server_id': 936},
#  {'app_name': 'couchbase',
#   'average': 0.48,
#   'cpu': 0.41,
#   'disk': 0.91,
#   'id': 937,
#   'memory': 0.19,
#   'network': 0.42,
#   'server_cost': 500,
#   'server_id': 937},
#  {'app_name': 'couchbase',
#   'average': 0.54,
#   'cpu': 0.69,
#   'disk': 0.28,
#   'id': 938,
#   'memory': 0.58,
#   'network': 0.61,
#   'server_cost': 500,
#   'server_id': 938},
#  {'app_name': 'couchbase',
#   'average': 0.49,
#   'cpu': 0.28,
#   'disk': 0.7,
#   'id': 939,
#   'memory': 0.96,
#   'network': 0.03,
#   'server_cost': 500,
#   'server_id': 939},
#  {'app_name': 'couchbase',
#   'average': 0.41,
#   'cpu': 0.29,
#   'disk': 0.23,
#   'id': 940,
#   'memory': 0.83,
#   'network': 0.3,
#   'server_cost': 500,
#   'server_id': 940},
#  {'app_name': 'couchbase',
#   'average': 0.47,
#   'cpu': 0.09,
#   'disk': 0.9,
#   'id': 941,
#   'memory': 0.53,
#   'network': 0.35,
#   'server_cost': 500,
#   'server_id': 941},
#  {'app_name': 'couchbase',
#   'average': 0.57,
#   'cpu': 0.53,
#   'disk': 0.48,
#   'id': 942,
#   'memory': 0.47,
#   'network': 0.8,
#   'server_cost': 500,
#   'server_id': 942},
#  {'app_name': 'couchbase',
#   'average': 0.64,
#   'cpu': 0.98,
#   'disk': 0.5,
#   'id': 943,
#   'memory': 0.77,
#   'network': 0.33,
#   'server_cost': 500,
#   'server_id': 943},
#  {'app_name': 'couchbase',
#   'average': 0.46,
#   'cpu': 0.3,
#   'disk': 0.55,
#   'id': 944,
#   'memory': 0.86,
#   'network': 0.14,
#   'server_cost': 500,
#   'server_id': 944},
#  {'app_name': 'couchbase',
#   'average': 0.5,
#   'cpu': 0.54,
#   'disk': 0.34,
#   'id': 945,
#   'memory': 0.32,
#   'network': 0.79,
#   'server_cost': 500,
#   'server_id': 945},
#  {'app_name': 'couchbase',
#   'average': 0.72,
#   'cpu': 0.77,
#   'disk': 0.85,
#   'id': 946,
#   'memory': 0.86,
#   'network': 0.39,
#   'server_cost': 500,
#   'server_id': 946},
#  {'app_name': 'couchbase',
#   'average': 0.52,
#   'cpu': 0.78,
#   'disk': 0.7,
#   'id': 947,
#   'memory': 0.11,
#   'network': 0.46,
#   'server_cost': 500,
#   'server_id': 947},
#  {'app_name': 'couchbase',
#   'average': 0.65,
#   'cpu': 0.54,
#   'disk': 0.84,
#   'id': 948,
#   'memory': 0.93,
#   'network': 0.29,
#   'server_cost': 500,
#   'server_id': 948},
#  {'app_name': 'couchbase',
#   'average': 0.61,
#   'cpu': 0.6,
#   'disk': 0.31,
#   'id': 949,
#   'memory': 0.58,
#   'network': 0.96,
#   'server_cost': 500,
#   'server_id': 949},
#  {'app_name': 'couchbase',
#   'average': 0.27,
#   'cpu': 0.48,
#   'disk': 0.08,
#   'id': 950,
#   'memory': 0.43,
#   'network': 0.1,
#   'server_cost': 500,
#   'server_id': 950},
#  {'app_name': 'MongoDB',
#   'average': 0.33,
#   'cpu': 0.61,
#   'disk': 0.29,
#   'id': 951,
#   'memory': 0.02,
#   'network': 0.38,
#   'server_cost': 500,
#   'server_id': 951},
#  {'app_name': 'MongoDB',
#   'average': 0.29,
#   'cpu': 0.19,
#   'disk': 0.34,
#   'id': 952,
#   'memory': 0.61,
#   'network': 0.03,
#   'server_cost': 500,
#   'server_id': 952},
#  {'app_name': 'MongoDB',
#   'average': 0.53,
#   'cpu': 0.95,
#   'disk': 0.93,
#   'id': 953,
#   'memory': 0.16,
#   'network': 0.09,
#   'server_cost': 500,
#   'server_id': 953},
#  {'app_name': 'MongoDB',
#   'average': 0.58,
#   'cpu': 0.88,
#   'disk': 0.84,
#   'id': 954,
#   'memory': 0.04,
#   'network': 0.56,
#   'server_cost': 500,
#   'server_id': 954},
#  {'app_name': 'MongoDB',
#   'average': 0.43,
#   'cpu': 0.5,
#   'disk': 0.27,
#   'id': 955,
#   'memory': 0.81,
#   'network': 0.13,
#   'server_cost': 500,
#   'server_id': 955},
#  {'app_name': 'MongoDB',
#   'average': 0.67,
#   'cpu': 0.83,
#   'disk': 0.93,
#   'id': 956,
#   'memory': 0.67,
#   'network': 0.24,
#   'server_cost': 500,
#   'server_id': 956},
#  {'app_name': 'MongoDB',
#   'average': 0.43,
#   'cpu': 0.63,
#   'disk': 0.96,
#   'id': 957,
#   'memory': 0.12,
#   'network': 0.01,
#   'server_cost': 500,
#   'server_id': 957},
#  {'app_name': 'MongoDB',
#   'average': 0.36,
#   'cpu': 0.05,
#   'disk': 0.15,
#   'id': 958,
#   'memory': 0.87,
#   'network': 0.38,
#   'server_cost': 500,
#   'server_id': 958},
#  {'app_name': 'MongoDB',
#   'average': 0.27,
#   'cpu': 0.48,
#   'disk': 0.23,
#   'id': 959,
#   'memory': 0.33,
#   'network': 0.05,
#   'server_cost': 500,
#   'server_id': 959},
#  {'app_name': 'MongoDB',
#   'average': 0.67,
#   'cpu': 0.31,
#   'disk': 1.0,
#   'id': 960,
#   'memory': 0.47,
#   'network': 0.89,
#   'server_cost': 500,
#   'server_id': 960},
#  {'app_name': 'MongoDB',
#   'average': 0.56,
#   'cpu': 0.25,
#   'disk': 0.99,
#   'id': 961,
#   'memory': 0.89,
#   'network': 0.13,
#   'server_cost': 500,
#   'server_id': 961},
#  {'app_name': 'MongoDB',
#   'average': 0.64,
#   'cpu': 0.64,
#   'disk': 0.79,
#   'id': 962,
#   'memory': 0.83,
#   'network': 0.32,
#   'server_cost': 500,
#   'server_id': 962},
#  {'app_name': 'MongoDB',
#   'average': 0.55,
#   'cpu': 0.66,
#   'disk': 0.23,
#   'id': 963,
#   'memory': 0.43,
#   'network': 0.86,
#   'server_cost': 500,
#   'server_id': 963},
#  {'app_name': 'MongoDB',
#   'average': 0.45,
#   'cpu': 0.55,
#   'disk': 0.18,
#   'id': 964,
#   'memory': 0.5,
#   'network': 0.57,
#   'server_cost': 500,
#   'server_id': 964},
#  {'app_name': 'MongoDB',
#   'average': 0.64,
#   'cpu': 0.86,
#   'disk': 0.15,
#   'id': 965,
#   'memory': 0.78,
#   'network': 0.8,
#   'server_cost': 500,
#   'server_id': 965},
#  {'app_name': 'MongoDB',
#   'average': 0.4,
#   'cpu': 0.53,
#   'disk': 0.34,
#   'id': 966,
#   'memory': 0.27,
#   'network': 0.45,
#   'server_cost': 500,
#   'server_id': 966},
#  {'app_name': 'MongoDB',
#   'average': 0.58,
#   'cpu': 0.17,
#   'disk': 0.39,
#   'id': 967,
#   'memory': 0.87,
#   'network': 0.87,
#   'server_cost': 500,
#   'server_id': 967},
#  {'app_name': 'MongoDB',
#   'average': 0.45,
#   'cpu': 0.61,
#   'disk': 0.14,
#   'id': 968,
#   'memory': 0.71,
#   'network': 0.33,
#   'server_cost': 500,
#   'server_id': 968},
#  {'app_name': 'MongoDB',
#   'average': 0.7,
#   'cpu': 0.21,
#   'disk': 0.71,
#   'id': 969,
#   'memory': 0.95,
#   'network': 0.9,
#   'server_cost': 500,
#   'server_id': 969},
#  {'app_name': 'MongoDB',
#   'average': 0.42,
#   'cpu': 0.53,
#   'disk': 0.53,
#   'id': 970,
#   'memory': 0.37,
#   'network': 0.25,
#   'server_cost': 500,
#   'server_id': 970},
#  {'app_name': 'MongoDB',
#   'average': 0.26,
#   'cpu': 0.64,
#   'disk': 0.17,
#   'id': 971,
#   'memory': 0.19,
#   'network': 0.03,
#   'server_cost': 500,
#   'server_id': 971},
#  {'app_name': 'MongoDB',
#   'average': 0.49,
#   'cpu': 0.07,
#   'disk': 0.78,
#   'id': 972,
#   'memory': 0.29,
#   'network': 0.83,
#   'server_cost': 500,
#   'server_id': 972},
#  {'app_name': 'MongoDB',
#   'average': 0.22,
#   'cpu': 0.31,
#   'disk': 0.28,
#   'id': 973,
#   'memory': 0.2,
#   'network': 0.07,
#   'server_cost': 500,
#   'server_id': 973},
#  {'app_name': 'MongoDB',
#   'average': 0.6,
#   'cpu': 0.68,
#   'disk': 0.66,
#   'id': 974,
#   'memory': 0.9,
#   'network': 0.18,
#   'server_cost': 500,
#   'server_id': 974},
#  {'app_name': 'MongoDB',
#   'average': 0.23,
#   'cpu': 0.0,
#   'disk': 0.01,
#   'id': 975,
#   'memory': 0.29,
#   'network': 0.62,
#   'server_cost': 500,
#   'server_id': 975},
#  {'app_name': 'MongoDB',
#   'average': 0.51,
#   'cpu': 0.77,
#   'disk': 0.58,
#   'id': 976,
#   'memory': 0.37,
#   'network': 0.34,
#   'server_cost': 500,
#   'server_id': 976},
#  {'app_name': 'MongoDB',
#   'average': 0.49,
#   'cpu': 0.28,
#   'disk': 0.15,
#   'id': 977,
#   'memory': 0.84,
#   'network': 0.69,
#   'server_cost': 500,
#   'server_id': 977},
#  {'app_name': 'MongoDB',
#   'average': 0.48,
#   'cpu': 0.4,
#   'disk': 0.72,
#   'id': 978,
#   'memory': 0.79,
#   'network': 0.01,
#   'server_cost': 500,
#   'server_id': 978},
#  {'app_name': 'MongoDB',
#   'average': 0.46,
#   'cpu': 0.83,
#   'disk': 0.3,
#   'id': 979,
#   'memory': 0.14,
#   'network': 0.56,
#   'server_cost': 500,
#   'server_id': 979},
#  {'app_name': 'MongoDB',
#   'average': 0.39,
#   'cpu': 0.67,
#   'disk': 0.2,
#   'id': 980,
#   'memory': 0.25,
#   'network': 0.46,
#   'server_cost': 500,
#   'server_id': 980},
#  {'app_name': 'MongoDB',
#   'average': 0.53,
#   'cpu': 0.93,
#   'disk': 0.46,
#   'id': 981,
#   'memory': 0.17,
#   'network': 0.57,
#   'server_cost': 500,
#   'server_id': 981},
#  {'app_name': 'MongoDB',
#   'average': 0.6,
#   'cpu': 0.28,
#   'disk': 0.74,
#   'id': 982,
#   'memory': 0.89,
#   'network': 0.5,
#   'server_cost': 500,
#   'server_id': 982},
#  {'app_name': 'MongoDB',
#   'average': 0.42,
#   'cpu': 0.24,
#   'disk': 0.9,
#   'id': 983,
#   'memory': 0.36,
#   'network': 0.2,
#   'server_cost': 500,
#   'server_id': 983},
#  {'app_name': 'MongoDB',
#   'average': 0.56,
#   'cpu': 0.73,
#   'disk': 0.47,
#   'id': 984,
#   'memory': 0.46,
#   'network': 0.6,
#   'server_cost': 500,
#   'server_id': 984},
#  {'app_name': 'MongoDB',
#   'average': 0.44,
#   'cpu': 0.63,
#   'disk': 0.06,
#   'id': 985,
#   'memory': 0.44,
#   'network': 0.63,
#   'server_cost': 500,
#   'server_id': 985},
#  {'app_name': 'MongoDB',
#   'average': 0.36,
#   'cpu': 0.33,
#   'disk': 0.25,
#   'id': 986,
#   'memory': 0.07,
#   'network': 0.79,
#   'server_cost': 500,
#   'server_id': 986},
#  {'app_name': 'MongoDB',
#   'average': 0.27,
#   'cpu': 0.3,
#   'disk': 0.1,
#   'id': 987,
#   'memory': 0.19,
#   'network': 0.5,
#   'server_cost': 500,
#   'server_id': 987},
#  {'app_name': 'MongoDB',
#   'average': 0.41,
#   'cpu': 0.23,
#   'disk': 0.73,
#   'id': 988,
#   'memory': 0.51,
#   'network': 0.18,
#   'server_cost': 500,
#   'server_id': 988},
#  {'app_name': 'MongoDB',
#   'average': 0.37,
#   'cpu': 0.13,
#   'disk': 0.76,
#   'id': 989,
#   'memory': 0.26,
#   'network': 0.32,
#   'server_cost': 500,
#   'server_id': 989},
#  {'app_name': 'MongoDB',
#   'average': 0.19,
#   'cpu': 0.63,
#   'disk': 0.13,
#   'id': 990,
#   'memory': 0.0,
#   'network': 0.01,
#   'server_cost': 500,
#   'server_id': 990},
#  {'app_name': 'MongoDB',
#   'average': 0.37,
#   'cpu': 0.3,
#   'disk': 0.04,
#   'id': 991,
#   'memory': 0.63,
#   'network': 0.52,
#   'server_cost': 500,
#   'server_id': 991},
#  {'app_name': 'MongoDB',
#   'average': 0.6,
#   'cpu': 0.4,
#   'disk': 0.64,
#   'id': 992,
#   'memory': 0.49,
#   'network': 0.85,
#   'server_cost': 500,
#   'server_id': 992},
#  {'app_name': 'MongoDB',
#   'average': 0.49,
#   'cpu': 0.74,
#   'disk': 0.64,
#   'id': 993,
#   'memory': 0.03,
#   'network': 0.56,
#   'server_cost': 500,
#   'server_id': 993},
#  {'app_name': 'MongoDB',
#   'average': 0.26,
#   'cpu': 0.44,
#   'disk': 0.11,
#   'id': 994,
#   'memory': 0.05,
#   'network': 0.44,
#   'server_cost': 500,
#   'server_id': 994},
#  {'app_name': 'MongoDB',
#   'average': 0.18,
#   'cpu': 0.1,
#   'disk': 0.38,
#   'id': 995,
#   'memory': 0.08,
#   'network': 0.16,
#   'server_cost': 500,
#   'server_id': 995},
#  {'app_name': 'MongoDB',
#   'average': 0.51,
#   'cpu': 0.94,
#   'disk': 0.02,
#   'id': 996,
#   'memory': 0.96,
#   'network': 0.12,
#   'server_cost': 500,
#   'server_id': 996},
#  {'app_name': 'MongoDB',
#   'average': 0.54,
#   'cpu': 0.45,
#   'disk': 0.05,
#   'id': 997,
#   'memory': 0.94,
#   'network': 0.75,
#   'server_cost': 500,
#   'server_id': 997},
#  {'app_name': 'MongoDB',
#   'average': 0.49,
#   'cpu': 0.48,
#   'disk': 0.77,
#   'id': 998,
#   'memory': 0.69,
#   'network': 0.03,
#   'server_cost': 500,
#   'server_id': 998},
#  {'app_name': 'MongoDB',
#   'average': 0.49,
#   'cpu': 0.99,
#   'disk': 0.45,
#   'id': 999,
#   'memory': 0.24,
#   'network': 0.29,
#   'server_cost': 500,
#   'server_id': 999},
#  {'app_name': 'MongoDB',
#   'average': 0.68,
#   'cpu': 0.91,
#   'disk': 0.53,
#   'id': 1000,
#   'memory': 0.66,
#   'network': 0.64,
#   'server_cost': 500,
#   'server_id': 1000},
#  ...]

# %%
#this is for api route of app summary
#calculate total number of server per app
#calculate number of server with cpu, memory, network and disk with capacity less than or equal to 30% (under performing)
#calculate number of server with cpu, memory, network and disk with capacity over or equal to 95% (exceed performing)
#calculate number of server with cpu, memory, network and disk with capacity less than 95% and greater than 30% (average performing)

#set variable for app, sample app: 'Encryption'
app = 'Encryption'

app_filtered_df = cloud_df[cloud_df['app_name'] == app]

#total number of server per app
total_server_per_app = app_filtered_df.groupby('app_name')['server_id'].count()

#average cpu, memory, network and disk
avg_cpu_per_app = app_filtered_df.groupby('app_name')['cpu'].mean()
avg_memory_per_app = app_filtered_df.groupby('app_name')['memory'].mean()
avg_network_per_app = app_filtered_df.groupby('app_name')['network'].mean()
avg_disk_per_app = app_filtered_df.groupby('app_name')['disk'].mean()

under_performing_df = app_filtered_df[(app_filtered_df['cpu'] <= 0.30) & (app_filtered_df['memory'] <= 0.30) 
                              & (app_filtered_df['network'] <= 0.30) & (app_filtered_df['disk'] <= 0.30) ]

exceed_performing_df = app_filtered_df[(app_filtered_df['cpu'] >= 0.95) & (app_filtered_df['memory'] >= 0.95) 
                              & (app_filtered_df['network'] >= 0.95) & (app_filtered_df['disk'] >= 0.95) ]

average_performing_df = app_filtered_df[((app_filtered_df['cpu'] > 0.30) | (app_filtered_df['memory'] > 0.30)
                                         | (app_filtered_df['network'] > 0.30) | (app_filtered_df['disk'] > 0.30))
                                         & ((app_filtered_df['cpu'] < 0.95) | (app_filtered_df['memory'] < 0.95)
                                            | (app_filtered_df['network'] < 0.95) | (app_filtered_df['disk'] < 0.95))
                                       ]

under_performing_server_count = under_performing_df.groupby('app_name')['server_id'].count()
exceed_performing_server_count = exceed_performing_df.groupby('app_name')['server_id'].count()
average_performing_server_count = average_performing_df.groupby('app_name')['server_id'].count()

#print('total: ',str(total_server_per_app))
#print('under: ',str(under_performing_server_count))
#print('exceed: ',str(exceed_performing_server_count))
#print('average: ',str(average_performing_server_count))

summary_app_df = pd.DataFrame({'total_server': total_server_per_app,
                               'nbr_of_under_performing':under_performing_server_count,
                               'nbr_of_exceed_performing':exceed_performing_server_count,
                               'nbr_of_average_performing':average_performing_server_count,
                               'avg_cpu':avg_cpu_per_app,'avg_memory':avg_memory_per_app,
                               'avg_network':avg_network_per_app,'avg_disk':avg_disk_per_app
                              })

summary_app_df = summary_app_df.reset_index()

summary_app_df
# Out:
#         index   avg_cpu  avg_disk  avg_memory  avg_network  \
# 0  Encryption  0.499179  0.472761    0.481045     0.484627
#
#    nbr_of_average_performing  nbr_of_exceed_performing  \
# 0                        132                       NaN
#
#    nbr_of_under_performing  total_server
# 0                        2           134

# %%
json_app = json.loads(summary_app_df.to_json(orient='records'))

json_app
# Out:
# [{'avg_cpu': 0.4991791045,
#   'avg_disk': 0.472761194,
#   'avg_memory': 0.4810447761,
#   'avg_network': 0.4846268657,
#   'index': 'Encryption',
#   'nbr_of_average_performing': 132,
#   'nbr_of_exceed_performing': None,
#   'nbr_of_under_performing': 2,
#   'total_server': 134}]

# %%
#summary of data, group by app name, this is for api route: summary of data by app name
mean_cpu = cloud_df.groupby('app_name')['cpu'].mean()
mean_memory = cloud_df.groupby('app_name')['memory'].mean()
mean_network = cloud_df.groupby('app_name')['network'].mean()
mean_disk = cloud_df.groupby('app_name')['disk'].mean()
total_server = cloud_df.groupby('app_name')['server_id'].count()
total_server_cost = cloud_df.groupby('app_name')['disk'].sum()


summary_cloud_df = pd.DataFrame({'avg_cpu': mean_cpu,'avg_memory':mean_memory,'avg_network':mean_network,'avg_disk':mean_disk,
                                 'total_server':total_server,'total_server_cost':total_server_cost})

summary_cloud_df = summary_cloud_df.reset_index()

summary_cloud_df.head()
# Out:
#      app_name   avg_cpu  avg_disk  avg_memory  avg_network  total_server  \
# 0  APIGateway  0.527761  0.520746    0.430597     0.531642            67
# 1        Appd  0.428750  0.480833    0.493750     0.503750            24
# 2     BigData  0.515753  0.475068    0.490411     0.503699            73
# 3     Compile  0.624000  0.429000    0.648000     0.409000            10
# 4  ContentApp  0.467093  0.485039    0.497946     0.503101           258
#
#    total_server_cost
# 0              34.89
# 1              11.54
# 2              34.68
# 3               4.29
# 4             125.14

# %%
json_data_summary = json.loads(summary_cloud_df.to_json(orient='records'))

json_data_summary
# Out:
# [{'app_name': 'APIGateway',
#   'avg_cpu': 0.527761194,
#   'avg_disk': 0.5207462687,
#   'avg_memory': 0.4305970149,
#   'avg_network': 0.531641791,
#   'total_server': 67,
#   'total_server_cost': 34.89},
#  {'app_name': 'Appd',
#   'avg_cpu': 0.42875,
#   'avg_disk': 0.4808333333,
#   'avg_memory': 0.49375,
#   'avg_network': 0.50375,
#   'total_server': 24,
#   'total_server_cost': 11.54},
#  {'app_name': 'BigData',
#   'avg_cpu': 0.5157534247,
#   'avg_disk': 0.4750684932,
#   'avg_memory': 0.4904109589,
#   'avg_network': 0.5036986301,
#   'total_server': 73,
#   'total_server_cost': 34.68},
#  {'app_name': 'Compile',
#   'avg_cpu': 0.624,
#   'avg_disk': 0.429,
#   'avg_memory': 0.648,
#   'avg_network': 0.409,
#   'total_server': 10,
#   'total_server_cost': 4.29},
#  {'app_name': 'ContentApp',
#   'avg_cpu': 0.4670930233,
#   'avg_disk': 0.4850387597,
#   'avg_memory': 0.4979457364,
#   'avg_network': 0.5031007752,
#   'total_server': 258,
#   'total_server_cost': 125.14},
#  {'app_name': 'Couchbase',
#   'avg_cpu': 0.362,
#   'avg_disk': 0.492,
#   'avg_memory': 0.514,
#   'avg_network': 0.683,
#   'total_server': 10,
#   'total_server_cost': 4.92},
#  {'app_name': 'Couchbase_Operator',
#   'avg_cpu': 0.5534782609,
#   'avg_disk': 0.4504347826,
#   'avg_memory': 0.4843478261,
#   'avg_network': 0.5052173913,
#   'total_server': 23,
#   'total_server_cost': 10.36},
#  {'app_name': 'Database',
#   'avg_cpu': 0.385,
#   'avg_disk': 0.425,
#   'avg_memory': 0.22,
#   'avg_network': 0.335,
#   'total_server': 2,
#   'total_server_cost': 0.85},
#  {'app_name': 'Encryption',
#   'avg_cpu': 0.4991791045,
#   'avg_disk': 0.472761194,
#   'avg_memory': 0.4810447761,
#   'avg_network': 0.4846268657,
#   'total_server': 134,
#   'total_server_cost': 63.35},
#  {'app_name': 'Messaging',
#   'avg_cpu': 0.4485,
#   'avg_disk': 0.49,
#   'avg_memory': 0.5155,
#   'avg_network': 0.5865,
#   'total_server': 20,
#   'total_server_cost': 9.8},
#  {'app_name': 'Metrics',
#   'avg_cpu': 0.27,
#   'avg_disk': 0.46,
#   'avg_memory': 0.765,
#   'avg_network': 0.925,
#   'total_server': 2,
#   'total_server_cost': 0.92},
#  {'app_name': 'MongoDB',
#   'avg_cpu': 0.5296875,
#   'avg_disk': 0.4559375,
#   'avg_memory': 0.4830208333,
#   'avg_network': 0.5127083333,
#   'total_server': 96,
#   'total_server_cost': 43.77},
#  {'app_name': 'MySQL',
#   'avg_cpu': 0.5035135135,
#   'avg_disk': 0.5083783784,
#   'avg_memory': 0.5775675676,
#   'avg_network': 0.4778378378,
#   'total_server': 74,
#   'total_server_cost': 37.62},
#  {'app_name': 'Performance',
#   'avg_cpu': 0.5478571429,
#   'avg_disk': 0.5078571429,
#   'avg_memory': 0.3785714286,
#   'avg_network': 0.4428571429,
#   'total_server': 14,
#   'total_server_cost': 7.11},
#  {'app_name': 'Security',
#   'avg_cpu': 0.405,
#   'avg_disk': 0.6025,
#   'avg_memory': 0.7825,
#   'avg_network': 0.3275,
#   'total_server': 4,
#   'total_server_cost': 2.41},
#  {'app_name': 'Test',
#   'avg_cpu': 0.4175,
#   'avg_disk': 0.3375,
#   'avg_memory': 0.5325,
#   'avg_network': 0.59,
#   'total_server': 4,
#   'total_server_cost': 1.35},
#  {'app_name': 'Test_deploy',
#   'avg_cpu': 0.2,
#   'avg_disk': 0.775,
#   'avg_memory': 0.6,
#   'avg_network': 0.63,
#   'total_server': 2,
#   'total_server_cost': 1.55},
#  {'app_name': 'Tools-Test',
#   'avg_cpu': 0.8,
#   'avg_disk': 0.855,
#   'avg_memory': 0.61,
#   'avg_network': 0.51,
#   'total_server': 2,
#   'total_server_cost': 1.71},
#  {'app_name': 'UI',
#   'avg_cpu': 0.4086666667,
#   'avg_disk': 0.5093333333,
#   'avg_memory': 0.5076666667,
#   'avg_network': 0.49,
#   'total_server': 30,
#   'total_server_cost': 15.28},
#  {'app_name': 'adapter',
#   'avg_cpu': 0.6316666667,
#   'avg_disk': 0.6116666667,
#   'avg_memory': 0.3166666667,
#   'avg_network': 0.5233333333,
#   'total_server': 6,
#   'total_server_cost': 3.67},
#  {'app_name': 'cache',
#   'avg_cpu': 0.516,
#   'avg_disk': 0.4898,
#   'avg_memory': 0.5174,
#   'avg_network': 0.4774,
#   'total_server': 50,
#   'total_server_cost': 24.49},
#  {'app_name': 'couchbase',
#   'avg_cpu': 0.4799348534,
#   'avg_disk': 0.4891856678,
#   'avg_memory': 0.4979153094,
#   'avg_network': 0.4975895765,
#   'total_server': 307,
#   'total_server_cost': 150.18},
#  {'app_name': 'custodian',
#   'avg_cpu': 0.73,
#   'avg_disk': 0.64,
#   'avg_memory': 0.55,
#   'avg_network': 0.86,
#   'total_server': 1,
#   'total_server_cost': 0.64},
#  {'app_name': 'dataplatform',
#   'avg_cpu': 0.47575,
#   'avg_disk': 0.44375,
#   'avg_memory': 0.4915,
#   'avg_network': 0.4805,
#   'total_server': 40,
#   'total_server_cost': 17.75},
#  {'app_name': 'datawarehouse',
#   'avg_cpu': 0.598,
#   'avg_disk': 0.533,
#   'avg_memory': 0.4926666667,
#   'avg_network': 0.4873333333,
#   'total_server': 30,
#   'total_server_cost': 15.99},
#  {'app_name': 'elasticsearch',
#   'avg_cpu': 0.32,
#   'avg_disk': 0.135,
#   'avg_memory': 0.15,
#   'avg_network': 0.18,
#   'total_server': 2,
#   'total_server_cost': 0.27},
#  {'app_name': 'elasticsearch-2',
#   'avg_cpu': 0.43,
#   'avg_disk': 0.82,
#   'avg_memory': 0.48,
#   'avg_network': 0.89,
#   'total_server': 2,
#   'total_server_cost': 1.64},
#  {'app_name': 'enforce-test',
#   'avg_cpu': 0.67,
#   'avg_disk': 0.715,
#   'avg_memory': 0.63,
#   'avg_network': 0.33,
#   'total_server': 2,
#   'total_server_cost': 1.43},
#  {'app_name': 'lambda',
#   'avg_cpu': 0.4881151832,
#   'avg_disk': 0.4847120419,
#   'avg_memory': 0.4839267016,
#   'avg_network': 0.4928272251,
#   'total_server': 191,
#   'total_server_cost': 92.58},
#  {'app_name': 'locust',
#   'avg_cpu': 0.4533333333,
#   'avg_disk': 0.7433333333,
#   'avg_memory': 0.2666666667,
#   'avg_network': 0.2266666667,
#   'total_server': 3,
#   'total_server_cost': 2.23},
#  {'app_name': 'messaging',
#   'avg_cpu': 0.4507692308,
#   'avg_disk': 0.6561538462,
#   'avg_memory': 0.4611538462,
#   'avg_network': 0.5253846154,
#   'total_server': 26,
#   'total_server_cost': 17.06},
#  {'app_name': 'microservices',
#   'avg_cpu': 0.4441134752,
#   'avg_disk': 0.4688652482,
#   'avg_memory': 0.5182269504,
#   'avg_network': 0.5044680851,
#   'total_server': 141,
#   'total_server_cost': 66.11},
#  {'app_name': 'mobile',
#   'avg_cpu': 0.5685714286,
#   'avg_disk': 0.5571428571,
#   'avg_memory': 0.4532142857,
#   'avg_network': 0.4410714286,
#   'total_server': 28,
#   'total_server_cost': 15.6},
#  {'app_name': 'mongoDB',
#   'avg_cpu': 0.55375,
#   'avg_disk': 0.59875,
#   'avg_memory': 0.375,
#   'avg_network': 0.45875,
#   'total_server': 8,
#   'total_server_cost': 4.79},
#  {'app_name': 'mysql',
#   'avg_cpu': 0.5146428571,
#   'avg_disk': 0.5307142857,
#   'avg_memory': 0.5260714286,
#   'avg_network': 0.4610714286,
#   'total_server': 28,
#   'total_server_cost': 14.86}]

# %%
#this is for bar chart, 1st layer of bar for selected app - assign red color??
#summary_cloud_app_df = summary_cloud_df[summary_cloud_df['app_name'] == app]
#summary_cloud_app_df.head()

# %%
#this is for bar chart, 2nd layer of bar for app were not selected - assign grey color for all bar??
#summary_cloud_other_app_df = summary_cloud_df[summary_cloud_df['app_name'] != app]
#summary_cloud_other_app_df.head()
